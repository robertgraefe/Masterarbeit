# %% [markdown]
# ## <u>2. Datenaufbereitung Application</u>

# %% [markdown]
# In diesem Dokument werden für die Untersuchung unwichtige Variablen aus dem Application-Datensatz gelöscht. Dabei werden zuerst die kategorischen Variablen (nominale & ordinale) betrachtet, um anschließend die metrischen Variablen zu betrachten.
#
# *Vorgehensweise kategorische Variablen:*
# - Löschung von Variablen mit mehr als 60% fehlenden Daten
# - Löschung von nominalen Variablen mit weniger als 5pP relativer Anteilsdifferenz zwischen Paybacks und Defaults
# - Bildung von Korrelationsclustern (Kontingenzkoeffizent bei nominalen Daten)
# - Bildung von Korrelationsclustern (Spearman-Rangkorrelationskoeffizienz bei ordinalen Daten)
# - Löschung von Variablen ohne kausalen Einfluss auf die Kreditwürdigkeitsbestimmung
# - Transformation der nominalen Daten in Integer
#
# *Vorgehensweise metrischer Variablen:*
# - Löschung von Variablen mit mehr als 60% fehlenden Daten
# - Bildung von Korrelationsclustern (Pearson-Korrelationskoeffizient)
# - Löschung von Variablen ohne kausalen Einfluss auf die Kreditwürdigkeitsbestimmung

# %% [markdown]
# ## Initialisierung

# %%
from pathlib import Path
from scipy import stats

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

from sklearn.linear_model import LogisticRegression

from IPython.display import display, Markdown

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
app_test = pd.read_csv(DATASET_DIR / "application_test.csv", index_col="SK_ID_CURR")
app_train = pd.read_csv(DATASET_DIR / "2. Datenaufbereitung" / "app_train.csv", index_col="SK_ID_CURR")
description = pd.read_csv(DATASET_DIR / "HomeCredit_columns_description.csv", encoding="latin", index_col=0)

# %%
des = description.loc[description['Table']=="application_{train|test}.csv", "Row":"Special"]

# %%
app_test.head()
# Out:
#            NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# SK_ID_CURR
# 100001             Cash loans           F            N               Y
# 100005             Cash loans           M            N               Y
# 100013             Cash loans           M            Y               Y
# 100028             Cash loans           F            N               Y
# 100038             Cash loans           M            Y               N
#
#             CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# 100001                 0          135000.0    568800.0      20560.5
# 100005                 0           99000.0    222768.0      17370.0
# 100013                 0          202500.0    663264.0      69777.0
# 100028                 2          315000.0   1575000.0      49018.5
# 100038                 1          180000.0    625500.0      32067.0
#
#             AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# SK_ID_CURR
# 100001             450000.0   Unaccompanied          Working
# 100005             180000.0   Unaccompanied          Working
# 100013             630000.0             NaN          Working
# 100028            1575000.0   Unaccompanied          Working
# 100038             625500.0   Unaccompanied          Working
#
#                       NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# SK_ID_CURR
# 100001                   Higher education            Married
# 100005      Secondary / secondary special            Married
# 100013                   Higher education            Married
# 100028      Secondary / secondary special            Married
# 100038      Secondary / secondary special            Married
#
#             NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# SK_ID_CURR
# 100001      House / apartment                    0.018850      -19241
# 100005      House / apartment                    0.035792      -18064
# 100013      House / apartment                    0.019101      -20038
# 100028      House / apartment                    0.026392      -13976
# 100038      House / apartment                    0.010032      -13040
#
#             DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  \
# SK_ID_CURR
# 100001              -2329            -5170.0             -812          NaN
# 100005              -4469            -9118.0            -1623          NaN
# 100013              -4458            -2175.0            -3503          5.0
# 100028              -1866            -2000.0            -4208          NaN
# 100038              -2191            -4000.0            -4262         16.0
#
#             FLAG_MOBIL  FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  \
# SK_ID_CURR
# 100001               1               1                0                 1
# 100005               1               1                0                 1
# 100013               1               1                0                 1
# 100028               1               1                0                 1
# 100038               1               1                1                 1
#
#             FLAG_PHONE  FLAG_EMAIL     OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# SK_ID_CURR
# 100001               0           1                 NaN              2.0
# 100005               0           0  Low-skill Laborers              2.0
# 100013               0           0             Drivers              2.0
# 100028               1           0         Sales staff              4.0
# 100038               0           0                 NaN              3.0
#
#             REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# SK_ID_CURR
# 100001                         2                            2
# 100005                         2                            2
# 100013                         2                            2
# 100028                         2                            2
# 100038                         2                            2
#
#            WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  \
# SK_ID_CURR
# 100001                        TUESDAY                       18
# 100005                         FRIDAY                        9
# 100013                         MONDAY                       14
# 100028                      WEDNESDAY                       11
# 100038                         FRIDAY                        5
#
#             REG_REGION_NOT_LIVE_REGION  REG_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100001                               0                           0
# 100005                               0                           0
# 100013                               0                           0
# 100028                               0                           0
# 100038                               0                           0
#
#             LIVE_REGION_NOT_WORK_REGION  REG_CITY_NOT_LIVE_CITY  \
# SK_ID_CURR
# 100001                                0                       0
# 100005                                0                       0
# 100013                                0                       0
# 100028                                0                       0
# 100038                                0                       0
#
#             REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100001                           0                        0
# 100005                           0                        0
# 100013                           0                        0
# 100028                           0                        0
# 100038                           1                        1
#
#                  ORGANIZATION_TYPE  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# SK_ID_CURR
# 100001                Kindergarten      0.752614      0.789654      0.159520
# 100005               Self-employed      0.564990      0.291656      0.432962
# 100013           Transport: type 3           NaN      0.699787      0.610991
# 100028      Business Entity Type 3      0.525734      0.509677      0.612704
# 100038      Business Entity Type 3      0.202145      0.425687           NaN
#
#             APARTMENTS_AVG  BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  \
# SK_ID_CURR
# 100001              0.0660            0.0590                       0.9732
# 100005                 NaN               NaN                          NaN
# 100013                 NaN               NaN                          NaN
# 100028              0.3052            0.1974                       0.9970
# 100038                 NaN               NaN                          NaN
#
#             YEARS_BUILD_AVG  COMMONAREA_AVG  ELEVATORS_AVG  ENTRANCES_AVG  \
# SK_ID_CURR
# 100001                  NaN             NaN            NaN         0.1379
# 100005                  NaN             NaN            NaN            NaN
# 100013                  NaN             NaN            NaN            NaN
# 100028               0.9592          0.1165           0.32         0.2759
# 100038                  NaN             NaN            NaN            NaN
#
#             FLOORSMAX_AVG  FLOORSMIN_AVG  LANDAREA_AVG  LIVINGAPARTMENTS_AVG  \
# SK_ID_CURR
# 100001              0.125            NaN           NaN                   NaN
# 100005                NaN            NaN           NaN                   NaN
# 100013                NaN            NaN           NaN                   NaN
# 100028              0.375         0.0417        0.2042                0.2404
# 100038                NaN            NaN           NaN                   NaN
#
#             LIVINGAREA_AVG  NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  \
# SK_ID_CURR
# 100001              0.0505                      NaN                NaN
# 100005                 NaN                      NaN                NaN
# 100013                 NaN                      NaN                NaN
# 100028              0.3673                   0.0386               0.08
# 100038                 NaN                      NaN                NaN
#
#             APARTMENTS_MODE  BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  \
# SK_ID_CURR
# 100001               0.0672             0.0612                        0.9732
# 100005                  NaN                NaN                           NaN
# 100013                  NaN                NaN                           NaN
# 100028               0.3109             0.2049                        0.9970
# 100038                  NaN                NaN                           NaN
#
#             YEARS_BUILD_MODE  COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  \
# SK_ID_CURR
# 100001                   NaN              NaN             NaN          0.1379
# 100005                   NaN              NaN             NaN             NaN
# 100013                   NaN              NaN             NaN             NaN
# 100028                0.9608           0.1176          0.3222          0.2759
# 100038                   NaN              NaN             NaN             NaN
#
#             FLOORSMAX_MODE  FLOORSMIN_MODE  LANDAREA_MODE  \
# SK_ID_CURR
# 100001               0.125             NaN            NaN
# 100005                 NaN             NaN            NaN
# 100013                 NaN             NaN            NaN
# 100028               0.375          0.0417         0.2089
# 100038                 NaN             NaN            NaN
#
#             LIVINGAPARTMENTS_MODE  LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  \
# SK_ID_CURR
# 100001                        NaN           0.0526                       NaN
# 100005                        NaN              NaN                       NaN
# 100013                        NaN              NaN                       NaN
# 100028                     0.2626           0.3827                    0.0389
# 100038                        NaN              NaN                       NaN
#
#             NONLIVINGAREA_MODE  APARTMENTS_MEDI  BASEMENTAREA_MEDI  \
# SK_ID_CURR
# 100001                     NaN           0.0666             0.0590
# 100005                     NaN              NaN                NaN
# 100013                     NaN              NaN                NaN
# 100028                  0.0847           0.3081             0.1974
# 100038                     NaN              NaN                NaN
#
#             YEARS_BEGINEXPLUATATION_MEDI  YEARS_BUILD_MEDI  COMMONAREA_MEDI  \
# SK_ID_CURR
# 100001                            0.9732               NaN              NaN
# 100005                               NaN               NaN              NaN
# 100013                               NaN               NaN              NaN
# 100028                            0.9970            0.9597           0.1173
# 100038                               NaN               NaN              NaN
#
#             ELEVATORS_MEDI  ENTRANCES_MEDI  FLOORSMAX_MEDI  FLOORSMIN_MEDI  \
# SK_ID_CURR
# 100001                 NaN          0.1379           0.125             NaN
# 100005                 NaN             NaN             NaN             NaN
# 100013                 NaN             NaN             NaN             NaN
# 100028                0.32          0.2759           0.375          0.0417
# 100038                 NaN             NaN             NaN             NaN
#
#             LANDAREA_MEDI  LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  \
# SK_ID_CURR
# 100001                NaN                    NaN           0.0514
# 100005                NaN                    NaN              NaN
# 100013                NaN                    NaN              NaN
# 100028             0.2078                 0.2446           0.3739
# 100038                NaN                    NaN              NaN
#
#             NONLIVINGAPARTMENTS_MEDI  NONLIVINGAREA_MEDI FONDKAPREMONT_MODE  \
# SK_ID_CURR
# 100001                           NaN                 NaN                NaN
# 100005                           NaN                 NaN                NaN
# 100013                           NaN                 NaN                NaN
# 100028                        0.0388              0.0817   reg oper account
# 100038                           NaN                 NaN                NaN
#
#             HOUSETYPE_MODE  TOTALAREA_MODE WALLSMATERIAL_MODE  \
# SK_ID_CURR
# 100001      block of flats          0.0392       Stone, brick
# 100005                 NaN             NaN                NaN
# 100013                 NaN             NaN                NaN
# 100028      block of flats          0.3700              Panel
# 100038                 NaN             NaN                NaN
#
#            EMERGENCYSTATE_MODE  OBS_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100001                      No                       0.0
# 100005                     NaN                       0.0
# 100013                     NaN                       0.0
# 100028                      No                       0.0
# 100038                     NaN                       0.0
#
#             DEF_30_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100001                           0.0                       0.0
# 100005                           0.0                       0.0
# 100013                           0.0                       0.0
# 100028                           0.0                       0.0
# 100038                           0.0                       0.0
#
#             DEF_60_CNT_SOCIAL_CIRCLE  DAYS_LAST_PHONE_CHANGE  FLAG_DOCUMENT_2  \
# SK_ID_CURR
# 100001                           0.0                 -1740.0                0
# 100005                           0.0                     0.0                0
# 100013                           0.0                  -856.0                0
# 100028                           0.0                 -1805.0                0
# 100038                           0.0                  -821.0                0
#
#             FLAG_DOCUMENT_3  FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  \
# SK_ID_CURR
# 100001                    1                0                0
# 100005                    1                0                0
# 100013                    0                0                0
# 100028                    1                0                0
# 100038                    1                0                0
#
#             FLAG_DOCUMENT_6  FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  \
# SK_ID_CURR
# 100001                    0                0                0
# 100005                    0                0                0
# 100013                    0                0                1
# 100028                    0                0                0
# 100038                    0                0                0
#
#             FLAG_DOCUMENT_9  FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  \
# SK_ID_CURR
# 100001                    0                 0                 0
# 100005                    0                 0                 0
# 100013                    0                 0                 0
# 100028                    0                 0                 0
# 100038                    0                 0                 0
#
#             FLAG_DOCUMENT_12  FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  \
# SK_ID_CURR
# 100001                     0                 0                 0
# 100005                     0                 0                 0
# 100013                     0                 0                 0
# 100028                     0                 0                 0
# 100038                     0                 0                 0
#
#             FLAG_DOCUMENT_15  FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  \
# SK_ID_CURR
# 100001                     0                 0                 0
# 100005                     0                 0                 0
# 100013                     0                 0                 0
# 100028                     0                 0                 0
# 100038                     0                 0                 0
#
#             FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  \
# SK_ID_CURR
# 100001                     0                 0                 0
# 100005                     0                 0                 0
# 100013                     0                 0                 0
# 100028                     0                 0                 0
# 100038                     0                 0                 0
#
#             FLAG_DOCUMENT_21  AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100001                     0                         0.0
# 100005                     0                         0.0
# 100013                     0                         0.0
# 100028                     0                         0.0
# 100038                     0                         NaN
#
#             AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# SK_ID_CURR
# 100001                            0.0                         0.0
# 100005                            0.0                         0.0
# 100013                            0.0                         0.0
# 100028                            0.0                         0.0
# 100038                            NaN                         NaN
#
#             AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# SK_ID_CURR
# 100001                            0.0                        0.0
# 100005                            0.0                        0.0
# 100013                            0.0                        1.0
# 100028                            0.0                        0.0
# 100038                            NaN                        NaN
#
#             AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR
# 100001                             0.0
# 100005                             3.0
# 100013                             4.0
# 100028                             3.0
# 100038                             NaN

# %%
# Spalten die innerhalb der Aufbereitung nicht verändert werden können
skip = ["TARGET", "SK_ID_CURR"]

# %%
# nominale und metrische Spalten
n_heads = ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'WEEKDAY_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21']
o_heads = ["CNT_CHILDREN", "CNT_FAM_MEMBERS", "HOUR_APPR_PROCESS_START", "OBS_30_CNT_SOCIAL_CIRCLE", "DEF_30_CNT_SOCIAL_CIRCLE", "OBS_60_CNT_SOCIAL_CIRCLE", "DEF_60_CNT_SOCIAL_CIRCLE", "AMT_REQ_CREDIT_BUREAU_HOUR", "AMT_REQ_CREDIT_BUREAU_DAY", "AMT_REQ_CREDIT_BUREAU_WEEK", "AMT_REQ_CREDIT_BUREAU_MON", "AMT_REQ_CREDIT_BUREAU_QRT", "AMT_REQ_CREDIT_BUREAU_YEAR"]
m_heads = [head for head in app_test.columns.values if head not in n_heads and head not in o_heads]

# %% [markdown]
# ## <u>kategorische Variablen

# %%
df = app_test[n_heads + o_heads].copy()

# %%
df.head()
# Out:
#            NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# SK_ID_CURR
# 100001             Cash loans           F            N               Y
# 100005             Cash loans           M            N               Y
# 100013             Cash loans           M            Y               Y
# 100028             Cash loans           F            N               Y
# 100038             Cash loans           M            Y               N
#
#            NAME_TYPE_SUITE NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# SK_ID_CURR
# 100001       Unaccompanied          Working               Higher education
# 100005       Unaccompanied          Working  Secondary / secondary special
# 100013                 NaN          Working               Higher education
# 100028       Unaccompanied          Working  Secondary / secondary special
# 100038       Unaccompanied          Working  Secondary / secondary special
#
#            NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  FLAG_MOBIL  FLAG_EMP_PHONE  \
# SK_ID_CURR
# 100001                Married  House / apartment           1               1
# 100005                Married  House / apartment           1               1
# 100013                Married  House / apartment           1               1
# 100028                Married  House / apartment           1               1
# 100038                Married  House / apartment           1               1
#
#             FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL  \
# SK_ID_CURR
# 100001                    0                 1           0           1
# 100005                    0                 1           0           0
# 100013                    0                 1           0           0
# 100028                    0                 1           1           0
# 100038                    1                 1           0           0
#
#                OCCUPATION_TYPE  REGION_RATING_CLIENT  \
# SK_ID_CURR
# 100001                     NaN                     2
# 100005      Low-skill Laborers                     2
# 100013                 Drivers                     2
# 100028             Sales staff                     2
# 100038                     NaN                     2
#
#             REGION_RATING_CLIENT_W_CITY WEEKDAY_APPR_PROCESS_START  \
# SK_ID_CURR
# 100001                                2                    TUESDAY
# 100005                                2                     FRIDAY
# 100013                                2                     MONDAY
# 100028                                2                  WEDNESDAY
# 100038                                2                     FRIDAY
#
#             REG_REGION_NOT_LIVE_REGION  REG_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100001                               0                           0
# 100005                               0                           0
# 100013                               0                           0
# 100028                               0                           0
# 100038                               0                           0
#
#             LIVE_REGION_NOT_WORK_REGION  REG_CITY_NOT_LIVE_CITY  \
# SK_ID_CURR
# 100001                                0                       0
# 100005                                0                       0
# 100013                                0                       0
# 100028                                0                       0
# 100038                                0                       0
#
#             REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100001                           0                        0
# 100005                           0                        0
# 100013                           0                        0
# 100028                           0                        0
# 100038                           1                        1
#
#                  ORGANIZATION_TYPE FONDKAPREMONT_MODE  HOUSETYPE_MODE  \
# SK_ID_CURR
# 100001                Kindergarten                NaN  block of flats
# 100005               Self-employed                NaN             NaN
# 100013           Transport: type 3                NaN             NaN
# 100028      Business Entity Type 3   reg oper account  block of flats
# 100038      Business Entity Type 3                NaN             NaN
#
#            WALLSMATERIAL_MODE EMERGENCYSTATE_MODE  FLAG_DOCUMENT_2  \
# SK_ID_CURR
# 100001           Stone, brick                  No                0
# 100005                    NaN                 NaN                0
# 100013                    NaN                 NaN                0
# 100028                  Panel                  No                0
# 100038                    NaN                 NaN                0
#
#             FLAG_DOCUMENT_3  FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  \
# SK_ID_CURR
# 100001                    1                0                0
# 100005                    1                0                0
# 100013                    0                0                0
# 100028                    1                0                0
# 100038                    1                0                0
#
#             FLAG_DOCUMENT_6  FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  \
# SK_ID_CURR
# 100001                    0                0                0
# 100005                    0                0                0
# 100013                    0                0                1
# 100028                    0                0                0
# 100038                    0                0                0
#
#             FLAG_DOCUMENT_9  FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  \
# SK_ID_CURR
# 100001                    0                 0                 0
# 100005                    0                 0                 0
# 100013                    0                 0                 0
# 100028                    0                 0                 0
# 100038                    0                 0                 0
#
#             FLAG_DOCUMENT_12  FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  \
# SK_ID_CURR
# 100001                     0                 0                 0
# 100005                     0                 0                 0
# 100013                     0                 0                 0
# 100028                     0                 0                 0
# 100038                     0                 0                 0
#
#             FLAG_DOCUMENT_15  FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  \
# SK_ID_CURR
# 100001                     0                 0                 0
# 100005                     0                 0                 0
# 100013                     0                 0                 0
# 100028                     0                 0                 0
# 100038                     0                 0                 0
#
#             FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  \
# SK_ID_CURR
# 100001                     0                 0                 0
# 100005                     0                 0                 0
# 100013                     0                 0                 0
# 100028                     0                 0                 0
# 100038                     0                 0                 0
#
#             FLAG_DOCUMENT_21  CNT_CHILDREN  CNT_FAM_MEMBERS  \
# SK_ID_CURR
# 100001                     0             0              2.0
# 100005                     0             0              2.0
# 100013                     0             0              2.0
# 100028                     0             2              4.0
# 100038                     0             1              3.0
#
#             HOUR_APPR_PROCESS_START  OBS_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100001                           18                       0.0
# 100005                            9                       0.0
# 100013                           14                       0.0
# 100028                           11                       0.0
# 100038                            5                       0.0
#
#             DEF_30_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100001                           0.0                       0.0
# 100005                           0.0                       0.0
# 100013                           0.0                       0.0
# 100028                           0.0                       0.0
# 100038                           0.0                       0.0
#
#             DEF_60_CNT_SOCIAL_CIRCLE  AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100001                           0.0                         0.0
# 100005                           0.0                         0.0
# 100013                           0.0                         0.0
# 100028                           0.0                         0.0
# 100038                           0.0                         NaN
#
#             AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# SK_ID_CURR
# 100001                            0.0                         0.0
# 100005                            0.0                         0.0
# 100013                            0.0                         0.0
# 100028                            0.0                         0.0
# 100038                            NaN                         NaN
#
#             AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# SK_ID_CURR
# 100001                            0.0                        0.0
# 100005                            0.0                        0.0
# 100013                            0.0                        1.0
# 100028                            0.0                        0.0
# 100038                            NaN                        NaN
#
#             AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR
# 100001                             0.0
# 100005                             3.0
# 100013                             4.0
# 100028                             3.0
# 100038                             NaN

# %% [markdown]
# ### Transformation von Kategorien in numerische Werte

# %%
# transformiert kategorische variablen in integer
HEADS = [head for head in df.columns.values if df[head].dtype == "object"]

for head in HEADS:
    df[head], cats = pd.factorize(df[head])

# %%
df = df.add_prefix("A_")

# %% [markdown]
# ### Ergebnis

# %%
df.head()
# Out:
#             A_NAME_CONTRACT_TYPE  A_CODE_GENDER  A_FLAG_OWN_CAR  \
# SK_ID_CURR
# 100001                         0              0               0
# 100005                         0              1               0
# 100013                         0              1               1
# 100028                         0              0               0
# 100038                         0              1               1
#
#             A_FLAG_OWN_REALTY  A_NAME_TYPE_SUITE  A_NAME_INCOME_TYPE  \
# SK_ID_CURR
# 100001                      0                  0                   0
# 100005                      0                  0                   0
# 100013                      0                 -1                   0
# 100028                      0                  0                   0
# 100038                      1                  0                   0
#
#             A_NAME_EDUCATION_TYPE  A_NAME_FAMILY_STATUS  A_NAME_HOUSING_TYPE  \
# SK_ID_CURR
# 100001                          0                     0                    0
# 100005                          1                     0                    0
# 100013                          0                     0                    0
# 100028                          1                     0                    0
# 100038                          1                     0                    0
#
#             A_FLAG_MOBIL  A_FLAG_EMP_PHONE  A_FLAG_WORK_PHONE  \
# SK_ID_CURR
# 100001                 1                 1                  0
# 100005                 1                 1                  0
# 100013                 1                 1                  0
# 100028                 1                 1                  0
# 100038                 1                 1                  1
#
#             A_FLAG_CONT_MOBILE  A_FLAG_PHONE  A_FLAG_EMAIL  A_OCCUPATION_TYPE  \
# SK_ID_CURR
# 100001                       1             0             1                 -1
# 100005                       1             0             0                  0
# 100013                       1             0             0                  1
# 100028                       1             1             0                  2
# 100038                       1             0             0                 -1
#
#             A_REGION_RATING_CLIENT  A_REGION_RATING_CLIENT_W_CITY  \
# SK_ID_CURR
# 100001                           2                              2
# 100005                           2                              2
# 100013                           2                              2
# 100028                           2                              2
# 100038                           2                              2
#
#             A_WEEKDAY_APPR_PROCESS_START  A_REG_REGION_NOT_LIVE_REGION  \
# SK_ID_CURR
# 100001                                 0                             0
# 100005                                 1                             0
# 100013                                 2                             0
# 100028                                 3                             0
# 100038                                 1                             0
#
#             A_REG_REGION_NOT_WORK_REGION  A_LIVE_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100001                                 0                              0
# 100005                                 0                              0
# 100013                                 0                              0
# 100028                                 0                              0
# 100038                                 0                              0
#
#             A_REG_CITY_NOT_LIVE_CITY  A_REG_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100001                             0                         0
# 100005                             0                         0
# 100013                             0                         0
# 100028                             0                         0
# 100038                             0                         1
#
#             A_LIVE_CITY_NOT_WORK_CITY  A_ORGANIZATION_TYPE  \
# SK_ID_CURR
# 100001                              0                    0
# 100005                              0                    1
# 100013                              0                    2
# 100028                              0                    3
# 100038                              1                    3
#
#             A_FONDKAPREMONT_MODE  A_HOUSETYPE_MODE  A_WALLSMATERIAL_MODE  \
# SK_ID_CURR
# 100001                        -1                 0                     0
# 100005                        -1                -1                    -1
# 100013                        -1                -1                    -1
# 100028                         0                 0                     1
# 100038                        -1                -1                    -1
#
#             A_EMERGENCYSTATE_MODE  A_FLAG_DOCUMENT_2  A_FLAG_DOCUMENT_3  \
# SK_ID_CURR
# 100001                          0                  0                  1
# 100005                         -1                  0                  1
# 100013                         -1                  0                  0
# 100028                          0                  0                  1
# 100038                         -1                  0                  1
#
#             A_FLAG_DOCUMENT_4  A_FLAG_DOCUMENT_5  A_FLAG_DOCUMENT_6  \
# SK_ID_CURR
# 100001                      0                  0                  0
# 100005                      0                  0                  0
# 100013                      0                  0                  0
# 100028                      0                  0                  0
# 100038                      0                  0                  0
#
#             A_FLAG_DOCUMENT_7  A_FLAG_DOCUMENT_8  A_FLAG_DOCUMENT_9  \
# SK_ID_CURR
# 100001                      0                  0                  0
# 100005                      0                  0                  0
# 100013                      0                  1                  0
# 100028                      0                  0                  0
# 100038                      0                  0                  0
#
#             A_FLAG_DOCUMENT_10  A_FLAG_DOCUMENT_11  A_FLAG_DOCUMENT_12  \
# SK_ID_CURR
# 100001                       0                   0                   0
# 100005                       0                   0                   0
# 100013                       0                   0                   0
# 100028                       0                   0                   0
# 100038                       0                   0                   0
#
#             A_FLAG_DOCUMENT_13  A_FLAG_DOCUMENT_14  A_FLAG_DOCUMENT_15  \
# SK_ID_CURR
# 100001                       0                   0                   0
# 100005                       0                   0                   0
# 100013                       0                   0                   0
# 100028                       0                   0                   0
# 100038                       0                   0                   0
#
#             A_FLAG_DOCUMENT_16  A_FLAG_DOCUMENT_17  A_FLAG_DOCUMENT_18  \
# SK_ID_CURR
# 100001                       0                   0                   0
# 100005                       0                   0                   0
# 100013                       0                   0                   0
# 100028                       0                   0                   0
# 100038                       0                   0                   0
#
#             A_FLAG_DOCUMENT_19  A_FLAG_DOCUMENT_20  A_FLAG_DOCUMENT_21  \
# SK_ID_CURR
# 100001                       0                   0                   0
# 100005                       0                   0                   0
# 100013                       0                   0                   0
# 100028                       0                   0                   0
# 100038                       0                   0                   0
#
#             A_CNT_CHILDREN  A_CNT_FAM_MEMBERS  A_HOUR_APPR_PROCESS_START  \
# SK_ID_CURR
# 100001                   0                2.0                         18
# 100005                   0                2.0                          9
# 100013                   0                2.0                         14
# 100028                   2                4.0                         11
# 100038                   1                3.0                          5
#
#             A_OBS_30_CNT_SOCIAL_CIRCLE  A_DEF_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100001                             0.0                         0.0
# 100005                             0.0                         0.0
# 100013                             0.0                         0.0
# 100028                             0.0                         0.0
# 100038                             0.0                         0.0
#
#             A_OBS_60_CNT_SOCIAL_CIRCLE  A_DEF_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100001                             0.0                         0.0
# 100005                             0.0                         0.0
# 100013                             0.0                         0.0
# 100028                             0.0                         0.0
# 100038                             0.0                         0.0
#
#             A_AMT_REQ_CREDIT_BUREAU_HOUR  A_AMT_REQ_CREDIT_BUREAU_DAY  \
# SK_ID_CURR
# 100001                               0.0                          0.0
# 100005                               0.0                          0.0
# 100013                               0.0                          0.0
# 100028                               0.0                          0.0
# 100038                               NaN                          NaN
#
#             A_AMT_REQ_CREDIT_BUREAU_WEEK  A_AMT_REQ_CREDIT_BUREAU_MON  \
# SK_ID_CURR
# 100001                               0.0                          0.0
# 100005                               0.0                          0.0
# 100013                               0.0                          0.0
# 100028                               0.0                          0.0
# 100038                               NaN                          NaN
#
#             A_AMT_REQ_CREDIT_BUREAU_QRT  A_AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR
# 100001                              0.0                           0.0
# 100005                              0.0                           3.0
# 100013                              1.0                           4.0
# 100028                              0.0                           3.0
# 100038                              NaN                           NaN

# %%
cats = df

# %% [markdown]
# ## <u>metrische Variablen

# %%
df = app_test[m_heads].copy()

# %%
df.head()
# Out:
#             AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# SK_ID_CURR
# 100001              135000.0    568800.0      20560.5         450000.0
# 100005               99000.0    222768.0      17370.0         180000.0
# 100013              202500.0    663264.0      69777.0         630000.0
# 100028              315000.0   1575000.0      49018.5        1575000.0
# 100038              180000.0    625500.0      32067.0         625500.0
#
#             REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# SK_ID_CURR
# 100001                        0.018850      -19241          -2329
# 100005                        0.035792      -18064          -4469
# 100013                        0.019101      -20038          -4458
# 100028                        0.026392      -13976          -1866
# 100038                        0.010032      -13040          -2191
#
#             DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  EXT_SOURCE_1  \
# SK_ID_CURR
# 100001                -5170.0             -812          NaN      0.752614
# 100005                -9118.0            -1623          NaN      0.564990
# 100013                -2175.0            -3503          5.0           NaN
# 100028                -2000.0            -4208          NaN      0.525734
# 100038                -4000.0            -4262         16.0      0.202145
#
#             EXT_SOURCE_2  EXT_SOURCE_3  APARTMENTS_AVG  BASEMENTAREA_AVG  \
# SK_ID_CURR
# 100001          0.789654      0.159520          0.0660            0.0590
# 100005          0.291656      0.432962             NaN               NaN
# 100013          0.699787      0.610991             NaN               NaN
# 100028          0.509677      0.612704          0.3052            0.1974
# 100038          0.425687           NaN             NaN               NaN
#
#             YEARS_BEGINEXPLUATATION_AVG  YEARS_BUILD_AVG  COMMONAREA_AVG  \
# SK_ID_CURR
# 100001                           0.9732              NaN             NaN
# 100005                              NaN              NaN             NaN
# 100013                              NaN              NaN             NaN
# 100028                           0.9970           0.9592          0.1165
# 100038                              NaN              NaN             NaN
#
#             ELEVATORS_AVG  ENTRANCES_AVG  FLOORSMAX_AVG  FLOORSMIN_AVG  \
# SK_ID_CURR
# 100001                NaN         0.1379          0.125            NaN
# 100005                NaN            NaN            NaN            NaN
# 100013                NaN            NaN            NaN            NaN
# 100028               0.32         0.2759          0.375         0.0417
# 100038                NaN            NaN            NaN            NaN
#
#             LANDAREA_AVG  LIVINGAPARTMENTS_AVG  LIVINGAREA_AVG  \
# SK_ID_CURR
# 100001               NaN                   NaN          0.0505
# 100005               NaN                   NaN             NaN
# 100013               NaN                   NaN             NaN
# 100028            0.2042                0.2404          0.3673
# 100038               NaN                   NaN             NaN
#
#             NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  APARTMENTS_MODE  \
# SK_ID_CURR
# 100001                          NaN                NaN           0.0672
# 100005                          NaN                NaN              NaN
# 100013                          NaN                NaN              NaN
# 100028                       0.0386               0.08           0.3109
# 100038                          NaN                NaN              NaN
#
#             BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  YEARS_BUILD_MODE  \
# SK_ID_CURR
# 100001                 0.0612                        0.9732               NaN
# 100005                    NaN                           NaN               NaN
# 100013                    NaN                           NaN               NaN
# 100028                 0.2049                        0.9970            0.9608
# 100038                    NaN                           NaN               NaN
#
#             COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  FLOORSMAX_MODE  \
# SK_ID_CURR
# 100001                  NaN             NaN          0.1379           0.125
# 100005                  NaN             NaN             NaN             NaN
# 100013                  NaN             NaN             NaN             NaN
# 100028               0.1176          0.3222          0.2759           0.375
# 100038                  NaN             NaN             NaN             NaN
#
#             FLOORSMIN_MODE  LANDAREA_MODE  LIVINGAPARTMENTS_MODE  \
# SK_ID_CURR
# 100001                 NaN            NaN                    NaN
# 100005                 NaN            NaN                    NaN
# 100013                 NaN            NaN                    NaN
# 100028              0.0417         0.2089                 0.2626
# 100038                 NaN            NaN                    NaN
#
#             LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_MODE  \
# SK_ID_CURR
# 100001               0.0526                       NaN                 NaN
# 100005                  NaN                       NaN                 NaN
# 100013                  NaN                       NaN                 NaN
# 100028               0.3827                    0.0389              0.0847
# 100038                  NaN                       NaN                 NaN
#
#             APARTMENTS_MEDI  BASEMENTAREA_MEDI  YEARS_BEGINEXPLUATATION_MEDI  \
# SK_ID_CURR
# 100001               0.0666             0.0590                        0.9732
# 100005                  NaN                NaN                           NaN
# 100013                  NaN                NaN                           NaN
# 100028               0.3081             0.1974                        0.9970
# 100038                  NaN                NaN                           NaN
#
#             YEARS_BUILD_MEDI  COMMONAREA_MEDI  ELEVATORS_MEDI  ENTRANCES_MEDI  \
# SK_ID_CURR
# 100001                   NaN              NaN             NaN          0.1379
# 100005                   NaN              NaN             NaN             NaN
# 100013                   NaN              NaN             NaN             NaN
# 100028                0.9597           0.1173            0.32          0.2759
# 100038                   NaN              NaN             NaN             NaN
#
#             FLOORSMAX_MEDI  FLOORSMIN_MEDI  LANDAREA_MEDI  \
# SK_ID_CURR
# 100001               0.125             NaN            NaN
# 100005                 NaN             NaN            NaN
# 100013                 NaN             NaN            NaN
# 100028               0.375          0.0417         0.2078
# 100038                 NaN             NaN            NaN
#
#             LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  NONLIVINGAPARTMENTS_MEDI  \
# SK_ID_CURR
# 100001                        NaN           0.0514                       NaN
# 100005                        NaN              NaN                       NaN
# 100013                        NaN              NaN                       NaN
# 100028                     0.2446           0.3739                    0.0388
# 100038                        NaN              NaN                       NaN
#
#             NONLIVINGAREA_MEDI  TOTALAREA_MODE  DAYS_LAST_PHONE_CHANGE
# SK_ID_CURR
# 100001                     NaN          0.0392                 -1740.0
# 100005                     NaN             NaN                     0.0
# 100013                     NaN             NaN                  -856.0
# 100028                  0.0817          0.3700                 -1805.0
# 100038                     NaN             NaN                  -821.0

# %%
df["CREDIT/INCOME"] = df["AMT_CREDIT"] / df["AMT_INCOME_TOTAL"]

# %% [markdown]
# ### Ergebnis

# %%
print(df.columns.values)
# Out:
# ['AMT_INCOME_TOTAL' 'AMT_CREDIT' 'AMT_ANNUITY' 'AMT_GOODS_PRICE'
#  'REGION_POPULATION_RELATIVE' 'DAYS_BIRTH' 'DAYS_EMPLOYED'
#  'DAYS_REGISTRATION' 'DAYS_ID_PUBLISH' 'OWN_CAR_AGE' 'EXT_SOURCE_1'
#  'EXT_SOURCE_2' 'EXT_SOURCE_3' 'APARTMENTS_AVG' 'BASEMENTAREA_AVG'
#  'YEARS_BEGINEXPLUATATION_AVG' 'YEARS_BUILD_AVG' 'COMMONAREA_AVG'
#  'ELEVATORS_AVG' 'ENTRANCES_AVG' 'FLOORSMAX_AVG' 'FLOORSMIN_AVG'
#  'LANDAREA_AVG' 'LIVINGAPARTMENTS_AVG' 'LIVINGAREA_AVG'
#  'NONLIVINGAPARTMENTS_AVG' 'NONLIVINGAREA_AVG' 'APARTMENTS_MODE'
#  'BASEMENTAREA_MODE' 'YEARS_BEGINEXPLUATATION_MODE' 'YEARS_BUILD_MODE'
#  'COMMONAREA_MODE' 'ELEVATORS_MODE' 'ENTRANCES_MODE' 'FLOORSMAX_MODE'
#  'FLOORSMIN_MODE' 'LANDAREA_MODE' 'LIVINGAPARTMENTS_MODE'
#  'LIVINGAREA_MODE' 'NONLIVINGAPARTMENTS_MODE' 'NONLIVINGAREA_MODE'
#  'APARTMENTS_MEDI' 'BASEMENTAREA_MEDI' 'YEARS_BEGINEXPLUATATION_MEDI'
#  'YEARS_BUILD_MEDI' 'COMMONAREA_MEDI' 'ELEVATORS_MEDI' 'ENTRANCES_MEDI'
#  'FLOORSMAX_MEDI' 'FLOORSMIN_MEDI' 'LANDAREA_MEDI' 'LIVINGAPARTMENTS_MEDI'
#  'LIVINGAREA_MEDI' 'NONLIVINGAPARTMENTS_MEDI' 'NONLIVINGAREA_MEDI'
#  'TOTALAREA_MODE' 'DAYS_LAST_PHONE_CHANGE' 'CREDIT/INCOME']

# %%
df = df.add_prefix("A_")

# %%
# Header abgleich

# %% [markdown]
# ### Speichern der Ergebnisse

# %%
df = pd.merge(cats, df, left_index=True, right_index=True)

# %%
df = df[app_train.columns[1:]]

# %%
df.head()
# Out:
#             A_CODE_GENDER  A_NAME_INCOME_TYPE  A_NAME_EDUCATION_TYPE  \
# SK_ID_CURR
# 100001                  0                   0                      0
# 100005                  1                   0                      1
# 100013                  1                   0                      0
# 100028                  0                   0                      1
# 100038                  1                   0                      1
#
#             A_FLAG_EMP_PHONE  A_OCCUPATION_TYPE  A_REGION_RATING_CLIENT  \
# SK_ID_CURR
# 100001                     1                 -1                       2
# 100005                     1                  0                       2
# 100013                     1                  1                       2
# 100028                     1                  2                       2
# 100038                     1                 -1                       2
#
#             A_REG_CITY_NOT_WORK_CITY  A_ORGANIZATION_TYPE  A_FLAG_DOCUMENT_3  \
# SK_ID_CURR
# 100001                             0                    0                  1
# 100005                             0                    1                  1
# 100013                             0                    2                  0
# 100028                             0                    3                  1
# 100038                             1                    3                  1
#
#             A_CNT_CHILDREN  A_OBS_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100001                   0                         0.0
# 100005                   0                         0.0
# 100013                   0                         0.0
# 100028                   2                         0.0
# 100038                   1                         0.0
#
#             A_DEF_60_CNT_SOCIAL_CIRCLE  A_AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100001                             0.0                           0.0
# 100005                             0.0                           0.0
# 100013                             0.0                           0.0
# 100028                             0.0                           0.0
# 100038                             0.0                           NaN
#
#             A_AMT_REQ_CREDIT_BUREAU_DAY  A_AMT_REQ_CREDIT_BUREAU_WEEK  \
# SK_ID_CURR
# 100001                              0.0                           0.0
# 100005                              0.0                           0.0
# 100013                              0.0                           0.0
# 100028                              0.0                           0.0
# 100038                              NaN                           NaN
#
#             A_AMT_REQ_CREDIT_BUREAU_MON  A_AMT_REQ_CREDIT_BUREAU_QRT  \
# SK_ID_CURR
# 100001                              0.0                          0.0
# 100005                              0.0                          0.0
# 100013                              0.0                          1.0
# 100028                              0.0                          0.0
# 100038                              NaN                          NaN
#
#             A_AMT_REQ_CREDIT_BUREAU_YEAR  A_AMT_INCOME_TOTAL  A_AMT_CREDIT  \
# SK_ID_CURR
# 100001                               0.0            135000.0      568800.0
# 100005                               3.0             99000.0      222768.0
# 100013                               4.0            202500.0      663264.0
# 100028                               3.0            315000.0     1575000.0
# 100038                               NaN            180000.0      625500.0
#
#             A_AMT_ANNUITY  A_REGION_POPULATION_RELATIVE  A_DAYS_BIRTH  \
# SK_ID_CURR
# 100001            20560.5                      0.018850        -19241
# 100005            17370.0                      0.035792        -18064
# 100013            69777.0                      0.019101        -20038
# 100028            49018.5                      0.026392        -13976
# 100038            32067.0                      0.010032        -13040
#
#             A_DAYS_EMPLOYED  A_DAYS_REGISTRATION  A_DAYS_ID_PUBLISH  \
# SK_ID_CURR
# 100001                -2329              -5170.0               -812
# 100005                -4469              -9118.0              -1623
# 100013                -4458              -2175.0              -3503
# 100028                -1866              -2000.0              -4208
# 100038                -2191              -4000.0              -4262
#
#             A_EXT_SOURCE_1  A_EXT_SOURCE_2  A_EXT_SOURCE_3  \
# SK_ID_CURR
# 100001            0.752614        0.789654        0.159520
# 100005            0.564990        0.291656        0.432962
# 100013                 NaN        0.699787        0.610991
# 100028            0.525734        0.509677        0.612704
# 100038            0.202145        0.425687             NaN
#
#             A_BASEMENTAREA_AVG  A_YEARS_BEGINEXPLUATATION_AVG  A_LANDAREA_AVG  \
# SK_ID_CURR
# 100001                  0.0590                         0.9732             NaN
# 100005                     NaN                            NaN             NaN
# 100013                     NaN                            NaN             NaN
# 100028                  0.1974                         0.9970          0.2042
# 100038                     NaN                            NaN             NaN
#
#             A_NONLIVINGAREA_AVG  A_TOTALAREA_MODE  A_CREDIT/INCOME
# SK_ID_CURR
# 100001                      NaN            0.0392         4.213333
# 100005                      NaN               NaN         2.250182
# 100013                      NaN               NaN         3.275378
# 100028                     0.08            0.3700         5.000000
# 100038                      NaN               NaN         3.475000

# %%
df.to_csv(DATASET_DIR / "2. Datenaufbereitung" / "app_test.csv")
