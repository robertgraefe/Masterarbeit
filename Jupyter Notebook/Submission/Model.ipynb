# %%
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score

from sklearn.model_selection import KFold
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import auc

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

from IPython.display import clear_output

import json

import warnings

from sklearn import preprocessing

# %%
# Random Forest
TREE_PARAMS = {
    "random_state" : 0,
    "max_depth": 7,
    "n_jobs" : -1
}

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
app_train = pd.read_csv(DATASET_DIR / "4. FillNA" / "application.csv")
bureau = pd.read_csv(DATASET_DIR / "4. FillNA" / "bureau.csv")
pa_pos = pd.read_csv(DATASET_DIR / "4. FillNA" / "pa_pos.csv")
pa_ip = pd.read_csv(DATASET_DIR / "4. FillNA" / "pa_ip.csv")
pa_cc = pd.read_csv(DATASET_DIR / "4. FillNA" / "pa_cc.csv")

# %%
app_train = app_train.set_index("SK_ID_CURR")
bureau = bureau.set_index("SK_ID_CURR")
pa_pos = pa_pos.set_index("SK_ID_CURR")
pa_ip = pa_ip.set_index("SK_ID_CURR")
pa_cc = pa_cc.set_index("SK_ID_CURR")

# %%
MODEL_APPLICATION = "3.1. Esembler_RandomForest_Application.json"
MODEL_BUREAU = "3.2. Esembler_RandomForest_bureau.json"
MODEL_PA_POS = "3.3. Esembler_RandomForest_pa_pos.json"
MODEL_PA_IP = "3.4. Esembler_RandomForest_pa_ip.json"
MODEL_PA_CC = "3.5. Esembler_RandomForest_pa_cc.json"

# %%
with open(DATASET_DIR / "Models" / MODEL_APPLICATION, 'r') as file:
    model_application_data = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_BUREAU, 'r') as file:
    model_bureau_data = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_POS, 'r') as file:
    model_pa_pos_data = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_IP, 'r') as file:
    model_pa_ip_data = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_CC, 'r') as file:
    model_pa_cc_data = json.load(file)

# %%
print(len(model_application_data["keep"]))
print(len(model_bureau_data["keep"]))
print(len(model_pa_pos_data["keep"]))
print(len(model_pa_ip_data["keep"]))
print(len(model_pa_cc_data["keep"]))
# Out:
# 10
# 7
# 17
# 27
# 21

# %%
model_application = RandomForestClassifier(**model_application_data["params"])
model_bureau = RandomForestClassifier(**TREE_PARAMS)
model_pa_pos = RandomForestClassifier(**TREE_PARAMS)
model_pa_ip = RandomForestClassifier(**TREE_PARAMS)
model_pa_cc = RandomForestClassifier(**TREE_PARAMS)

# %%
df = app_train[["TARGET"]]
df.head()
# Out:
#             TARGET
# SK_ID_CURR
# 100002         1.0
# 100003         0.0
# 100004         0.0
# 100006         0.0
# 100007         0.0

# %%
# application prediction

# %%
x = app_train[model_application_data["keep"]]
x.head()
# Out:
#             A_EXT_SOURCE_3  A_EXT_SOURCE_1  A_EXT_SOURCE_2  \
# SK_ID_CURR
# 100002            0.139376        0.083037        0.262949
# 100003            0.344844        0.311267        0.622246
# 100004            0.729567        0.550824        0.555912
# 100006            0.565898        0.666039        0.650442
# 100007            0.571390        0.559619        0.322738
#
#             A_AMT_REQ_CREDIT_BUREAU_DAY  A_AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100002                         0.000000                      0.000000
# 100003                         0.000000                      0.000000
# 100004                         0.000000                      0.000000
# 100006                         0.005653                      0.008068
# 100007                         0.000000                      0.000000
#
#             A_YEARS_BEGINEXPLUATATION_AVG  A_DAYS_EMPLOYED  A_DAYS_BIRTH  \
# SK_ID_CURR
# 100002                           0.972200           -637.0       -9461.0
# 100003                           0.985100          -1188.0      -16765.0
# 100004                           0.981667           -225.0      -19046.0
# 100006                           0.979744          -3039.0      -19005.0
# 100007                           0.982023          -3038.0      -19932.0
#
#             A_BASEMENTAREA_AVG  A_LANDAREA_AVG
# SK_ID_CURR
# 100002                0.036900        0.036900
# 100003                0.052900        0.013000
# 100004                0.075009        0.067504
# 100006                0.076735        0.068598
# 100007                0.071043        0.048938

# %%
y = app_train.loc[app_train.index]["TARGET"]
y.head()
# Out:
# SK_ID_CURR
# 100002    1.0
# 100003    0.0
# 100004    0.0
# 100006    0.0
# 100007    0.0
# Name: TARGET, dtype: float64

# %%
model_application.fit(x,y)
# Out:
# RandomForestClassifier(max_depth=15, max_features=5, min_samples_leaf=12,
#                        n_estimators=900, n_jobs=-1, random_state=0)

# %%
predicted = pd.DataFrame(model_application.predict_proba(x), index=app_train.index)
predicted.columns = ["A_PAYBACK", "A_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT
# SK_ID_CURR
# 100002         1.0   0.411870   0.588130
# 100003         0.0   0.854116   0.145884
# 100004         0.0   0.974147   0.025853
# 100006         0.0   0.998703   0.001297
# 100007         0.0   0.934973   0.065027

# %%
# bureau prediction

# %%
x = bureau[model_bureau_data["keep"]]
x.head()
# Out:
#             B_Active  B_Closed  B_AMT_CREDIT_SUM  B_AMT_CREDIT_SUM_DEBT  \
# SK_ID_CURR
# 100002           2.0       6.0     638235.000000          245781.000000
# 100003           1.0       3.0     810000.000000               0.000000
# 100004           0.0       2.0     792471.023437          353526.556281
# 100007           0.0       1.0     635755.340213          291016.898931
# 100008           1.0       2.0     267606.000000          240057.000000
#
#             B_DAYS_CREDIT_ENDDATE  B_AMT_CREDIT_SUM_OVERDUE  B_AMT_ANNUITY
# SK_ID_CURR
# 100002                 309.000000                  0.000000       0.000000
# 100003                1216.000000                  0.000000       0.000000
# 100004                1172.145688                  0.001962    2735.621154
# 100007                1163.754146                  0.002387    2634.913696
# 100008                 471.000000                  0.000000       0.000000

# %%
y = app_train.loc[bureau.index]["TARGET"]
y.head()
# Out:
# SK_ID_CURR
# 100002    1.0
# 100003    0.0
# 100004    0.0
# 100007    0.0
# 100008    0.0
# Name: TARGET, dtype: float64

# %%
model_bureau.fit(x,y)
# Out:
# RandomForestClassifier(max_depth=7, n_jobs=-1, random_state=0)

# %%
predicted = pd.DataFrame(model_bureau.predict_proba(x), index=bureau.index)
predicted.columns = ["B_PAYBACK", "B_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT
# SK_ID_CURR
# 100002         1.0   0.411870   0.588130   0.939494   0.060506
# 100003         0.0   0.854116   0.145884   0.950200   0.049800
# 100004         0.0   0.974147   0.025853   0.940761   0.059239
# 100006         0.0   0.998703   0.001297        NaN        NaN
# 100007         0.0   0.934973   0.065027   0.929543   0.070457

# %%
# pa_pos prediction

# %%
x = pa_pos[model_pa_pos_data["keep"]]
x.head()
# Out:
#             PA_CNT_NAME_CONTRACT_STATUS_Refused  PA_AMT_ANNUITY  \
# SK_ID_CURR
# 158271                                      0.0        6404.310
# 252457                                      0.0        4951.350
# 260094                                      1.0       97839.945
# 176456                                      0.0       14713.605
# 256657                                      7.0       60139.575
#
#             PA_AMT_GOODS_PRICE  PA_AMT_DOWN_PAYMENT  \
# SK_ID_CURR
# 158271               58905.000                0.000
# 252457               47056.275                4.275
# 260094             2023469.370             8765.370
# 176456              123486.075            12349.575
# 256657             1115806.500            78714.000
#
#             PA_CNT_NAME_PRODUCT_TYPE_walk-in  PA_POS_CNT_DPD  PA_AMT_CREDIT  \
# SK_ID_CURR
# 158271                                   0.0             0.0        65124.0
# 252457                                   1.0             0.0        52641.0
# 260094                                   1.0             0.0      2294779.5
# 176456                                   0.0             0.0       120307.5
# 256657                                   5.0             0.0      1277523.0
#
#             PA_RATE_DOWN_PAYMENT  PA_CNT_NAME_YIELD_GROUP_high  \
# SK_ID_CURR
# 158271                  0.000000                           0.0
# 252457                  0.000088                           0.0
# 260094                  0.312513                           4.0
# 176456                  0.101388                           0.0
# 256657                  0.699443                           0.0
#
#             PA_POS_CNT_PAYMENTS_LEFT  PA_CNT_NAME_CLIENT_TYPE_New  \
# SK_ID_CURR
# 158271                           0.0                          1.0
# 252457                           9.0                          0.0
# 260094                          70.0                          1.0
# 176456                           0.0                          1.0
# 256657                          28.0                          1.0
#
#             PA_CNT_NAME_YIELD_GROUP_low_normal  \
# SK_ID_CURR
# 158271                                     0.0
# 252457                                     0.0
# 260094                                     3.0
# 176456                                     0.0
# 256657                                     2.0
#
#             PA_CNT_NAME_CONTRACT_TYPE_Revolving loans  PA_CNT_CREDITS  \
# SK_ID_CURR
# 158271                                            0.0             1.0
# 252457                                            1.0             1.0
# 260094                                            0.0             9.0
# 176456                                            0.0             1.0
# 256657                                            2.0             3.0
#
#             PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low  \
# SK_ID_CURR
# 158271                                              0.0
# 252457                                              0.0
# 260094                                              4.0
# 176456                                              0.0
# 256657                                              0.0
#
#             PA_CNT_NAME_CLIENT_TYPE_Refreshed  \
# SK_ID_CURR
# 158271                                    0.0
# 252457                                    2.0
# 260094                                    1.0
# 176456                                    0.0
# 256657                                    0.0
#
#             PA_CNT_PRODUCT_COMBINATION_POS industry with interest
# SK_ID_CURR
# 158271                                                        1.0
# 252457                                                        0.0
# 260094                                                        0.0
# 176456                                                        1.0
# 256657                                                        0.0

# %%
y = app_train.loc[pa_pos.index]["TARGET"]
y.head()
# Out:
# SK_ID_CURR
# 158271    0.0
# 252457    0.0
# 260094    0.0
# 176456    0.0
# 256657    0.0
# Name: TARGET, dtype: float64

# %%
model_pa_pos.fit(x,y)
# Out:
# RandomForestClassifier(max_depth=7, n_jobs=-1, random_state=0)

# %%
predicted = pd.DataFrame(model_pa_pos.predict_proba(x), index=pa_pos.index)
predicted.columns = ["PA_POS_PAYBACK", "PA_POS_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  \
# SK_ID_CURR
# 100002         1.0   0.411870   0.588130   0.939494   0.060506
# 100003         0.0   0.854116   0.145884   0.950200   0.049800
# 100004         0.0   0.974147   0.025853   0.940761   0.059239
# 100006         0.0   0.998703   0.001297        NaN        NaN
# 100007         0.0   0.934973   0.065027   0.929543   0.070457
#
#             PA_POS_PAYBACK  PA_POS_DEFAULT
# SK_ID_CURR
# 100002            0.923838        0.076162
# 100003            0.955988        0.044012
# 100004            0.900602        0.099398
# 100006            0.948088        0.051912
# 100007            0.922725        0.077275

# %%
# pa_ip prediction

# %%
x = pa_ip[model_pa_ip_data["keep"]]
x.head()
# Out:
#             PA_CNT_NAME_PRODUCT_TYPE_walk-in  PA_IP_DAYS_DIFF_60  \
# SK_ID_CURR
# 252457                                   1.0               -15.0
# 256657                                   5.0               -13.0
# 198678                                   0.0               -21.5
# 394447                                   1.0                -7.0
# 156331                                   0.0                 0.0
#
#             PA_CNT_NAME_CONTRACT_STATUS_Refused  PA_IP_DAYS_DIFF_30  \
# SK_ID_CURR
# 252457                                      0.0                 0.0
# 256657                                      7.0                -6.0
# 198678                                      0.0               -20.0
# 394447                                      0.0                -0.5
# 156331                                      0.0                 0.0
#
#             PA_AMT_ANNUITY  PA_IP_DAYS_DIFF_120  PA_IP_DAYS_DIFF_90  \
# SK_ID_CURR
# 252457            4951.350                -14.0               -17.0
# 256657           49054.770                -12.5               -12.0
# 198678           98806.050                 -1.0                -6.5
# 394447           17141.445                 -6.5                -7.0
# 156331           40866.795                 -1.0                 0.0
#
#             PA_IP_DAYS_DIFF_180  PA_AMT_CREDIT  PA_IP_PAYMENT_180  \
# SK_ID_CURR
# 252457                      0.0        52641.0          -0.912871
# 256657                     -1.5      1198062.0          -1.020621
# 198678                     -0.5       941661.0           0.000204
# 394447                      0.0       129132.0          -0.412932
# 156331                     -5.0       793035.0           0.616385
#
#             PA_AMT_APPLICATION  PA_IP_AMT_DIFF_60  PA_IP_AMT_DIFF_30  \
# SK_ID_CURR
# 252457               47056.275                0.0                0.0
# 256657              978570.000                0.0                0.0
# 198678              921721.500                0.0                0.0
# 394447              129132.000                0.0                0.0
# 156331              793035.000                0.0                0.0
#
#             PA_IP_DAYS_DIFF_150  PA_CNT_NAME_YIELD_GROUP_low_normal  \
# SK_ID_CURR
# 252457                      0.0                                 0.0
# 256657                    -13.0                                 2.0
# 198678                      0.5                                 0.0
# 394447                     -8.5                                 0.0
# 156331                    -12.5                                 1.0
#
#             PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low  PA_IP_PAYMENT_60  \
# SK_ID_CURR
# 252457                                              0.0      9.128709e-01
# 256657                                              0.0      2.041241e-01
# 198678                                              0.0      4.540312e-08
# 394447                                              0.0      6.115381e-01
# 156331                                              0.0      1.416426e-02
#
#             PA_IP_AMT_DIFF_180  PA_IP_AMT_DIFF_90  \
# SK_ID_CURR
# 252457                     0.0                0.0
# 256657                     0.0                0.0
# 198678                     0.0                0.0
# 394447                     0.0                0.0
# 156331                     0.0                0.0
#
#             PA_CNT_NAME_CONTRACT_TYPE_Revolving loans  PA_IP_AMT_DIFF_150  \
# SK_ID_CURR
# 252457                                            1.0                 0.0
# 256657                                            2.0                 0.0
# 198678                                            0.0                 0.0
# 394447                                            1.0                 0.0
# 156331                                            2.0                 0.0
#
#             PA_CNT_NAME_CLIENT_TYPE_New  PA_CNT_NAME_YIELD_GROUP_high  \
# SK_ID_CURR
# 252457                              0.0                           0.0
# 256657                              1.0                           0.0
# 198678                              1.0                           0.0
# 394447                              2.0                           0.0
# 156331                              1.0                           3.0
#
#             PA_CNT_NAME_PORTFOLIO_Cards  PA_CNT_NAME_CLIENT_TYPE_Refreshed  \
# SK_ID_CURR
# 252457                              1.0                                2.0
# 256657                              2.0                                0.0
# 198678                              0.0                                0.0
# 394447                              1.0                                0.0
# 156331                              1.0                                0.0
#
#             PA_CNT_PRODUCT_COMBINATION_POS industry with interest  \
# SK_ID_CURR
# 252457                                                        0.0
# 256657                                                        0.0
# 198678                                                        0.0
# 394447                                                        0.0
# 156331                                                        0.0
#
#             PA_RATE_DOWN_PAYMENT
# SK_ID_CURR
# 252457                  0.000088
# 256657                  0.217818
# 198678                  0.193358
# 394447                  0.000000
# 156331                  0.000000

# %%
y = app_train.loc[pa_ip.index]["TARGET"]
y.head()
# Out:
# SK_ID_CURR
# 252457    0.0
# 256657    0.0
# 198678    0.0
# 394447    0.0
# 156331    0.0
# Name: TARGET, dtype: float64

# %%
model_pa_ip.fit(x,y)
# Out:
# RandomForestClassifier(max_depth=7, n_jobs=-1, random_state=0)

# %%
predicted = pd.DataFrame(model_pa_ip.predict_proba(x), index=pa_ip.index)
predicted.columns = ["PA_IP_PAYBACK", "PA_IP_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  \
# SK_ID_CURR
# 100002         1.0   0.411870   0.588130   0.939494   0.060506
# 100003         0.0   0.854116   0.145884   0.950200   0.049800
# 100004         0.0   0.974147   0.025853   0.940761   0.059239
# 100006         0.0   0.998703   0.001297        NaN        NaN
# 100007         0.0   0.934973   0.065027   0.929543   0.070457
#
#             PA_POS_PAYBACK  PA_POS_DEFAULT  PA_IP_PAYBACK  PA_IP_DEFAULT
# SK_ID_CURR
# 100002            0.923838        0.076162       0.934588       0.065412
# 100003            0.955988        0.044012            NaN            NaN
# 100004            0.900602        0.099398            NaN            NaN
# 100006            0.948088        0.051912       0.939385       0.060615
# 100007            0.922725        0.077275       0.912314       0.087686

# %%
# pa_cc prediction

# %%
x = pa_cc[model_pa_cc_data["keep"]]
x.head()
# Out:
#             PA_CC_BALANCE_60  PA_CC_BALANCE_30  PA_CC_BALANCE_90  \
# SK_ID_CURR
# 394447              1.434002         -1.206367          0.992963
# 361282              0.828945          0.946004          0.861611
# 436351              0.000000          0.000000          0.000000
# 181153              0.000000          0.000000          0.000000
# 309691              0.000000          0.000000          0.000000
#
#             PA_CC_BALANCE_180  PA_CC_BALANCE_120  \
# SK_ID_CURR
# 394447              -0.455389          -0.349513
# 361282              -1.169080          -0.393110
# 436351               0.000000           0.000000
# 181153               0.000000           0.000000
# 309691               0.000000           0.000000
#
#             PA_CNT_NAME_PRODUCT_TYPE_walk-in  PA_CC_PAYMENT_60  \
# SK_ID_CURR
# 394447                                   1.0          1.008387
# 361282                                   1.0          1.109609
# 436351                                   1.0          0.000000
# 181153                                   1.0          0.000000
# 309691                                   1.0          0.000000
#
#             PA_CC_PAYMENT_180  PA_CC_PAYMENT_120  \
# SK_ID_CURR
# 394447               1.318045          -0.292196
# 361282              -1.152838          -1.267179
# 436351               0.000000           0.000000
# 181153               0.000000           0.000000
# 309691               0.000000           0.000000
#
#             PA_CNT_NAME_CONTRACT_STATUS_Refused  PA_AMT_CREDIT  \
# SK_ID_CURR
# 394447                                      0.0        45000.0
# 361282                                      0.0        45000.0
# 436351                                      3.0        45000.0
# 181153                                      3.0        45000.0
# 309691                                      0.0        45000.0
#
#             PA_AMT_APPLICATION  PA_AMT_GOODS_PRICE  \
# SK_ID_CURR
# 394447                 45000.0             45000.0
# 361282                 45000.0             45000.0
# 436351                 45000.0             45000.0
# 181153                 45000.0             45000.0
# 309691                 45000.0             45000.0
#
#             PA_CNT_CODE_REJECT_REASON_HC  PA_CNT_NAME_YIELD_GROUP_high  \
# SK_ID_CURR
# 394447                               0.0                           0.0
# 361282                               0.0                           0.0
# 436351                               3.0                           2.0
# 181153                               0.0                           3.0
# 309691                               0.0                           1.0
#
#             PA_CNT_NAME_CLIENT_TYPE_New  \
# SK_ID_CURR
# 394447                              2.0
# 361282                              2.0
# 436351                              0.0
# 181153                              1.0
# 309691                              1.0
#
#             PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low  \
# SK_ID_CURR
# 394447                                              0.0
# 361282                                              0.0
# 436351                                              3.0
# 181153                                              0.0
# 309691                                              1.0
#
#             PA_CNT_NAME_YIELD_GROUP_low_normal  \
# SK_ID_CURR
# 394447                                     0.0
# 361282                                     1.0
# 436351                                     6.0
# 181153                                     1.0
# 309691                                     1.0
#
#             PA_CNT_NAME_CLIENT_TYPE_Refreshed  \
# SK_ID_CURR
# 394447                                    0.0
# 361282                                    0.0
# 436351                                    1.0
# 181153                                    1.0
# 309691                                    0.0
#
#             PA_CNT_PRODUCT_COMBINATION_POS industry with interest  \
# SK_ID_CURR
# 394447                                                        0.0
# 361282                                                        0.0
# 436351                                                        0.0
# 181153                                                        0.0
# 309691                                                        0.0
#
#             PA_CC_DPD_180
# SK_ID_CURR
# 394447                0.0
# 361282                0.0
# 436351                0.0
# 181153                0.0
# 309691                0.0

# %%
y = app_train.loc[pa_cc.index]["TARGET"]
y.head()
# Out:
# SK_ID_CURR
# 394447    0.0
# 361282    0.0
# 436351    0.0
# 181153    0.0
# 309691    0.0
# Name: TARGET, dtype: float64

# %%
model_pa_cc.fit(x,y)
# Out:
# RandomForestClassifier(max_depth=7, n_jobs=-1, random_state=0)

# %%
predicted = pd.DataFrame(model_pa_cc.predict_proba(x), index=pa_cc.index)
predicted.columns = ["PA_CC_PAYBACK", "PA_CC_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  \
# SK_ID_CURR
# 100002         1.0   0.411870   0.588130   0.939494   0.060506
# 100003         0.0   0.854116   0.145884   0.950200   0.049800
# 100004         0.0   0.974147   0.025853   0.940761   0.059239
# 100006         0.0   0.998703   0.001297        NaN        NaN
# 100007         0.0   0.934973   0.065027   0.929543   0.070457
#
#             PA_POS_PAYBACK  PA_POS_DEFAULT  PA_IP_PAYBACK  PA_IP_DEFAULT  \
# SK_ID_CURR
# 100002            0.923838        0.076162       0.934588       0.065412
# 100003            0.955988        0.044012            NaN            NaN
# 100004            0.900602        0.099398            NaN            NaN
# 100006            0.948088        0.051912       0.939385       0.060615
# 100007            0.922725        0.077275       0.912314       0.087686
#
#             PA_CC_PAYBACK  PA_CC_DEFAULT
# SK_ID_CURR
# 100002                NaN            NaN
# 100003                NaN            NaN
# 100004                NaN            NaN
# 100006           0.952863       0.047137
# 100007                NaN            NaN

# %%
df = df.fillna(0.5)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  \
# SK_ID_CURR
# 100002         1.0   0.411870   0.588130   0.939494   0.060506
# 100003         0.0   0.854116   0.145884   0.950200   0.049800
# 100004         0.0   0.974147   0.025853   0.940761   0.059239
# 100006         0.0   0.998703   0.001297   0.500000   0.500000
# 100007         0.0   0.934973   0.065027   0.929543   0.070457
#
#             PA_POS_PAYBACK  PA_POS_DEFAULT  PA_IP_PAYBACK  PA_IP_DEFAULT  \
# SK_ID_CURR
# 100002            0.923838        0.076162       0.934588       0.065412
# 100003            0.955988        0.044012       0.500000       0.500000
# 100004            0.900602        0.099398       0.500000       0.500000
# 100006            0.948088        0.051912       0.939385       0.060615
# 100007            0.922725        0.077275       0.912314       0.087686
#
#             PA_CC_PAYBACK  PA_CC_DEFAULT
# SK_ID_CURR
# 100002           0.500000       0.500000
# 100003           0.500000       0.500000
# 100004           0.500000       0.500000
# 100006           0.952863       0.047137
# 100007           0.500000       0.500000

# %%
# finales Modell

# %%
model = RandomForestClassifier(**TREE_PARAMS)

aucs = []

kfold = KFold(5, shuffle=True, random_state=1)
data = df

y = df["TARGET"]
x = df.drop(["TARGET"], axis=1)

for ID_TRAIN, ID_TEST in kfold.split(data):
    
    x_train = x.iloc[ID_TRAIN]
    y_train = y.iloc[ID_TRAIN]
    x_test = x.iloc[ID_TEST]
    y_test = y.iloc[ID_TEST]
    
    model.fit(x_train, y_train)
    auc = roc_auc_score(y_test, model.predict_proba(x_test)[:,1])
    aucs.append(auc)
    
    print('train: %s, test: %s, auc: %s' % (ID_TRAIN, ID_TEST, auc))

print("\n")
print("Durchschnitt: %.2f" % (np.mean(aucs)))
print("Standardabw.: %.2f" % (np.std(aucs)))
print("Varianz:      %.2f" % (np.var(aucs)))
# Out:
# train: [     0      2      3 ... 307508 307509 307510], test: [     1      4      6 ... 307493 307495 307501], auc: 0.9394438215801807
# train: [     0      1      2 ... 307508 307509 307510], test: [     3     18     22 ... 307499 307503 307504], auc: 0.9367866336499592
# train: [     0      1      2 ... 307508 307509 307510], test: [     9     10     15 ... 307489 307492 307502], auc: 0.9353776828992423
# train: [     0      1      2 ... 307506 307507 307508], test: [    12     16     23 ... 307505 307509 307510], auc: 0.9374553568825879
# train: [     1      3      4 ... 307505 307509 307510], test: [     0      2      5 ... 307506 307507 307508], auc: 0.9343673666153791
#
#
# Durchschnitt: 0.94
# Standardabw.: 0.00
# Varianz:      0.00

# %%
model = RandomForestClassifier(**TREE_PARAMS)
model = model.fit(x, y)

# %%
app_test = pd.read_csv(DATASET_DIR / "4. FillNA" / "app_test.csv")
bureau = pd.read_csv(DATASET_DIR / "4. FillNA" / "bureau_all.csv")
pa_pos = pd.read_csv(DATASET_DIR / "4. FillNA" / "pa_pos_all.csv")
pa_ip = pd.read_csv(DATASET_DIR / "4. FillNA" / "pa_ip_all.csv")
pa_cc = pd.read_csv(DATASET_DIR / "4. FillNA" / "pa_cc_all.csv")

# %%
app_test = app_test.set_index("SK_ID_CURR")
bureau = bureau.set_index("SK_ID_CURR")
pa_pos = pa_pos.set_index("SK_ID_CURR")
pa_ip = pa_ip.set_index("SK_ID_CURR")
pa_cc = pa_cc.set_index("SK_ID_CURR")

# %%
df = pd.DataFrame(index=app_test.index)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [100001, 100005, 100013, 100028, 100038]

# %%
# application prediction

# %%
x = app_test[model_application_data["keep"]]
x.head()
# Out:
#             A_EXT_SOURCE_3  A_EXT_SOURCE_1  A_EXT_SOURCE_2  \
# SK_ID_CURR
# 100001            0.159520        0.752614        0.789654
# 100005            0.432962        0.564990        0.291656
# 100013            0.610991        0.716539        0.699787
# 100028            0.612704        0.525734        0.509677
# 100038            0.418580        0.202145        0.425687
#
#             A_AMT_REQ_CREDIT_BUREAU_DAY  A_AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100001                         0.000000                      0.000000
# 100005                         0.000000                      0.000000
# 100013                         0.000000                      0.000000
# 100028                         0.000000                      0.000000
# 100038                         0.007371                      0.006616
#
#             A_YEARS_BEGINEXPLUATATION_AVG  A_DAYS_EMPLOYED  A_DAYS_BIRTH  \
# SK_ID_CURR
# 100001                           0.973200          -2329.0      -19241.0
# 100005                           0.977818          -4469.0      -18064.0
# 100013                           0.982704          -4458.0      -20038.0
# 100028                           0.997000          -1866.0      -13976.0
# 100038                           0.979896          -2191.0      -13040.0
#
#             A_BASEMENTAREA_AVG  A_LANDAREA_AVG
# SK_ID_CURR
# 100001                0.059000        0.020985
# 100005                0.083623        0.057886
# 100013                0.087005        0.067540
# 100028                0.197400        0.204200
# 100038                0.050552        0.076152

# %%
predicted = pd.DataFrame(model_application.predict_proba(x), index=app_test.index)
predicted.columns = ["A_PAYBACK", "A_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             A_PAYBACK  A_DEFAULT
# SK_ID_CURR
# 100001       0.961833   0.038167
# 100005       0.888497   0.111503
# 100013       0.996241   0.003759
# 100028       0.967570   0.032430
# 100038       0.890788   0.109212

# %%
# bureau prediction

# %%
x = bureau[model_bureau_data["keep"]]
x.head()
# Out:
#             B_Active  B_Closed  B_AMT_CREDIT_SUM  B_AMT_CREDIT_SUM_DEBT  \
# SK_ID_CURR
# 100001           3.0       4.0     290936.250000          149171.625000
# 100002           2.0       6.0     212745.000000           81927.000000
# 100003           1.0       3.0     810000.000000               0.000000
# 100004           0.0       2.0     592024.042525          278490.216669
# 100005           2.0       1.0     219042.000000          189469.500000
#
#             B_DAYS_CREDIT_ENDDATE  B_AMT_CREDIT_SUM_OVERDUE  B_AMT_ANNUITY
# SK_ID_CURR
# 100001                 728.000000                  0.000000    6204.375000
# 100002                 309.000000                  0.000000       0.000000
# 100003                1216.000000                  0.000000       0.000000
# 100004                2401.546966                  7.541775    5861.850739
# 100005                 439.333333                  0.000000    1420.500000

# %%
predicted = pd.DataFrame(model_bureau.predict_proba(x), index=bureau.index)
predicted.columns = ["B_PAYBACK", "B_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT
# SK_ID_CURR
# 100001       0.961833   0.038167   0.925268   0.074732
# 100005       0.888497   0.111503   0.919031   0.080969
# 100013       0.996241   0.003759   0.931967   0.068033
# 100028       0.967570   0.032430   0.910811   0.089189
# 100038       0.890788   0.109212        NaN        NaN

# %%
# pa_pos prediction

# %%
x = pa_pos[model_pa_pos_data["keep"]]
x.head()
# Out:
#             PA_CNT_NAME_CONTRACT_STATUS_Refused  PA_AMT_ANNUITY  \
# SK_ID_CURR
# 100001                                      0.0        3951.000
# 100002                                      0.0        9251.775
# 100003                                      0.0      169661.970
# 100004                                      0.0        5357.250
# 100005                                      0.0        4813.200
#
#             PA_AMT_GOODS_PRICE  PA_AMT_DOWN_PAYMENT  \
# SK_ID_CURR
# 100001                 24835.5               2520.0
# 100002                179055.0                  0.0
# 100003               1306309.5               6885.0
# 100004                 24282.0               4860.0
# 100005                 44617.5               4464.0
#
#             PA_CNT_NAME_PRODUCT_TYPE_walk-in  PA_POS_CNT_DPD  PA_AMT_CREDIT  \
# SK_ID_CURR
# 100001                                   0.0             0.0        23787.0
# 100002                                   0.0             0.0       179055.0
# 100003                                   0.0             0.0      1452573.0
# 100004                                   0.0             0.0        20106.0
# 100005                                   0.0             0.0        40153.5
#
#             PA_RATE_DOWN_PAYMENT  PA_CNT_NAME_YIELD_GROUP_high  \
# SK_ID_CURR
# 100001                  0.104326                           1.0
# 100002                  0.000000                           0.0
# 100003                  0.100061                           0.0
# 100004                  0.212008                           0.0
# 100005                  0.108964                           1.0
#
#             PA_POS_CNT_PAYMENTS_LEFT  PA_CNT_NAME_CLIENT_TYPE_New  \
# SK_ID_CURR
# 100001                           0.0                          0.0
# 100002                           6.0                          1.0
# 100003                           0.0                          0.0
# 100004                           0.0                          1.0
# 100005                           0.0                          1.0
#
#             PA_CNT_NAME_YIELD_GROUP_low_normal  \
# SK_ID_CURR
# 100001                                     0.0
# 100002                                     1.0
# 100003                                     1.0
# 100004                                     0.0
# 100005                                     0.0
#
#             PA_CNT_NAME_CONTRACT_TYPE_Revolving loans  PA_CNT_CREDITS  \
# SK_ID_CURR
# 100001                                            0.0             1.0
# 100002                                            0.0             1.0
# 100003                                            0.0             3.0
# 100004                                            0.0             1.0
# 100005                                            0.0             1.0
#
#             PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low  \
# SK_ID_CURR
# 100001                                              0.0
# 100002                                              0.0
# 100003                                              1.0
# 100004                                              0.0
# 100005                                              0.0
#
#             PA_CNT_NAME_CLIENT_TYPE_Refreshed  \
# SK_ID_CURR
# 100001                                    1.0
# 100002                                    0.0
# 100003                                    2.0
# 100004                                    0.0
# 100005                                    0.0
#
#             PA_CNT_PRODUCT_COMBINATION_POS industry with interest
# SK_ID_CURR
# 100001                                                        0.0
# 100002                                                        0.0
# 100003                                                        1.0
# 100004                                                        0.0
# 100005                                                        0.0

# %%
predicted = pd.DataFrame(model_pa_pos.predict_proba(x), index=pa_pos.index)
predicted.columns = ["PA_POS_PAYBACK", "PA_POS_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  PA_POS_PAYBACK  \
# SK_ID_CURR
# 100001       0.961833   0.038167   0.925268   0.074732        0.915258
# 100005       0.888497   0.111503   0.919031   0.080969        0.892115
# 100013       0.996241   0.003759   0.931967   0.068033        0.943434
# 100028       0.967570   0.032430   0.910811   0.089189        0.931185
# 100038       0.890788   0.109212        NaN        NaN        0.896059
#
#             PA_POS_DEFAULT
# SK_ID_CURR
# 100001            0.084742
# 100005            0.107885
# 100013            0.056566
# 100028            0.068815
# 100038            0.103941

# %%
# pa_ip prediction

# %%
x = pa_ip[model_pa_ip_data["keep"]]
x.head()
# Out:
#             PA_CNT_NAME_PRODUCT_TYPE_walk-in  PA_IP_DAYS_DIFF_60  \
# SK_ID_CURR
# 252457                                   1.0               -15.0
# 256657                                   5.0               -13.0
# 198678                                   0.0               -21.5
# 310743                                   0.0                 0.0
# 394447                                   1.0                -7.0
#
#             PA_CNT_NAME_CONTRACT_STATUS_Refused  PA_IP_DAYS_DIFF_30  \
# SK_ID_CURR
# 252457                                      0.0                 0.0
# 256657                                      7.0                -6.0
# 198678                                      0.0               -20.0
# 310743                                      1.0                 0.0
# 394447                                      0.0                -0.5
#
#             PA_AMT_ANNUITY  PA_IP_DAYS_DIFF_120  PA_IP_DAYS_DIFF_90  \
# SK_ID_CURR
# 252457            4951.350                -14.0               -17.0
# 256657           49054.770                -12.5               -12.0
# 198678           98806.050                 -1.0                -6.5
# 310743            7002.720                  0.0                 0.0
# 394447           17141.445                 -6.5                -7.0
#
#             PA_IP_DAYS_DIFF_180  PA_AMT_CREDIT  PA_IP_PAYMENT_180  \
# SK_ID_CURR
# 252457                      0.0        52641.0          -0.912871
# 256657                     -1.5      1198062.0          -1.020621
# 198678                     -0.5       941661.0           0.000204
# 310743                     -5.0        75024.0           2.041241
# 394447                      0.0       129132.0          -0.412932
#
#             PA_AMT_APPLICATION  PA_IP_AMT_DIFF_60  PA_IP_AMT_DIFF_30  \
# SK_ID_CURR
# 252457               47056.275                0.0                0.0
# 256657              978570.000                0.0                0.0
# 198678              921721.500                0.0                0.0
# 310743               67864.230                0.0                0.0
# 394447              129132.000                0.0                0.0
#
#             PA_IP_DAYS_DIFF_150  PA_CNT_NAME_YIELD_GROUP_low_normal  \
# SK_ID_CURR
# 252457                      0.0                                 0.0
# 256657                    -13.0                                 2.0
# 198678                      0.5                                 0.0
# 310743                      0.0                                 2.0
# 394447                     -8.5                                 0.0
#
#             PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low  PA_IP_PAYMENT_60  \
# SK_ID_CURR
# 252457                                              0.0      9.128709e-01
# 256657                                              0.0      2.041241e-01
# 198678                                              0.0      4.540312e-08
# 310743                                              1.0     -4.082483e-01
# 394447                                              0.0      6.115381e-01
#
#             PA_IP_AMT_DIFF_180  PA_IP_AMT_DIFF_90  \
# SK_ID_CURR
# 252457                     0.0                0.0
# 256657                     0.0                0.0
# 198678                     0.0                0.0
# 310743                     0.0                0.0
# 394447                     0.0                0.0
#
#             PA_CNT_NAME_CONTRACT_TYPE_Revolving loans  PA_IP_AMT_DIFF_150  \
# SK_ID_CURR
# 252457                                            1.0                 0.0
# 256657                                            2.0                 0.0
# 198678                                            0.0                 0.0
# 310743                                            0.0                 0.0
# 394447                                            1.0                 0.0
#
#             PA_CNT_NAME_CLIENT_TYPE_New  PA_CNT_NAME_YIELD_GROUP_high  \
# SK_ID_CURR
# 252457                              0.0                           0.0
# 256657                              1.0                           0.0
# 198678                              1.0                           0.0
# 310743                              1.0                           0.0
# 394447                              2.0                           0.0
#
#             PA_CNT_NAME_PORTFOLIO_Cards  PA_CNT_NAME_CLIENT_TYPE_Refreshed  \
# SK_ID_CURR
# 252457                              1.0                                2.0
# 256657                              2.0                                0.0
# 198678                              0.0                                0.0
# 310743                              0.0                                0.0
# 394447                              1.0                                0.0
#
#             PA_CNT_PRODUCT_COMBINATION_POS industry with interest  \
# SK_ID_CURR
# 252457                                                        0.0
# 256657                                                        0.0
# 198678                                                        0.0
# 310743                                                        0.0
# 394447                                                        0.0
#
#             PA_RATE_DOWN_PAYMENT
# SK_ID_CURR
# 252457                  0.000088
# 256657                  0.217818
# 198678                  0.193358
# 310743                  0.000061
# 394447                  0.000000

# %%
predicted = pd.DataFrame(model_pa_ip.predict_proba(x), index=pa_ip.index)
predicted.columns = ["PA_IP_PAYBACK", "PA_IP_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  PA_POS_PAYBACK  \
# SK_ID_CURR
# 100001       0.961833   0.038167   0.925268   0.074732        0.915258
# 100005       0.888497   0.111503   0.919031   0.080969        0.892115
# 100013       0.996241   0.003759   0.931967   0.068033        0.943434
# 100028       0.967570   0.032430   0.910811   0.089189        0.931185
# 100038       0.890788   0.109212        NaN        NaN        0.896059
#
#             PA_POS_DEFAULT  PA_IP_PAYBACK  PA_IP_DEFAULT
# SK_ID_CURR
# 100001            0.084742            NaN            NaN
# 100005            0.107885            NaN            NaN
# 100013            0.056566       0.844992       0.155008
# 100028            0.068815       0.920394       0.079606
# 100038            0.103941            NaN            NaN

# %%
# pa_cc prediction

# %%
x = pa_cc[model_pa_cc_data["keep"]]
x.head()
# Out:
#             PA_CC_BALANCE_60  PA_CC_BALANCE_30  PA_CC_BALANCE_90  \
# SK_ID_CURR
# 394447              1.434002         -1.206367          0.992963
# 361282              0.828945          0.946004          0.861611
# 131335              0.719445          0.722068          0.791575
# 436351              0.000000          0.000000          0.000000
# 181153              0.000000          0.000000          0.000000
#
#             PA_CC_BALANCE_180  PA_CC_BALANCE_120  \
# SK_ID_CURR
# 394447              -0.455389          -0.349513
# 361282              -1.169080          -0.393110
# 131335              -1.619869           0.204483
# 436351               0.000000           0.000000
# 181153               0.000000           0.000000
#
#             PA_CNT_NAME_PRODUCT_TYPE_walk-in  PA_CC_PAYMENT_60  \
# SK_ID_CURR
# 394447                                   1.0          1.008387
# 361282                                   1.0          1.109609
# 131335                                   1.0         -0.427508
# 436351                                   1.0          0.000000
# 181153                                   1.0          0.000000
#
#             PA_CC_PAYMENT_180  PA_CC_PAYMENT_120  \
# SK_ID_CURR
# 394447               1.318045          -0.292196
# 361282              -1.152838          -1.267179
# 131335               2.030866          -0.215249
# 436351               0.000000           0.000000
# 181153               0.000000           0.000000
#
#             PA_CNT_NAME_CONTRACT_STATUS_Refused  PA_AMT_CREDIT  \
# SK_ID_CURR
# 394447                                      0.0        45000.0
# 361282                                      0.0        45000.0
# 131335                                      0.0        45000.0
# 436351                                      3.0        45000.0
# 181153                                      3.0        45000.0
#
#             PA_AMT_APPLICATION  PA_AMT_GOODS_PRICE  \
# SK_ID_CURR
# 394447                 45000.0             45000.0
# 361282                 45000.0             45000.0
# 131335                 45000.0             45000.0
# 436351                 45000.0             45000.0
# 181153                 45000.0             45000.0
#
#             PA_CNT_CODE_REJECT_REASON_HC  PA_CNT_NAME_YIELD_GROUP_high  \
# SK_ID_CURR
# 394447                               0.0                           0.0
# 361282                               0.0                           0.0
# 131335                               0.0                           0.0
# 436351                               3.0                           2.0
# 181153                               0.0                           3.0
#
#             PA_CNT_NAME_CLIENT_TYPE_New  \
# SK_ID_CURR
# 394447                              2.0
# 361282                              2.0
# 131335                              2.0
# 436351                              0.0
# 181153                              1.0
#
#             PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low  \
# SK_ID_CURR
# 394447                                              0.0
# 361282                                              0.0
# 131335                                              0.0
# 436351                                              3.0
# 181153                                              0.0
#
#             PA_CNT_NAME_YIELD_GROUP_low_normal  \
# SK_ID_CURR
# 394447                                     0.0
# 361282                                     1.0
# 131335                                     1.0
# 436351                                     6.0
# 181153                                     1.0
#
#             PA_CNT_NAME_CLIENT_TYPE_Refreshed  \
# SK_ID_CURR
# 394447                                    0.0
# 361282                                    0.0
# 131335                                    0.0
# 436351                                    1.0
# 181153                                    1.0
#
#             PA_CNT_PRODUCT_COMBINATION_POS industry with interest  \
# SK_ID_CURR
# 394447                                                        0.0
# 361282                                                        0.0
# 131335                                                        0.0
# 436351                                                        0.0
# 181153                                                        0.0
#
#             PA_CC_DPD_180
# SK_ID_CURR
# 394447                0.0
# 361282                0.0
# 131335                0.0
# 436351                0.0
# 181153                0.0

# %%
predicted = pd.DataFrame(model_pa_cc.predict_proba(x), index=pa_cc.index)
predicted.columns = ["PA_CC_PAYBACK", "PA_CC_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  PA_POS_PAYBACK  \
# SK_ID_CURR
# 100001       0.961833   0.038167   0.925268   0.074732        0.915258
# 100005       0.888497   0.111503   0.919031   0.080969        0.892115
# 100013       0.996241   0.003759   0.931967   0.068033        0.943434
# 100028       0.967570   0.032430   0.910811   0.089189        0.931185
# 100038       0.890788   0.109212        NaN        NaN        0.896059
#
#             PA_POS_DEFAULT  PA_IP_PAYBACK  PA_IP_DEFAULT  PA_CC_PAYBACK  \
# SK_ID_CURR
# 100001            0.084742            NaN            NaN            NaN
# 100005            0.107885            NaN            NaN            NaN
# 100013            0.056566       0.844992       0.155008            NaN
# 100028            0.068815       0.920394       0.079606       0.894884
# 100038            0.103941            NaN            NaN            NaN
#
#             PA_CC_DEFAULT
# SK_ID_CURR
# 100001                NaN
# 100005                NaN
# 100013                NaN
# 100028           0.105116
# 100038                NaN

# %%
df = df.fillna(0.5)
df.head()
# Out:
#             A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  PA_POS_PAYBACK  \
# SK_ID_CURR
# 100001       0.961833   0.038167   0.925268   0.074732        0.915258
# 100005       0.888497   0.111503   0.919031   0.080969        0.892115
# 100013       0.996241   0.003759   0.931967   0.068033        0.943434
# 100028       0.967570   0.032430   0.910811   0.089189        0.931185
# 100038       0.890788   0.109212   0.500000   0.500000        0.896059
#
#             PA_POS_DEFAULT  PA_IP_PAYBACK  PA_IP_DEFAULT  PA_CC_PAYBACK  \
# SK_ID_CURR
# 100001            0.084742       0.500000       0.500000       0.500000
# 100005            0.107885       0.500000       0.500000       0.500000
# 100013            0.056566       0.844992       0.155008       0.500000
# 100028            0.068815       0.920394       0.079606       0.894884
# 100038            0.103941       0.500000       0.500000       0.500000
#
#             PA_CC_DEFAULT
# SK_ID_CURR
# 100001           0.500000
# 100005           0.500000
# 100013           0.500000
# 100028           0.105116
# 100038           0.500000

# %%
TARGET = model.predict_proba(df)[:,1]

# %%
solution = pd.DataFrame(TARGET, index=df.index)
solution.columns = ["TARGET"]

# %%
solution.head()
# Out:
#               TARGET
# SK_ID_CURR
# 100001      0.011435
# 100005      0.093632
# 100013      0.006050
# 100028      0.010159
# 100038      0.074113

# %%
solution.to_csv(DATASET_DIR / "solution.csv")
