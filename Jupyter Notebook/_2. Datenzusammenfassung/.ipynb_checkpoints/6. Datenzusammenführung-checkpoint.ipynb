# %%
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
app_test = pd.read_csv(DATASET_DIR / "application_test.csv", index_col=0)
app_train = pd.read_csv(DATASET_DIR / "application_train.csv", index_col=0)

bureau = pd.read_csv(DATASET_DIR / "Datengruppierung" / "bureau.csv", index_col=0)
previous_application = pd.read_csv(DATASET_DIR / "Datengruppierung" / "previous_application.csv", index_col=0)
POS_CASH_balance = pd.read_csv(DATASET_DIR / "Datengruppierung" / "POS_CASH_balance.csv", index_col=0)
installments_payments = pd.read_csv(DATASET_DIR / "Datengruppierung" / "installments_payments.csv", index_col=0)
credit_card_balance = pd.read_csv(DATASET_DIR / "Datengruppierung" / "credit_card_balance.csv", index_col=0)

# %%
data = app_train.join(bureau, on="SK_ID_CURR")
data = data.join(previous_application, on="SK_ID_CURR", rsuffix='_pa')
data = data.join(POS_CASH_balance, on="SK_ID_CURR")
data = data.join(installments_payments, on="SK_ID_CURR")
data = data.join(credit_card_balance, on="SK_ID_CURR", rsuffix='_cc')

# %%
# TODO: MERGE APP_TEST -> Kontrollieren, dass keine IDs aus AppTrain zu AppTest hinzufügen

# %%
data.head()
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M            N
# 100003           0         Cash loans           F            N
# 100004           0    Revolving loans           M            Y
# 100006           0         Cash loans           F            N
# 100007           0         Cash loans           M            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                   Y             0          202500.0    406597.5
# 100003                   N             0          270000.0   1293502.5
# 100004                   Y             0           67500.0    135000.0
# 100006                   Y             0          135000.0    312682.5
# 100007                   Y             0          121500.0    513000.0
#
#             AMT_ANNUITY  AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# SK_ID_CURR
# ...

# %%
data["TARGET"].value_counts()
# Out:
# 0    282686
# 1     24825
# Name: TARGET, dtype: int64

# %%
app_train["TARGET"].value_counts()
# Out:
# 0    282686
# 1     24825
# Name: TARGET, dtype: int64

# %%
data.to_csv(DATASET_DIR / "Datengruppierung" / "dataset.csv")
