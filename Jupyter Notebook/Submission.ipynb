# %%
from pathlib import Path
from scipy import stats

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

from sklearn.linear_model import LogisticRegression

from IPython.display import display, Markdown

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
app_train = pd.read_csv(DATASET_DIR / "application_train.csv", index_col="SK_ID_CURR")
app_test = pd.read_csv(DATASET_DIR / "application_test.csv", index_col="SK_ID_CURR")
description = pd.read_csv(DATASET_DIR / "HomeCredit_columns_description.csv", encoding="latin", index_col=0)

# %%
cats_head = ['CODE_GENDER', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
 'FLAG_EMP_PHONE', 'OCCUPATION_TYPE', 'REGION_RATING_CLIENT',
 'REG_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'FLAG_DOCUMENT_3',
 'CNT_CHILDREN', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE',
 'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY',
 'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON',
 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR']

# %%
mets_head = ['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY',
 'REGION_POPULATION_RELATIVE' ,'DAYS_BIRTH', 'DAYS_EMPLOYED',
 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH' ,'EXT_SOURCE_1' ,'EXT_SOURCE_2',
 'EXT_SOURCE_3', 'BASEMENTAREA_AVG' ,'YEARS_BEGINEXPLUATATION_AVG',
 'LANDAREA_AVG', 'NONLIVINGAREA_AVG', 'TOTALAREA_MODE' ,'CREDIT/INCOME']

# %%
app_test.head()
# Out:
#            NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# SK_ID_CURR
# 100001             Cash loans           F            N               Y
# 100005             Cash loans           M            N               Y
# 100013             Cash loans           M            Y               Y
# 100028             Cash loans           F            N               Y
# 100038             Cash loans           M            Y               N
#
#             CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# 100001                 0          135000.0    568800.0      20560.5
# 100005                 0           99000.0    222768.0      17370.0
# 100013                 0          202500.0    663264.0      69777.0
# 100028                 2          315000.0   1575000.0      49018.5
# 100038                 1          180000.0    625500.0      32067.0
#
#             AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# SK_ID_CURR
# 100001             450000.0   Unaccompanied          Working
# 100005             180000.0   Unaccompanied          Working
# 100013             630000.0             NaN          Working
# 100028            1575000.0   Unaccompanied          Working
# 100038             625500.0   Unaccompanied          Working
#
#                       NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# SK_ID_CURR
# 100001                   Higher education            Married
# 100005      Secondary / secondary special            Married
# 100013                   Higher education            Married
# 100028      Secondary / secondary special            Married
# 100038      Secondary / secondary special            Married
#
#             NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# SK_ID_CURR
# 100001      House / apartment                    0.018850      -19241
# 100005      House / apartment                    0.035792      -18064
# 100013      House / apartment                    0.019101      -20038
# 100028      House / apartment                    0.026392      -13976
# 100038      House / apartment                    0.010032      -13040
#
#             DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  \
# SK_ID_CURR
# 100001              -2329            -5170.0             -812          NaN
# 100005              -4469            -9118.0            -1623          NaN
# 100013              -4458            -2175.0            -3503          5.0
# 100028              -1866            -2000.0            -4208          NaN
# 100038              -2191            -4000.0            -4262         16.0
#
#             FLAG_MOBIL  FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  \
# SK_ID_CURR
# 100001               1               1                0                 1
# 100005               1               1                0                 1
# 100013               1               1                0                 1
# 100028               1               1                0                 1
# 100038               1               1                1                 1
#
#             FLAG_PHONE  FLAG_EMAIL     OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# SK_ID_CURR
# 100001               0           1                 NaN              2.0
# 100005               0           0  Low-skill Laborers              2.0
# 100013               0           0             Drivers              2.0
# 100028               1           0         Sales staff              4.0
# 100038               0           0                 NaN              3.0
#
#             REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# SK_ID_CURR
# 100001                         2                            2
# 100005                         2                            2
# 100013                         2                            2
# 100028                         2                            2
# 100038                         2                            2
#
#            WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  \
# SK_ID_CURR
# 100001                        TUESDAY                       18
# 100005                         FRIDAY                        9
# 100013                         MONDAY                       14
# 100028                      WEDNESDAY                       11
# 100038                         FRIDAY                        5
#
#             REG_REGION_NOT_LIVE_REGION  REG_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100001                               0                           0
# 100005                               0                           0
# 100013                               0                           0
# 100028                               0                           0
# 100038                               0                           0
#
#             LIVE_REGION_NOT_WORK_REGION  REG_CITY_NOT_LIVE_CITY  \
# SK_ID_CURR
# 100001                                0                       0
# 100005                                0                       0
# 100013                                0                       0
# 100028                                0                       0
# 100038                                0                       0
#
#             REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100001                           0                        0
# 100005                           0                        0
# 100013                           0                        0
# 100028                           0                        0
# 100038                           1                        1
#
#                  ORGANIZATION_TYPE  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# SK_ID_CURR
# 100001                Kindergarten      0.752614      0.789654      0.159520
# 100005               Self-employed      0.564990      0.291656      0.432962
# 100013           Transport: type 3           NaN      0.699787      0.610991
# 100028      Business Entity Type 3      0.525734      0.509677      0.612704
# 100038      Business Entity Type 3      0.202145      0.425687           NaN
#
#             APARTMENTS_AVG  BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  \
# SK_ID_CURR
# 100001              0.0660            0.0590                       0.9732
# 100005                 NaN               NaN                          NaN
# 100013                 NaN               NaN                          NaN
# 100028              0.3052            0.1974                       0.9970
# 100038                 NaN               NaN                          NaN
#
#             YEARS_BUILD_AVG  COMMONAREA_AVG  ELEVATORS_AVG  ENTRANCES_AVG  \
# SK_ID_CURR
# 100001                  NaN             NaN            NaN         0.1379
# 100005                  NaN             NaN            NaN            NaN
# 100013                  NaN             NaN            NaN            NaN
# 100028               0.9592          0.1165           0.32         0.2759
# 100038                  NaN             NaN            NaN            NaN
#
#             FLOORSMAX_AVG  FLOORSMIN_AVG  LANDAREA_AVG  LIVINGAPARTMENTS_AVG  \
# SK_ID_CURR
# 100001              0.125            NaN           NaN                   NaN
# 100005                NaN            NaN           NaN                   NaN
# 100013                NaN            NaN           NaN                   NaN
# 100028              0.375         0.0417        0.2042                0.2404
# 100038                NaN            NaN           NaN                   NaN
#
#             LIVINGAREA_AVG  NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  \
# SK_ID_CURR
# 100001              0.0505                      NaN                NaN
# 100005                 NaN                      NaN                NaN
# 100013                 NaN                      NaN                NaN
# 100028              0.3673                   0.0386               0.08
# 100038                 NaN                      NaN                NaN
#
#             APARTMENTS_MODE  BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  \
# SK_ID_CURR
# 100001               0.0672             0.0612                        0.9732
# 100005                  NaN                NaN                           NaN
# 100013                  NaN                NaN                           NaN
# 100028               0.3109             0.2049                        0.9970
# 100038                  NaN                NaN                           NaN
#
#             YEARS_BUILD_MODE  COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  \
# SK_ID_CURR
# 100001                   NaN              NaN             NaN          0.1379
# 100005                   NaN              NaN             NaN             NaN
# 100013                   NaN              NaN             NaN             NaN
# 100028                0.9608           0.1176          0.3222          0.2759
# 100038                   NaN              NaN             NaN             NaN
#
#             FLOORSMAX_MODE  FLOORSMIN_MODE  LANDAREA_MODE  \
# SK_ID_CURR
# 100001               0.125             NaN            NaN
# 100005                 NaN             NaN            NaN
# 100013                 NaN             NaN            NaN
# 100028               0.375          0.0417         0.2089
# 100038                 NaN             NaN            NaN
#
#             LIVINGAPARTMENTS_MODE  LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  \
# SK_ID_CURR
# 100001                        NaN           0.0526                       NaN
# 100005                        NaN              NaN                       NaN
# 100013                        NaN              NaN                       NaN
# 100028                     0.2626           0.3827                    0.0389
# 100038                        NaN              NaN                       NaN
#
#             NONLIVINGAREA_MODE  APARTMENTS_MEDI  BASEMENTAREA_MEDI  \
# SK_ID_CURR
# 100001                     NaN           0.0666             0.0590
# 100005                     NaN              NaN                NaN
# 100013                     NaN              NaN                NaN
# 100028                  0.0847           0.3081             0.1974
# 100038                     NaN              NaN                NaN
#
#             YEARS_BEGINEXPLUATATION_MEDI  YEARS_BUILD_MEDI  COMMONAREA_MEDI  \
# SK_ID_CURR
# 100001                            0.9732               NaN              NaN
# 100005                               NaN               NaN              NaN
# 100013                               NaN               NaN              NaN
# 100028                            0.9970            0.9597           0.1173
# 100038                               NaN               NaN              NaN
#
#             ELEVATORS_MEDI  ENTRANCES_MEDI  FLOORSMAX_MEDI  FLOORSMIN_MEDI  \
# SK_ID_CURR
# 100001                 NaN          0.1379           0.125             NaN
# 100005                 NaN             NaN             NaN             NaN
# 100013                 NaN             NaN             NaN             NaN
# 100028                0.32          0.2759           0.375          0.0417
# 100038                 NaN             NaN             NaN             NaN
#
#             LANDAREA_MEDI  LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  \
# SK_ID_CURR
# 100001                NaN                    NaN           0.0514
# 100005                NaN                    NaN              NaN
# 100013                NaN                    NaN              NaN
# 100028             0.2078                 0.2446           0.3739
# 100038                NaN                    NaN              NaN
#
#             NONLIVINGAPARTMENTS_MEDI  NONLIVINGAREA_MEDI FONDKAPREMONT_MODE  \
# SK_ID_CURR
# 100001                           NaN                 NaN                NaN
# 100005                           NaN                 NaN                NaN
# 100013                           NaN                 NaN                NaN
# 100028                        0.0388              0.0817   reg oper account
# 100038                           NaN                 NaN                NaN
#
#             HOUSETYPE_MODE  TOTALAREA_MODE WALLSMATERIAL_MODE  \
# SK_ID_CURR
# 100001      block of flats          0.0392       Stone, brick
# 100005                 NaN             NaN                NaN
# 100013                 NaN             NaN                NaN
# 100028      block of flats          0.3700              Panel
# 100038                 NaN             NaN                NaN
#
#            EMERGENCYSTATE_MODE  OBS_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100001                      No                       0.0
# 100005                     NaN                       0.0
# 100013                     NaN                       0.0
# 100028                      No                       0.0
# 100038                     NaN                       0.0
#
#             DEF_30_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100001                           0.0                       0.0
# 100005                           0.0                       0.0
# 100013                           0.0                       0.0
# 100028                           0.0                       0.0
# 100038                           0.0                       0.0
#
#             DEF_60_CNT_SOCIAL_CIRCLE  DAYS_LAST_PHONE_CHANGE  FLAG_DOCUMENT_2  \
# SK_ID_CURR
# 100001                           0.0                 -1740.0                0
# 100005                           0.0                     0.0                0
# 100013                           0.0                  -856.0                0
# 100028                           0.0                 -1805.0                0
# 100038                           0.0                  -821.0                0
#
#             FLAG_DOCUMENT_3  FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  \
# SK_ID_CURR
# 100001                    1                0                0
# 100005                    1                0                0
# 100013                    0                0                0
# 100028                    1                0                0
# 100038                    1                0                0
#
#             FLAG_DOCUMENT_6  FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  \
# SK_ID_CURR
# 100001                    0                0                0
# 100005                    0                0                0
# 100013                    0                0                1
# 100028                    0                0                0
# 100038                    0                0                0
#
#             FLAG_DOCUMENT_9  FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  \
# SK_ID_CURR
# 100001                    0                 0                 0
# 100005                    0                 0                 0
# 100013                    0                 0                 0
# 100028                    0                 0                 0
# 100038                    0                 0                 0
#
#             FLAG_DOCUMENT_12  FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  \
# SK_ID_CURR
# 100001                     0                 0                 0
# 100005                     0                 0                 0
# 100013                     0                 0                 0
# 100028                     0                 0                 0
# 100038                     0                 0                 0
#
#             FLAG_DOCUMENT_15  FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  \
# SK_ID_CURR
# 100001                     0                 0                 0
# 100005                     0                 0                 0
# 100013                     0                 0                 0
# 100028                     0                 0                 0
# 100038                     0                 0                 0
#
#             FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  \
# SK_ID_CURR
# 100001                     0                 0                 0
# 100005                     0                 0                 0
# 100013                     0                 0                 0
# 100028                     0                 0                 0
# 100038                     0                 0                 0
#
#             FLAG_DOCUMENT_21  AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100001                     0                         0.0
# 100005                     0                         0.0
# 100013                     0                         0.0
# 100028                     0                         0.0
# 100038                     0                         NaN
#
#             AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# SK_ID_CURR
# 100001                            0.0                         0.0
# 100005                            0.0                         0.0
# 100013                            0.0                         0.0
# 100028                            0.0                         0.0
# 100038                            NaN                         NaN
#
#             AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# SK_ID_CURR
# 100001                            0.0                        0.0
# 100005                            0.0                        0.0
# 100013                            0.0                        1.0
# 100028                            0.0                        0.0
# 100038                            NaN                        NaN
#
#             AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR
# 100001                             0.0
# 100005                             3.0
# 100013                             4.0
# 100028                             3.0
# 100038                             NaN

# %%
app_test["CREDIT/INCOME"] = app_test["AMT_CREDIT"] / app_test["AMT_INCOME_TOTAL"]

# %%
df = app_test[cats_head + mets_head].copy()

# %%
# transformiert kategorische variablen in integer
HEADS = [head for head in df.columns.values if df[head].dtype == "object"]

for head in HEADS:
    df[head], cats = pd.factorize(df[head])

# %%
len(df.columns)
# Out:
# 35

# %%
# fill na

# %%
app_train = pd.read_csv(DATASET_DIR / "3. Ausreißerbereinigung" / "app_train.csv")

# %%
app_train = app_train.set_index("SK_ID_CURR")

# %%
app_test = df

# %%
df = app_train.append(app_test)

# %%
len(app_test)
# Out:
# 48744

# %%
df = df.sort_index()

# %%
df.head()
# Out:
#             TARGET  A_CODE_GENDER  A_NAME_INCOME_TYPE  A_NAME_EDUCATION_TYPE  \
# SK_ID_CURR
# 100001         NaN            NaN                 NaN                    NaN
# 100002         1.0            0.0                 0.0                    0.0
# 100003         0.0            1.0                 1.0                    1.0
# 100004         0.0            0.0                 0.0                    0.0
# 100005         NaN            NaN                 NaN                    NaN
#
#             A_FLAG_EMP_PHONE  A_OCCUPATION_TYPE  A_REGION_RATING_CLIENT  \
# SK_ID_CURR
# 100001                   NaN                NaN                     NaN
# 100002                   1.0                0.0                     2.0
# 100003                   1.0                1.0                     1.0
# 100004                   1.0                0.0                     2.0
# 100005                   NaN                NaN                     NaN
#
#             A_REG_CITY_NOT_WORK_CITY  A_ORGANIZATION_TYPE  A_FLAG_DOCUMENT_3  \
# SK_ID_CURR
# 100001                           NaN                  NaN                NaN
# 100002                           0.0                  0.0                1.0
# 100003                           0.0                  1.0                1.0
# 100004                           0.0                  2.0                0.0
# 100005                           NaN                  NaN                NaN
#
#             A_CNT_CHILDREN  A_OBS_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100001                 NaN                         NaN
# 100002                 0.0                         2.0
# 100003                 0.0                         1.0
# 100004                 0.0                         0.0
# 100005                 NaN                         NaN
#
#             A_DEF_60_CNT_SOCIAL_CIRCLE  A_AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100001                             NaN                           NaN
# 100002                             2.0                           0.0
# 100003                             0.0                           0.0
# 100004                             0.0                           0.0
# 100005                             NaN                           NaN
#
#             A_AMT_REQ_CREDIT_BUREAU_DAY  A_AMT_REQ_CREDIT_BUREAU_WEEK  \
# SK_ID_CURR
# 100001                              NaN                           NaN
# 100002                              0.0                           0.0
# 100003                              0.0                           0.0
# 100004                              0.0                           0.0
# 100005                              NaN                           NaN
#
#             A_AMT_REQ_CREDIT_BUREAU_MON  A_AMT_REQ_CREDIT_BUREAU_QRT  \
# SK_ID_CURR
# 100001                              NaN                          NaN
# 100002                              0.0                          0.0
# 100003                              0.0                          0.0
# 100004                              0.0                          0.0
# 100005                              NaN                          NaN
#
#             A_AMT_REQ_CREDIT_BUREAU_YEAR  A_AMT_INCOME_TOTAL  A_AMT_CREDIT  \
# SK_ID_CURR
# 100001                               NaN                 NaN           NaN
# 100002                               1.0            202500.0      406597.5
# 100003                               0.0            270000.0     1293502.5
# 100004                               0.0             67500.0      135000.0
# 100005                               NaN                 NaN           NaN
#
#             A_AMT_ANNUITY  A_REGION_POPULATION_RELATIVE  A_DAYS_BIRTH  \
# SK_ID_CURR
# 100001                NaN                           NaN           NaN
# 100002            24700.5                      0.018801       -9461.0
# 100003            35698.5                      0.003541      -16765.0
# 100004             6750.0                      0.010032      -19046.0
# 100005                NaN                           NaN           NaN
#
#             A_DAYS_EMPLOYED  A_DAYS_REGISTRATION  A_DAYS_ID_PUBLISH  \
# SK_ID_CURR
# 100001                  NaN                  NaN                NaN
# 100002            -1.745205              -3648.0            -2120.0
# 100003            -3.254795              -1186.0             -291.0
# 100004            -0.616438              -4260.0            -2531.0
# 100005                  NaN                  NaN                NaN
#
#             A_EXT_SOURCE_1  A_EXT_SOURCE_2  A_EXT_SOURCE_3  \
# SK_ID_CURR
# 100001                 NaN             NaN             NaN
# 100002            0.083037        0.262949        0.139376
# 100003            0.311267        0.622246             NaN
# 100004                 NaN        0.555912        0.729567
# 100005                 NaN             NaN             NaN
#
#             A_BASEMENTAREA_AVG  A_YEARS_BEGINEXPLUATATION_AVG  A_LANDAREA_AVG  \
# SK_ID_CURR
# 100001                     NaN                            NaN             NaN
# 100002                  0.0369                         0.9722          0.0369
# 100003                  0.0529                         0.9851          0.0130
# 100004                     NaN                            NaN             NaN
# 100005                     NaN                            NaN             NaN
#
#             A_NONLIVINGAREA_AVG  A_TOTALAREA_MODE  A_CREDIT/INCOME  \
# SK_ID_CURR
# 100001                      NaN               NaN              NaN
# 100002                   0.0000            0.0149         2.007889
# 100003                   0.0098            0.0714         4.790750
# 100004                      NaN               NaN         2.000000
# 100005                      NaN               NaN              NaN
#
#             CODE_GENDER  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# SK_ID_CURR
# 100001              0.0               0.0                  0.0
# 100002              NaN               NaN                  NaN
# 100003              NaN               NaN                  NaN
# 100004              NaN               NaN                  NaN
# 100005              1.0               0.0                  1.0
#
#             FLAG_EMP_PHONE  OCCUPATION_TYPE  REGION_RATING_CLIENT  \
# SK_ID_CURR
# 100001                 1.0             -1.0                   2.0
# 100002                 NaN              NaN                   NaN
# 100003                 NaN              NaN                   NaN
# 100004                 NaN              NaN                   NaN
# 100005                 1.0              0.0                   2.0
#
#             REG_CITY_NOT_WORK_CITY  ORGANIZATION_TYPE  FLAG_DOCUMENT_3  \
# SK_ID_CURR
# 100001                         0.0                0.0              1.0
# 100002                         NaN                NaN              NaN
# 100003                         NaN                NaN              NaN
# 100004                         NaN                NaN              NaN
# 100005                         0.0                1.0              1.0
#
#             CNT_CHILDREN  OBS_60_CNT_SOCIAL_CIRCLE  DEF_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100001               0.0                       0.0                       0.0
# 100002               NaN                       NaN                       NaN
# 100003               NaN                       NaN                       NaN
# 100004               NaN                       NaN                       NaN
# 100005               0.0                       0.0                       0.0
#
#             AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# SK_ID_CURR
# 100001                             0.0                        0.0
# 100002                             NaN                        NaN
# 100003                             NaN                        NaN
# 100004                             NaN                        NaN
# 100005                             0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# SK_ID_CURR
# 100001                             0.0                        0.0
# 100002                             NaN                        NaN
# 100003                             NaN                        NaN
# 100004                             NaN                        NaN
# 100005                             0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR  \
# SK_ID_CURR
# 100001                            0.0                         0.0
# 100002                            NaN                         NaN
# 100003                            NaN                         NaN
# 100004                            NaN                         NaN
# 100005                            0.0                         3.0
#
#             AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# 100001              135000.0    568800.0      20560.5
# 100002                   NaN         NaN          NaN
# 100003                   NaN         NaN          NaN
# 100004                   NaN         NaN          NaN
# 100005               99000.0    222768.0      17370.0
#
#             REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# SK_ID_CURR
# 100001                        0.018850    -19241.0        -2329.0
# 100002                             NaN         NaN            NaN
# 100003                             NaN         NaN            NaN
# 100004                             NaN         NaN            NaN
# 100005                        0.035792    -18064.0        -4469.0
#
#             DAYS_REGISTRATION  DAYS_ID_PUBLISH  EXT_SOURCE_1  EXT_SOURCE_2  \
# SK_ID_CURR
# 100001                -5170.0           -812.0      0.752614      0.789654
# 100002                    NaN              NaN           NaN           NaN
# 100003                    NaN              NaN           NaN           NaN
# 100004                    NaN              NaN           NaN           NaN
# 100005                -9118.0          -1623.0      0.564990      0.291656
#
#             EXT_SOURCE_3  BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  \
# SK_ID_CURR
# 100001          0.159520             0.059                       0.9732
# 100002               NaN               NaN                          NaN
# 100003               NaN               NaN                          NaN
# 100004               NaN               NaN                          NaN
# 100005          0.432962               NaN                          NaN
#
#             LANDAREA_AVG  NONLIVINGAREA_AVG  TOTALAREA_MODE  CREDIT/INCOME
# SK_ID_CURR
# 100001               NaN                NaN          0.0392       4.213333
# 100002               NaN                NaN             NaN            NaN
# 100003               NaN                NaN             NaN            NaN
# 100004               NaN                NaN             NaN            NaN
# 100005               NaN                NaN             NaN       2.250182

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
from datetime import datetime

# %%
print(datetime.now().hour, ":", datetime.now().minute)
x = df.copy()
imp = IterativeImputer(max_iter=500, random_state=0)
df = imp.fit_transform(x)
df = pd.DataFrame(df)
df.columns = app_train.columns.values
df.index = app_train.index
print(datetime.now().hour, ":", datetime.now().minute)
# Out:
# 15 : 35
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-2aa3ec3de43b> in <module>
#       2 x = df
#       3 imp = IterativeImputer(max_iter=500, random_state=0)
# ----> 4 df = imp.fit_transform(x)
#       5 df = pd.DataFrame(df)
#       6 df.columns = app_train.columns.values
#
# c:\users\rober\documents\workspace\python\masterarbeit\venv\lib\site-packages\sklearn\impute\_iterative.py in fit_transform(self, X, y)
#     639                                                                 feat_idx,
#     640                                                                 abs_corr_mat)
# --> 641                 Xt, estimator = self._impute_one_feature(
#     642                     Xt, mask_missing_values, feat_idx, neighbor_feat_idx,
#     643                     estimator=None, fit_mode=True)
#
# c:\users\rober\documents\workspace\python\masterarbeit\venv\lib\site-packages\sklearn\impute\_iterative.py in _impute_one_feature(self, X_filled, mask_missing_values, feat_idx, neighbor_feat_idx, estimator, fit_mode)
#     334                 random_state=self.random_state_)
#     335         else:
# --> 336             imputed_values = estimator.predict(X_test)
#     337             imputed_values = np.clip(imputed_values,
#     338                                      self._min_value[feat_idx],
#
# c:\users\rober\documents\workspace\python\masterarbeit\venv\lib\site-packages\sklearn\linear_model\_bayes.py in predict(self, X, return_std)
#     314             Standard deviation of predictive distribution of query points.
#     315         """
# --> 316         y_mean = self._decision_function(X)
#     317         if return_std is False:
#     318             return y_mean
#
# c:\users\rober\documents\workspace\python\masterarbeit\venv\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#
# c:\users\rober\documents\workspace\python\masterarbeit\venv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\users\rober\documents\workspace\python\masterarbeit\venv\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     642
#     643         if force_all_finite:
# --> 644             _assert_all_finite(array,
#     645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#
# c:\users\rober\documents\workspace\python\masterarbeit\venv\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      87     # safely to reduce dtype induced overflows.
#      88     is_float = X.dtype.kind in 'fc'
# ---> 89     if is_float and (np.isfinite(_safe_accumulator_op(np.sum, X))):
#      90         pass
#      91     elif is_float:
#
# c:\users\rober\documents\workspace\python\masterarbeit\venv\lib\site-packages\sklearn\utils\extmath.py in _safe_accumulator_op(op, x, *args, **kwargs)
#     709         result = op(x, *args, **kwargs, dtype=np.float64)
#     710     else:
# --> 711         result = op(x, *args, **kwargs)
#     712     return result
#     713
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# c:\users\rober\documents\workspace\python\masterarbeit\venv\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2239         return res
#    2240
# -> 2241     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2242                           initial=initial, where=where)
#    2243
#
# c:\users\rober\documents\workspace\python\masterarbeit\venv\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# KeyboardInterrupt:
