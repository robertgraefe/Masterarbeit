# %%
from pathlib import Path
from scipy import stats

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

from sklearn.linear_model import LogisticRegression

from IPython.display import display, Markdown

from sklearn import preprocessing

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
app_train = pd.read_csv(DATASET_DIR / "3. Ausreißerbereinigung" / "app_train.csv")
app_train_imp = pd.read_csv(DATASET_DIR / "4. FillNA" / "application.csv")

description = pd.read_csv(DATASET_DIR / "HomeCredit_columns_description.csv", encoding="latin", index_col=0)

# %%
# Original

# %%
df = app_train[["TARGET","A_DAYS_EMPLOYED"]].copy()

# %%
payback = df[df["TARGET"] == 0]
default = df[df["TARGET"] == 1]

# %%
head = "A_DAYS_EMPLOYED"

sns.kdeplot(payback[head])
sns.kdeplot(default[head])

plt.legend(labels=["Payback","Default"])
plt.xlabel("DAYS EMPLOYED")
plt.ylabel("Wahrscheinlichkeit")
plt.title("Original")
plt.show()

# %%
# na = 0

# %%
df = app_train[["TARGET","A_DAYS_EMPLOYED"]].copy()

# %%
df = df.fillna(0)

# %%
payback = df[df["TARGET"] == 0]
default = df[df["TARGET"] == 1]

# %%
head = "A_DAYS_EMPLOYED"

sns.kdeplot(payback[head])
sns.kdeplot(default[head])

plt.legend(labels=["Payback","Default"])
plt.xlabel("DAYS EMPLOYED")
plt.ylabel("Wahrscheinlichkeit")
plt.title("na = 0")
plt.show()

# %%
# na = max

# %%
df = app_train[["TARGET","A_DAYS_EMPLOYED"]].copy()

# %%
df = df.fillna(df.min())

# %%
payback = df[df["TARGET"] == 0]
default = df[df["TARGET"] == 1]

# %%
head = "A_DAYS_EMPLOYED"

sns.kdeplot(payback[head])
sns.kdeplot(default[head])

plt.legend(labels=["Payback","Default"])
plt.xlabel("DAYS EMPLOYED")
plt.ylabel("Wahrscheinlichkeit")
plt.title("na = max")
plt.show()

# %%
# Iterative Imputation

# %%
df = app_train_imp[["TARGET","A_DAYS_EMPLOYED"]].copy()

# %%
payback = df[df["TARGET"] == 0]
default = df[df["TARGET"] == 1]

# %%
head = "A_DAYS_EMPLOYED"

sns.kdeplot(payback[head])
sns.kdeplot(default[head])

plt.legend(labels=["Payback","Default"])
plt.xlabel("DAYS EMPLOYED")
plt.ylabel("Wahrscheinlichkeit")
plt.title("iterative Imputation")
plt.show()
