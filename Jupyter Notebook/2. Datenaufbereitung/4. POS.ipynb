# %% [markdown]
# ## <u>2.Datenaufbereitung Point of Sales

# %% [markdown]
# In diesem Dokument werden für die Untersuchung unwichtige Variablen aus dem POS-Datensatz gelöscht und wichtige gruppiert. Im Gegensatz zu den Application-Daten liegt in dem POS-Datensatz eine N:M-Beziehung vor, da ein Kreditnehmer in der Vergangenheit mehrere Kredite gehabt haben kann und diese monatliche Kreditdaten beinhalten. Dies erfordert die Gruppierung der historischen Daten. Für die Bestimmung der Kreditwürdigkeit werden nur Daten historische Kontodaten benutzt, die maximal ein halbes Jahr in der Vergangenheit liegen.
#
# *Vorgehensweise kategorische Variablen:*
# - Gruppierung der Variablen

# %% [markdown]
# ## Initialisierung

# %%
from pathlib import Path
from scipy import stats

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

from sklearn.linear_model import LogisticRegression

from IPython.display import display, Markdown

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
pos = pd.read_csv(DATASET_DIR / "POS_CASH_balance.csv")
description = pd.read_csv(DATASET_DIR / "HomeCredit_columns_description.csv", encoding="latin", index_col=0)

# %%
des = description.loc[description['Table']=="POS_CASH_balance.csv", "Row":"Special"]

# %%
des
# Out:
#                        Row  \
# 145            SK_ID_PREV
# 146             SK_ID_CURR
# 147         MONTHS_BALANCE
# 148         CNT_INSTALMENT
# 149  CNT_INSTALMENT_FUTURE
# 150   NAME_CONTRACT_STATUS
# 151                 SK_DPD
# 152             SK_DPD_DEF
#
#                                                                                                                                                                                                                                                         Description  \
# 145                                                                                                               ID of previous credit in Home Credit related to loan in our sample. (One loan in our sample can have 0,1,2 or more previous loans in Home Credit)
# 146                                                                                                                                                                                                                                        ID of loan in our sample
# 147  Month of balance relative to application date (-1 means the information to the freshest monthly snapshot, 0 means the information at application - often it will be the same as -1 as many banks are not updating the information to Credit Bureau regularly )
# 148                                                                                                                                                                                                                  Term of previous credit (can change over time)
# 149                                                                                                                                                                                                                 Installments left to pay on the previous credit
# 150                                                                                                                                                                                                                                Contract status during the month
# 151                                                                                                                                                                                                         DPD (days past due) during the month of previous credit
# 152                                                                                                                                                            DPD during the month with tolerance (debts with low loan amounts are ignored) of the previous credit
#
#                                    Special
# 145                                    NaN
# 146                                    NaN
# 147  time only relative to the application
# 148                                    NaN
# 149                                    NaN
# 150                                    NaN
# 151                                    NaN
# 152                                    NaN

# %% [markdown]
# # Informationsgehalt:
# * Anzahl der restlichen monatlichen Zahlungen die paralell zum aktuellen Kredit noch abbezahlt werden müssen
# * Anzahl an Monaten in denen ein Zahlungsrückstand vorlag

# %%
pos[(pos["SK_ID_PREV"] == 1682318) & (pos["MONTHS_BALANCE"] >= -12)].sort_values("MONTHS_BALANCE")
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 8829991     1682318      161674             -10            10.0
# 4037027     1682318      161674              -9            10.0
# 88351       1682318      161674              -8            10.0
# 9240316     1682318      161674              -7            10.0
# 9021153     1682318      161674              -6            10.0
# 8549983     1682318      161674              -5            10.0
# 9232915     1682318      161674              -4            10.0
# 8419944     1682318      161674              -3            10.0
# 6518430     1682318      161674              -2             8.0
#
#          CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 8829991                   10.0               Active       0           0
# 4037027                    9.0               Active       0           0
# 88351                      8.0               Active       0           0
# 9240316                    7.0               Active       0           0
# 9021153                    6.0               Active       0           0
# 8549983                    5.0               Active       0           0
# 9232915                    4.0               Active       0           0
# 8419944                    3.0               Active       0           0
# 6518430                    0.0            Completed       0           0

# %%
pos[(pos["SK_ID_PREV"] == 1487161) & (pos["MONTHS_BALANCE"] >= -12)].sort_values("MONTHS_BALANCE")
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 1789040     1487161      169489             -12            24.0
# 308815      1487161      169489             -11            24.0
# 3369171     1487161      169489             -10            24.0
# 1741425     1487161      169489              -9            24.0
# 1945738     1487161      169489              -8            24.0
# 4187515     1487161      169489              -7            24.0
# 4461021     1487161      169489              -6            24.0
# 5360357     1487161      169489              -5            24.0
# 1114287     1487161      169489              -4            24.0
# 1702339     1487161      169489              -3            24.0
# 2159186     1487161      169489              -2            24.0
# 105429      1487161      169489              -1            24.0
#
#          CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 1789040                   15.0               Active       0           0
# 308815                    14.0               Active       0           0
# 3369171                   13.0               Active       0           0
# 1741425                   12.0               Active       0           0
# 1945738                   11.0               Active       0           0
# 4187515                   10.0               Active       0           0
# 4461021                    9.0               Active       0           0
# 5360357                    8.0               Active       0           0
# 1114287                    7.0               Active       0           0
# 1702339                    6.0               Active       0           0
# 2159186                    5.0               Active       0           0
# 105429                     4.0               Active       0           0

# %%
df = pos.copy()

# %%
result = pd.DataFrame(index=df.SK_ID_PREV.unique())
result.index.name = "SK_ID_PREV"

# %%
X = df[df["MONTHS_BALANCE"] == -1] # Daten über den letzten Zahlungsmonat
X = X[["SK_ID_PREV", "CNT_INSTALMENT_FUTURE"]]
X = X.set_index("SK_ID_PREV")
X.columns = ["CNT_PAYMENTS_LEFT"]
X.head()
# Out:
#             CNT_PAYMENTS_LEFT
# SK_ID_PREV
# 2373788                  12.0
# 1328586                  10.0
# 1059231                  21.0
# 1627415                   6.0
# 2070143                   5.0

# %%
result = pd.merge(result, X, how="left", left_index=True, right_index=True)

# %% [markdown]
# Zum Zeitpunkt der Kreditaufnahme im Application-Datensatz muss Kreditnehmer 2373788 noch 12 Monatszahlungen für seine POS-Kredite leisten.

# %%
# Anzahl verschuldeter Monate in der Vergangenheit

# %%
X = df[df["MONTHS_BALANCE"] >= -6][["SK_ID_PREV", "SK_DPD_DEF"]]
X = X[["SK_ID_PREV", "SK_DPD_DEF"]]
X = X.groupby(by =["SK_ID_PREV"]).sum()
X.columns = ["CNT_DPD"]
X.head()
# Out:
#             CNT_DPD
# SK_ID_PREV
# 1000003           0
# 1000007           0
# 1000011           0
# 1000017           0
# 1000025           0

# %%
result = pd.merge(result, X, how="left", left_index=True, right_index=True)

# %% [markdown]
# Zum Zeitpunkt der Kreditaufnahme im Application-Datensatz hat Kreditnehmer 1000003 180 Tage zuvor keine Tage mit Zahlungsverzug gehabt.

# %%
result = result.fillna(0)

# %% [markdown]
# ### Ergebnis

# %%
df = result

# %%
df = df.add_prefix("POS_")

# %%
df.head()
# Out:
#             POS_CNT_PAYMENTS_LEFT  POS_CNT_DPD
# SK_ID_PREV
# 1803195                       0.0          0.0
# 1715348                       0.0          0.0
# 1784872                       0.0          0.0
# 1903291                       0.0          0.0
# 2341044                       1.0          0.0

# %% [markdown]
# ### Speichern der Werte

# %%
df.to_csv(DATASET_DIR / "2. Datenaufbereitung" / "pos.csv")

# %%
df.loc[1487161]
# Out:
# POS_CNT_PAYMENTS_LEFT    4.0
# POS_CNT_DPD              0.0
# Name: 1487161, dtype: float64
