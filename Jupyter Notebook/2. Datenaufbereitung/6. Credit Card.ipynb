# %% [markdown]
# ## <u>2. Datenaufbereitung Credit Card

# %% [markdown]
# In diesem Dokument werden für die Untersuchung unwichtige Variablen aus dem CC-Datensatz gelöscht und wichtige gruppiert. Im Gegensatz zu den Application-Daten liegt in dem CC-Datensatz eine N:M-Beziehung vor, da ein Kreditnehmer in der Vergangenheit mehrere Kredite gehabt haben kann und diese monatliche Kreditdaten beinhalten. Dies erfordert die Gruppierung der historischen Daten. Für die Bestimmung der Kreditwürdigkeit werden nur Daten historische Kontodaten benutzt, die maximal ein halbes Jahr in der Vergangenheit liegen. Zur Vergleichbarkeit der Zahlungshöhen im Zeitverlauf werden diese normalisiert.
#
# *Vorgehensweise kategorische Variablen:*
# - Gruppierung der Variablen
# - Normalisierung der Variablen

# %% [markdown]
# ## Initialisierung

# %%
from pathlib import Path
from scipy import stats

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

from sklearn.linear_model import LogisticRegression

from IPython.display import display, Markdown

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
cc = pd.read_csv(DATASET_DIR / "credit_card_balance.csv")
description = pd.read_csv(DATASET_DIR / "HomeCredit_columns_description.csv", encoding="latin", index_col=0)

# %%
des = description.loc[description['Table']=="credit_card_balance.csv", "Row":"Special"]

# %%
des
# Out:
#                             Row  \
# 153                 SK_ID_PREV
# 154                  SK_ID_CURR
# 155              MONTHS_BALANCE
# 156                 AMT_BALANCE
# 157     AMT_CREDIT_LIMIT_ACTUAL
# 158    AMT_DRAWINGS_ATM_CURRENT
# 159        AMT_DRAWINGS_CURRENT
# 160  AMT_DRAWINGS_OTHER_CURRENT
# 161    AMT_DRAWINGS_POS_CURRENT
# 162     AMT_INST_MIN_REGULARITY
# 163         AMT_PAYMENT_CURRENT
# 164   AMT_PAYMENT_TOTAL_CURRENT
# 165    AMT_RECEIVABLE_PRINCIPAL
# 166               AMT_RECIVABLE
# 167        AMT_TOTAL_RECEIVABLE
# 168    CNT_DRAWINGS_ATM_CURRENT
# 169        CNT_DRAWINGS_CURRENT
# 170  CNT_DRAWINGS_OTHER_CURRENT
# 171    CNT_DRAWINGS_POS_CURRENT
# 172   CNT_INSTALMENT_MATURE_CUM
# 173        NAME_CONTRACT_STATUS
# 174                      SK_DPD
# 175                  SK_DPD_DEF
#
#                                                                                                                                            Description  \
# 153  ID of previous credit in Home credit related to loan in our sample. (One loan in our sample can have 0,1,2 or more previous loans in Home Credit)
# 154                                                                                                                           ID of loan in our sample
# 155                                                                 Month of balance relative to application date (-1 means the freshest balance date)
# 156                                                                                                        Balance during the month of previous credit
# 157                                                                                          Credit card limit during the month of the previous credit
# 158                                                                                      Amount drawing at ATM during the month of the previous credit
# 159                                                                                             Amount drawing during the month of the previous credit
# 160                                                                                   Amount of other drawings during the month of the previous credit
# 161                                                                             Amount drawing or buying goods during the month of the previous credit
# 162                                                                                          Minimal installment for this month of the previous credit
# 163                                                                                How much did the client pay during the month on the previous credit
# 164                                                                       How much did the client pay during the month in total on the previous credit
# 165                                                                                             Amount receivable for principal on the previous credit
# 166                                                                                                           Amount receivable on the previous credit
# 167                                                                                                     Total amount receivable on the previous credit
# 168                                                                                 Number of drawings at ATM during this month on the previous credit
# 169                                                                                        Number of drawings during this month on the previous credit
# 170                                                                                  Number of other drawings during this month on the previous credit
# 171                                                                              Number of drawings for goods during this month on the previous credit
# 172                                                                                                 Number of paid installments on the previous credit
# 173                                                                                         Contract status (active signed,...) on the previous credit
# 174                                                                                        DPD (Days past due) during the month on the previous credit
# 175                               DPD (Days past due) during the month with tolerance (debts with low loan amounts are ignored) of the previous credit
#
#                                    Special
# 153                                 hashed
# 154                                 hashed
# 155  time only relative to the application
# 156                                    NaN
# 157                                    NaN
# 158                                    NaN
# 159                                    NaN
# 160                                    NaN
# 161                                    NaN
# 162                                    NaN
# 163                                    NaN
# 164                                    NaN
# 165                                    NaN
# 166                                    NaN
# 167                                    NaN
# 168                                    NaN
# 169                                    NaN
# 170                                    NaN
# 171                                    NaN
# 172                                    NaN
# 173                                    NaN
# 174                                    NaN
# 175                                    NaN

# %%
cc[(cc["SK_ID_PREV"] == 1489084) & (cc["MONTHS_BALANCE"] >= -12)].sort_values("MONTHS_BALANCE")
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 832709      1489084      207482             -12    59059.845
# 2062010     1489084      207482             -11    72011.115
# 1088832     1489084      207482             -10     3942.090
# 1582318     1489084      207482              -9      135.360
# 277673      1489084      207482              -8        0.000
# 3691020     1489084      207482              -7   225000.000
# 2101775     1489084      207482              -6    41915.160
# 1260333     1489084      207482              -5   109375.200
# 517         1489084      207482              -4   146687.445
# 11332       1489084      207482              -3   133284.420
# 1460642     1489084      207482              -2   137173.230
# 1145796     1489084      207482              -1   151726.005
#
#          AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 832709                    225000                   45000.0
# 2062010                   225000                    9000.0
# 1088832                   225000                       0.0
# 1582318                   225000                       0.0
# 277673                    225000                       0.0
# 3691020                   225000                       0.0
# 2101775                   225000                       0.0
# 1260333                   225000                   45000.0
# 517                       225000                       0.0
# 11332                     148500                       0.0
# 1460642                   148500                       0.0
# 1145796                   148500                       0.0
#
#          AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# 832709              45000.000                         0.0
# 2062010             16567.965                         0.0
# 1088832              2965.500                         0.0
# 1582318                 0.000                         0.0
# 277673                  0.000                         0.0
# 3691020            225000.000                         0.0
# 2101775                 0.000                         0.0
# 1260333             66655.800                         0.0
# 517                 39060.000                         0.0
# 11332                   0.000                         0.0
# 1460642                 0.000                         0.0
# 1145796             11475.000                         0.0
#
#          AMT_DRAWINGS_POS_CURRENT  AMT_INST_MIN_REGULARITY  \
# 832709                      0.000                 2250.000
# 2062010                  7567.965                 2963.835
# 1088832                  2965.500                 3612.330
# 1582318                     0.000                 2250.000
# 277673                      0.000                  135.360
# 3691020                225000.000                    0.000
# 2101775                     0.000                11250.000
# 1260333                 21655.800                 2250.000
# 517                     39060.000                 5481.675
# 11332                       0.000                 7238.340
# 1460642                     0.000                 7069.185
# 1145796                 11475.000                 6880.635
#
#          AMT_PAYMENT_CURRENT  AMT_PAYMENT_TOTAL_CURRENT  \
# 832709               2250.00                    2250.00
# 2062010              6750.00                    6750.00
# 1088832             72270.00                   72270.00
# 1582318              4077.45                    4077.45
# 277673                135.36                     135.36
# 3691020                 0.00                       0.00
# 2101775            191250.00                  191250.00
# 1260333              2250.00                    2250.00
# 517                  4500.00                    4500.00
# 11332                9900.00                    9900.00
# 1460642              7200.00                    7200.00
# 1145796                 0.00                       0.00
#
#          AMT_RECEIVABLE_PRINCIPAL  AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  \
# 832709                  56666.475      57714.345             57714.345
# 2062010                 69094.575      70665.615             70665.615
# 1088832                  2941.965       3942.090              3942.090
# 1582318                     0.000          0.000                 0.000
# 277673                      0.000          0.000                 0.000
# 3691020                225000.000     225000.000            225000.000
# 2101775                 33750.000      41915.160             41915.160
# 1260333                100405.800     107804.700            107804.700
# 517                    139465.800     146687.445            146687.445
# 11332                  129466.440     133284.420            133284.420
# 1460642                134183.745     137173.230            137173.230
# 1145796                145658.745     151726.005            151726.005
#
#          CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# 832709                        1.0                     1
# 2062010                       1.0                     5
# 1088832                       0.0                     1
# 1582318                       0.0                     0
# 277673                        0.0                     0
# 3691020                       0.0                     1
# 2101775                       0.0                     0
# 1260333                       1.0                     9
# 517                           0.0                     1
# 11332                         0.0                     0
# 1460642                       0.0                     0
# 1145796                       0.0                     4
#
#          CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# 832709                          0.0                       0.0
# 2062010                         0.0                       4.0
# 1088832                         0.0                       1.0
# 1582318                         0.0                       0.0
# 277673                          0.0                       0.0
# 3691020                         0.0                       1.0
# 2101775                         0.0                       0.0
# 1260333                         0.0                       8.0
# 517                             0.0                       1.0
# 11332                           0.0                       0.0
# 1460642                         0.0                       0.0
# 1145796                         0.0                       4.0
#
#          CNT_INSTALMENT_MATURE_CUM NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 832709                        16.0               Active       0           0
# 2062010                       17.0               Active       0           0
# 1088832                       18.0               Active       0           0
# 1582318                       19.0               Active       0           0
# 277673                        20.0               Active       0           0
# 3691020                       20.0               Active       0           0
# 2101775                       21.0               Active       0           0
# 1260333                       22.0               Active       0           0
# 517                           23.0               Active       7           7
# 11332                         24.0               Active       0           0
# 1460642                       25.0               Active       0           0
# 1145796                       26.0               Active       5           5

# %%
df = cc.copy()

# %% [markdown]
# Aus allen Variablen wurden folgende als wichtig identifiziert:

# %%
df = df[["SK_ID_PREV", "MONTHS_BALANCE", "AMT_BALANCE", "AMT_PAYMENT_CURRENT", "SK_DPD_DEF"]]

# %%
df = df[df["MONTHS_BALANCE"] >= -6]

# %%
df.head()
# Out:
#    SK_ID_PREV  MONTHS_BALANCE  AMT_BALANCE  AMT_PAYMENT_CURRENT  SK_DPD_DEF
# 0     2562384              -6       56.970               1800.0           0
# 1     2582071              -1    63975.555               2250.0           0
# 3     1389973              -4   236572.110              11925.0           0
# 4     1891521              -1   453919.455              27000.0           0
# 6     1079071              -6   353451.645              15750.0           0

# %% [markdown]
# # Informationsgehalt:
# * 6 Monate Kontostand vor Kreditaufnahme
# * 6 Monate Ausgaben vor Kreditaufnahme
# * 6 Monate Summe überzogenen Tage

# %%
T1 = df[df["MONTHS_BALANCE"] == -1][["SK_ID_PREV", "AMT_BALANCE", "AMT_PAYMENT_CURRENT", "SK_DPD_DEF"]]
T2 = df[df["MONTHS_BALANCE"] == -2][["SK_ID_PREV", "AMT_BALANCE", "AMT_PAYMENT_CURRENT", "SK_DPD_DEF"]]
T3 = df[df["MONTHS_BALANCE"] == -3][["SK_ID_PREV", "AMT_BALANCE", "AMT_PAYMENT_CURRENT", "SK_DPD_DEF"]]
T4 = df[df["MONTHS_BALANCE"] == -4][["SK_ID_PREV", "AMT_BALANCE", "AMT_PAYMENT_CURRENT", "SK_DPD_DEF"]]
T5 = df[df["MONTHS_BALANCE"] == -5][["SK_ID_PREV", "AMT_BALANCE", "AMT_PAYMENT_CURRENT", "SK_DPD_DEF"]]
T6 = df[df["MONTHS_BALANCE"] == -6][["SK_ID_PREV", "AMT_BALANCE", "AMT_PAYMENT_CURRENT", "SK_DPD_DEF"]]

# %%
T1 = T1.groupby(by="SK_ID_PREV").sum()
T1.columns = ["BALANCE_30", "PAYMENT_30", "DPD_30"]

T2 = T2.groupby(by="SK_ID_PREV").sum()
T2.columns = ["BALANCE_60", "PAYMENT_60", "DPD_60"]

T3 = T3.groupby(by="SK_ID_PREV").sum()
T3.columns = ["BALANCE_90", "PAYMENT_90", "DPD_90"]

T4 = T4.groupby(by="SK_ID_PREV").sum()
T4.columns = ["BALANCE_120", "PAYMENT_120", "DPD_120"]

T5 = T5.groupby(by="SK_ID_PREV").sum()
T5.columns = ["BALANCE_150", "PAYMENT_150", "DPD_150"]

T6 = T6.groupby(by="SK_ID_PREV").sum()
T6.columns = ["BALANCE_180", "PAYMENT_180", "DPD_180"]

# %%
result = pd.DataFrame(index=df.SK_ID_PREV.unique())
result.index.name = "SK_ID_PREV"

# %%
result = pd.merge(result, T1, how="left", left_index=True, right_index=True)
result = pd.merge(result, T2, how="left", left_index=True, right_index=True)
result = pd.merge(result, T3, how="left", left_index=True, right_index=True)
result = pd.merge(result, T4, how="left", left_index=True, right_index=True)
result = pd.merge(result, T5, how="left", left_index=True, right_index=True)
result = pd.merge(result, T6, how="left", left_index=True, right_index=True)

# %%
result = result.fillna(0)

# %%
df = result

# %%
df.head()
# Out:
#             BALANCE_30  PAYMENT_30  DPD_30  BALANCE_60  PAYMENT_60  DPD_60  \
# SK_ID_PREV
# 2562384          0.000         0.0     0.0      28.575     1916.91     0.0
# 2582071      63975.555      2250.0     0.0   61124.625     2250.00     0.0
# 1389973     234919.845     11925.0     0.0  235687.860    11925.00     0.0
# 1891521     453919.455     27000.0     0.0  458497.395    27000.00     0.0
# 1079071     322906.140     18000.0     0.0  329464.845    18000.00     0.0
#
#             BALANCE_90  PAYMENT_90  DPD_90  BALANCE_120  PAYMENT_120  DPD_120  \
# SK_ID_PREV
# 2562384       1897.875      2250.0     0.0     4036.860       2250.0      0.0
# 2582071      61615.395      2250.0     0.0    62129.475       4500.0      0.0
# 1389973     236129.040     11925.0     0.0   236572.110      11925.0      0.0
# 1891521     461330.505     27000.0     0.0   457896.285      27000.0      0.0
# 1079071     335538.270     18000.0     0.0   342236.340      18000.0      0.0
#
#             BALANCE_150  PAYMENT_150  DPD_150  BALANCE_180  PAYMENT_180  \
# SK_ID_PREV
# 2562384        5228.280        841.5      0.0       56.970       1800.0
# 2582071       64634.985          0.0      1.0    62856.405       4500.0
# 1389973      237204.945      12150.0      0.0   237884.130      11250.0
# 1891521      459959.130      27000.0      0.0   457992.720      27000.0
# 1079071      347929.335      18000.0      0.0   353451.645      15750.0
#
#             DPD_180
# SK_ID_PREV
# 2562384         0.0
# 2582071         0.0
# 1389973         0.0
# 1891521         0.0
# 1079071         0.0

# %% [markdown]
# ### Normalisierung

# %%
# BALANCE

# %%
balance_heads = [head for head in df.columns.values if "BALANCE" in head]

# %%
df["BALANCE_MEAN"] = df[balance_heads].mean(axis=1)
df["BALANCE_STD"] = df[balance_heads].std(axis=1)

# %%
for head in balance_heads:
    df[head] = (df[head]-df["BALANCE_MEAN"])/df["BALANCE_STD"]

# %%
# PAYMENT

# %%
payment_heads = [head for head in df.columns.values if "PAYMENT" in head]

# %%
df["PAYMENT_MEAN"] = df[payment_heads].mean(axis=1)
df["PAYMENT_STD"] = df[payment_heads].std(axis=1)

# %%
for head in payment_heads:
    df[head] = (df[head]-df["PAYMENT_MEAN"])/df["PAYMENT_STD"]

# %%
df = df.drop(["BALANCE_MEAN", "BALANCE_STD", "PAYMENT_MEAN", "PAYMENT_STD"], axis=1)

# %% [markdown]
# ### Ergebnis

# %%
df = df.add_prefix("CC_")

# %%
df.head()
# Out:
#             CC_BALANCE_30  CC_PAYMENT_30  CC_DPD_30  CC_BALANCE_60  \
# SK_ID_PREV
# 2562384         -0.819794      -1.672973        0.0      -0.807299
# 2582071          0.914866      -0.221404        0.0      -1.167021
# 1389973         -1.391888       0.243975        0.0      -0.669504
# 1891521         -1.734005            NaN        0.0       0.092348
# 1079071         -1.364959       0.408248        0.0      -0.794077
#
#             CC_PAYMENT_60  CC_DPD_60  CC_BALANCE_90  CC_PAYMENT_90  CC_DPD_90  \
# SK_ID_PREV
# 2562384          0.451200        0.0       0.010108       0.820305        0.0
# 2582071         -0.221404        0.0      -0.808637      -0.221404        0.0
# 1389973          0.243975        0.0      -0.254537       0.243975        0.0
# 1891521               NaN        0.0       1.222608            NaN        0.0
# 1079071          0.408248        0.0      -0.265434       0.408248        0.0
#
#             CC_BALANCE_120  CC_PAYMENT_120  CC_DPD_120  CC_BALANCE_150  \
# SK_ID_PREV
# 2562384           0.945442        0.820305         0.0        1.466426
# 2582071          -0.433231        1.107019         0.0        1.396414
# 1389973           0.162209        0.243975         0.0        0.757444
# 1891521          -0.147463             NaN         0.0        0.675502
# 1079071           0.317579        0.408248         0.0        0.813109
#
#             CC_PAYMENT_150  CC_DPD_150  CC_BALANCE_180  CC_PAYMENT_180  \
# SK_ID_PREV
# 2562384          -0.740487         0.0       -0.794882        0.321649
# 2582071          -1.549826         1.0        0.097609        1.107019
# 1389973           0.975900         0.0        1.396276       -1.951800
# 1891521                NaN         0.0       -0.108990             NaN
# 1079071           0.408248         0.0        1.293782       -2.041241
#
#             CC_DPD_180
# SK_ID_PREV
# 2562384            0.0
# 2582071            0.0
# 1389973            0.0
# 1891521            0.0
# 1079071            0.0

# %% [markdown]
# ### Speichern der metrischen Werte

# %%
df.to_csv(DATASET_DIR / "2. Datenaufbereitung" / "cc.csv")
