# %% [markdown]
# ## 2. Datenaufbereitung Previous Application

# %%
from pathlib import Path
from scipy import stats

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

from sklearn.linear_model import LogisticRegression

from IPython.display import display, Markdown

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
app_train = pd.read_csv(DATASET_DIR / "application_train.csv")
pa = pd.read_csv(DATASET_DIR / "previous_application.csv")
description = pd.read_csv(DATASET_DIR / "HomeCredit_columns_description.csv", encoding="latin", index_col=0)

# %%
des = description.loc[description['Table']=="previous_application.csv", "Row":"Special"]

# %%
des
# Out:
#                              Row  \
# 176                  SK_ID_PREV
# 177                   SK_ID_CURR
# 178           NAME_CONTRACT_TYPE
# 179                  AMT_ANNUITY
# 180              AMT_APPLICATION
# 181                   AMT_CREDIT
# 182             AMT_DOWN_PAYMENT
# 183              AMT_GOODS_PRICE
# 184   WEEKDAY_APPR_PROCESS_START
# 185      HOUR_APPR_PROCESS_START
# 186  FLAG_LAST_APPL_PER_CONTRACT
# 187       NFLAG_LAST_APPL_IN_DAY
# 188             NFLAG_MICRO_CASH
# 189            RATE_DOWN_PAYMENT
# 190        RATE_INTEREST_PRIMARY
# 191     RATE_INTEREST_PRIVILEGED
# 192       NAME_CASH_LOAN_PURPOSE
# 193         NAME_CONTRACT_STATUS
# 194                DAYS_DECISION
# 195            NAME_PAYMENT_TYPE
# 196           CODE_REJECT_REASON
# 197              NAME_TYPE_SUITE
# 198             NAME_CLIENT_TYPE
# 199          NAME_GOODS_CATEGORY
# 200               NAME_PORTFOLIO
# 201            NAME_PRODUCT_TYPE
# 202                 CHANNEL_TYPE
# ...

# %%
pa = pd.merge(pa, app_train[["SK_ID_CURR","TARGET"]] ,on="SK_ID_CURR")

# %%
pa.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     1696966      271877     Consumer loans    68258.655        1800000.0
# 2     2154916      271877     Consumer loans    12417.390         108400.5
# 3     2802425      108129         Cash loans    25188.615         607500.0
# 4     1536272      108129         Cash loans    21709.125         450000.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1   1754721.0          180000.0        1800000.0                   SATURDAY
# 2    119848.5               0.0         108400.5                     SUNDAY
# 3    679671.0               NaN         607500.0                   THURSDAY
# 4    512370.0               NaN         450000.0                  WEDNESDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  \
# ...

# %%
# Spalten die innerhalb der Aufbereitung nicht verändert werden können
skip = ["TARGET", "SK_ID_CURR", "SK_ID_PREV"]

# %%
# nominale und metrische Spalten
n_heads = [element for element in pa.columns if pa[element].dtype.name == "object"]
n_heads += ["NFLAG_LAST_APPL_IN_DAY", "NFLAG_INSURED_ON_APPROVAL"]

m_heads = [element for element in pa.columns if element not in n_heads]

# %% [markdown]
# ### kategorische Variablen

# %%
df = pa[["SK_ID_CURR", "TARGET"] + n_heads].copy()

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE WEEKDAY_APPR_PROCESS_START  \
# 0      271877       0     Consumer loans                   SATURDAY
# 1      271877       0     Consumer loans                   SATURDAY
# 2      271877       0     Consumer loans                     SUNDAY
# 3      108129       0         Cash loans                   THURSDAY
# 4      108129       0         Cash loans                  WEDNESDAY
#
#   FLAG_LAST_APPL_PER_CONTRACT NAME_CASH_LOAN_PURPOSE NAME_CONTRACT_STATUS  \
# 0                           Y                    XAP             Approved
# 1                           Y                    XAP              Refused
# 2                           Y                    XAP             Approved
# 3                           Y                    XNA             Approved
# 4                           Y                    XNA             Approved
#
#        NAME_PAYMENT_TYPE CODE_REJECT_REASON NAME_TYPE_SUITE NAME_CLIENT_TYPE  \
# ...

# %% [markdown]
# ### Löschung der Spalten mit weniger als 40% ausgefüllten Daten

# %%
result = {
          "header":[],
          "rate":[],
          "des":[]
         }
for key in df.keys():
    if key in skip:
        continue
    rate = df[key].isna().sum() / len(df[key]) * 100
    if rate > 60:
        result["header"].append(key)
        result["rate"].append(rate)
        result["des"].append(des[des["Row"] == key]["Description"])

result = pd.DataFrame(result)
result
# Out:
# Empty DataFrame
# Columns: [header, rate, des]
# Index: []

# %%
df = df.drop(result.header.values, axis=1)

# %% [markdown]
# ### Bildung von Korrelationsclustern

# %%
c = df.corr(method='spearman') * 100

# %%
families = []
for i, row in c.iterrows():
    r = row[row > 70]
    if len(r) > 1 and set(r.index) not in families:
        print(r)
        print("\n")
        
        families.append(set(r.index))

# %%
result = {
          "family":[],
          "head":[],
          "r2":[],
          "na":[],
          "rate":[]
         }

for i, family in enumerate(families):
    headers = list(family)
    
    result["family"].append("")
    result["head"].append("")
    result["r2"].append("")
    result["na"].append("")
    result["rate"].append("")
    
    for head in headers:
        d = df[["TARGET"] + [head]]
        na = d[head].isna().sum() / len(d) * 100
        d = d.dropna()
        x = d[[head]]
        y = d[["TARGET"]]
        model = LogisticRegression().fit(x, y.values.ravel())
        r2 = round(model.score(x,y),5)
        
        result["family"].append(i)
        result["head"].append(head)
        result["r2"].append(round(r2,5))
        result["na"].append(round(na,2))
        result["rate"].append(r2/na)
    
result = pd.DataFrame(result)
result
# Out:
# Empty DataFrame
# Columns: [family, head, r2, na, rate]
# Index: []

# %% [markdown]
# ### Unterscheidbarkeit von mindestens 5pP einer Kategorie

# %%
ID_Payback = df[df["TARGET"] == 0].index.values
ID_Default = df[df["TARGET"] == 1].index.values

# %%
payback = df.loc[ID_Payback]
default = df.loc[ID_Default]

# %%
result = {
    "head" : [],
    "cat" : [],
    "payback" : [],
    "default" : [],
    "diff" : []
}

for head in df.columns.values:
    df1 = payback[head].value_counts().rename_axis(head).reset_index(name='payback').head()
    df2 = default[head].value_counts().rename_axis(head).reset_index(name='default').head()
    
    df1["payback"] = df1["payback"]/df1["payback"].sum()*100
    df2["default"] = df2["default"]/df2["default"].sum()*100
    
    df_ = df1.merge(df2, how="outer", on=head)
    
    df_["diff"] = (df_["default"]-df_["payback"])
    
    df_ = df_.sort_values("diff", ascending=False)
    
    for diff in df_["diff"]:
        if np.isnan(diff):
            continue
        if diff > 5 or diff < -5:
            row = df_.loc[df_["diff"] == diff]
            cat = row[head][row[head].index[0]]
            
            result["head"].append(head)
            result["cat"].append(cat)
            result["payback"].append(round(row["payback"].values[0],2))
            result["default"].append(round(row["default"].values[0],2))
            result["diff"].append(round(diff,2))

result = pd.DataFrame(result)
result.sort_values("diff", ascending=False)
# Out:
#                    head             cat  payback  default  diff
# 1  NAME_CONTRACT_STATUS         Refused    16.72    24.06  7.34
# 0    NAME_CONTRACT_TYPE  Consumer loans    44.69    39.40 -5.29
# 4        NAME_PORTFOLIO             POS    42.38    36.97 -5.40
# 3    CODE_REJECT_REASON             XAP    82.68    76.05 -6.63
# 2  NAME_CONTRACT_STATUS        Approved    63.41    54.96 -8.46

# %%
remove = [head for head in df.columns.values if head not in list(result["head"].unique()) + skip]

# %%
df = df.drop(remove, axis=1)

# %%
df = df.drop(["TARGET"], axis=1)

# %% [markdown]
# ### Erstellungen der Variablen:
# * Anzahl abgelehnte Kredite
# * Anzahl angenommene Kredite
# * Anzahl Konsumentenkredite
# * Anzahl POS Kredite
# * Anzahl Ablehnungsgrund XAP

# %%
df["NAME_CONTRACT_STATUS"].value_counts()
# Out:
# Approved        886099
# Canceled        259441
# Refused         245390
# Unused offer     22771
# Name: NAME_CONTRACT_STATUS, dtype: int64

# %%
df["NAME_CONTRACT_TYPE"].value_counts()
# Out:
# Cash loans         626764
# Consumer loans     625256
# Revolving loans    161368
# XNA                   313
# Name: NAME_CONTRACT_TYPE, dtype: int64

# %%
df["NAME_PORTFOLIO"].value_counts()
# Out:
# POS      592460
# Cash     391663
# XNA      307213
# Cards    121985
# Cars        380
# Name: NAME_PORTFOLIO, dtype: int64

# %%
df["CODE_REJECT_REASON"].value_counts()
# Out:
# XAP       1145533
# HC         145984
# LIMIT       47773
# SCO         32636
# CLIENT      22771
# SCOFR       10875
# XNA          4378
# VERIF        3079
# SYSTEM        672
# Name: CODE_REJECT_REASON, dtype: int64

# %%
df[df["NAME_CONTRACT_STATUS"] == "Approved"].head()
# Out:
#    SK_ID_CURR NAME_CONTRACT_TYPE NAME_CONTRACT_STATUS CODE_REJECT_REASON  \
# 0      271877     Consumer loans             Approved                XAP
# 2      271877     Consumer loans             Approved                XAP
# 3      108129         Cash loans             Approved                XAP
# 4      108129         Cash loans             Approved                XAP
# 5      108129     Consumer loans             Approved                XAP
#
#   NAME_PORTFOLIO
# 0            POS
# 2            POS
# 3           Cash
# 4           Cash
# 5            POS

# %%
approved = df[df["NAME_CONTRACT_STATUS"] == "Approved"]
approved = approved[["SK_ID_CURR", "NAME_CONTRACT_STATUS"]].groupby(by="SK_ID_CURR").count()
approved.columns = ["Approved"]

refused = df[df["NAME_CONTRACT_STATUS"] == "Refused"]
refused = refused[["SK_ID_CURR", "NAME_CONTRACT_STATUS"]].groupby(by="SK_ID_CURR").count()
refused.columns = ["Refused"]

consumer = df[df["NAME_CONTRACT_TYPE"] == "Consumer loans"]
consumer = consumer[["SK_ID_CURR", "NAME_CONTRACT_TYPE"]].groupby(by="SK_ID_CURR").count()
consumer.columns = ["Consumer loans"]

pos = df[df["NAME_PORTFOLIO"] == "POS"]
pos = pos[["SK_ID_CURR", "NAME_PORTFOLIO"]].groupby(by="SK_ID_CURR").count()
pos.columns = ["POS"]

xap = df[df["NAME_CONTRACT_STATUS"] == "XAP"]
xap = xap[["SK_ID_CURR", "NAME_CONTRACT_STATUS"]].groupby(by="SK_ID_CURR").count()
xap.columns = ["XAP"]

# %%
df = pd.DataFrame(index=app_train.SK_ID_CURR)
df.index.name = "SK_ID_CURR"

df = pd.merge(df, approved, how="left", left_index=True, right_index=True)
df = pd.merge(df, refused, how="left", left_index=True, right_index=True)
df = pd.merge(df, consumer, how="left", left_index=True, right_index=True)
df = pd.merge(df, pos, how="left", left_index=True, right_index=True)
df = pd.merge(df, xap, how="left", left_index=True, right_index=True)
df = df.fillna(0)

# %%
df.head()
# Out:
#             Approved  Refused  Consumer loans  POS  XAP
# SK_ID_CURR
# 100002           1.0      0.0             1.0  1.0  0.0
# 100003           3.0      0.0             2.0  2.0  0.0
# 100004           1.0      0.0             1.0  1.0  0.0
# 100006           5.0      1.0             2.0  2.0  0.0
# 100007           6.0      0.0             2.0  2.0  0.0

# %% [markdown]
# ### resultierende Variablen

# %%
result = {
    "head":[],
    "des":[]
}

for head in df.columns.values:
    if head in skip:
        continue
    result["head"].append(head)
    result["des"].append(des[des["Row"] == head]["Description"])
    
result = pd.DataFrame(result)
result
# Out:
#              head                                           des
# 0        Approved  Series([], Name: Description, dtype: object)
# 1         Refused  Series([], Name: Description, dtype: object)
# 2  Consumer loans  Series([], Name: Description, dtype: object)
# 3             POS  Series([], Name: Description, dtype: object)
# 4             XAP  Series([], Name: Description, dtype: object)

# %% [markdown]
# ### Speichern der kategorischen Werte

# %%
df.to_csv(DATASET_DIR / "2. Datenaufbereitung" / "pa_cats.csv")

# %% [markdown]
# ### metrische Variablen

# %%
df = pa[m_heads].copy()

# %%
df.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  AMT_ANNUITY  AMT_APPLICATION  AMT_CREDIT  \
# 0     2030495      271877     1730.430          17145.0     17145.0
# 1     1696966      271877    68258.655        1800000.0   1754721.0
# 2     2154916      271877    12417.390         108400.5    119848.5
# 3     2802425      108129    25188.615         607500.0    679671.0
# 4     1536272      108129    21709.125         450000.0    512370.0
#
#    AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  HOUR_APPR_PROCESS_START  \
# 0               0.0          17145.0                       15
# 1          180000.0        1800000.0                       18
# 2               0.0         108400.5                       14
# 3               NaN         607500.0                       11
# 4               NaN         450000.0                        9
#
#    RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  RATE_INTEREST_PRIVILEGED  \
# 0           0.000000               0.182832                  0.867336
# ...

# %% [markdown]
# ### Löschung der Spalten mit weniger als 40% ausgefüllten Daten

# %%
result = {
          "header":[],
          "rate":[],
          "des":[]
         }
for key in df.keys():
    if key in skip:
        continue
    rate = df[key].isna().sum() / len(df[key]) * 100
    if rate > 60:
        result["header"].append(key)
        result["rate"].append(rate)
        result["des"].append(des[des["Row"] == key]["Description"])

result = pd.DataFrame(result)
result
# Out:
#                      header       rate  \
# 0     RATE_INTEREST_PRIMARY  99.661102
# 1  RATE_INTEREST_PRIVILEGED  99.661102
#
#                                                                                    des
# 0  190    Interest rate normalized on previous credit
# Name: Description, dtype: object
# 1  191    Interest rate normalized on previous credit
# Name: Description, dtype: object

# %%
df = df.drop(result.header.values, axis=1)

# %% [markdown]
# ### Bildung von Korrelationsclustern

# %%
c = df.corr(method='pearson') * 100

# %%
families = []
for i, row in c.iterrows():
    r = row[row > 70]
    if len(r) > 1 and set(r.index) not in families:
        print(r)
        print("\n")
        
        families.append(set(r.index))
# Out:
# AMT_ANNUITY        100.000000
# AMT_APPLICATION     80.997240
# AMT_CREDIT          81.797711
# AMT_GOODS_PRICE     82.220444
# Name: AMT_ANNUITY, dtype: float64
#
#
# DAYS_LAST_DUE       100.000000
# DAYS_TERMINATION     92.774092
# Name: DAYS_LAST_DUE, dtype: float64

# %%
result = {
          "family":[],
          "head":[],
          "r2":[],
          "na":[],
          "rate":[]
         }

for i, family in enumerate(families):
    headers = list(family)
    
    result["family"].append("")
    result["head"].append("")
    result["r2"].append("")
    result["na"].append("")
    result["rate"].append("")
    
    for head in headers:
        d = df[["TARGET"] + [head]]
        na = d[head].isna().sum() / len(d) * 100
        d = d.dropna()
        x = d[[head]]
        y = d[["TARGET"]]
        model = LogisticRegression().fit(x, y.values.ravel())
        r2 = round(model.score(x,y),5)
        
        result["family"].append(i)
        result["head"].append(head)
        result["r2"].append(round(r2,5))
        result["na"].append(round(na,2))
        result["rate"].append(r2/na)
    
result = pd.DataFrame(result)
result
# Out:
# <ipython-input-39-51063d21f81e>:31: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
#   family              head       r2     na        rate
# 0
# 1      0       AMT_ANNUITY  0.91647  21.73   0.0421725
# 2      0   AMT_APPLICATION  0.91345      0         inf
# 3      0        AMT_CREDIT  0.91345      0     12913.5
# 4      0   AMT_GOODS_PRICE  0.91615   22.6    0.040534
# 5
# 6      1  DAYS_TERMINATION  0.26514  39.69  0.00668018
# 7      1     DAYS_LAST_DUE  0.25198  39.69  0.00634861

# %%
df = df.drop(["AMT_CREDIT", "AMT_GOODS_PRICE", "AMT_ANNUITY", "DAYS_LAST_DUE"], axis=1)

# %%
df.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  AMT_APPLICATION  AMT_DOWN_PAYMENT  \
# 0     2030495      271877          17145.0               0.0
# 1     1696966      271877        1800000.0          180000.0
# 2     2154916      271877         108400.5               0.0
# 3     2802425      108129         607500.0               NaN
# 4     1536272      108129         450000.0               NaN
#
#    HOUR_APPR_PROCESS_START  RATE_DOWN_PAYMENT  DAYS_DECISION  \
# 0                       15           0.000000            -73
# 1                       18           0.101325           -472
# 2                       14           0.000000           -548
# 3                       11                NaN           -164
# 4                        9                NaN           -515
#
#    SELLERPLACE_AREA  CNT_PAYMENT  DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  \
# 0                35         12.0            365243.0           -42.0
# 1                55         36.0                 NaN             NaN
# ...

# %% [markdown]
# ### Betrachtung der Kausalität

# %%
result = {
    "head":[],
    "des":[]
}

for head in df.columns.values:
    if head in skip:
        continue
    result["head"].append(head)
    result["des"].append(des[des["Row"] == head]["Description"])
    
result = pd.DataFrame(result)
result
# Out:
#                          head  \
# 0             AMT_APPLICATION
# 1            AMT_DOWN_PAYMENT
# 2     HOUR_APPR_PROCESS_START
# 3           RATE_DOWN_PAYMENT
# 4               DAYS_DECISION
# 5            SELLERPLACE_AREA
# 6                 CNT_PAYMENT
# 7          DAYS_FIRST_DRAWING
# 8              DAYS_FIRST_DUE
# 9   DAYS_LAST_DUE_1ST_VERSION
# 10           DAYS_TERMINATION
#
#                                                                                                                                                               des
# 0                                                          180    For how much credit did client ask on the previous application
# Name: Description, dtype: object
# 1                                                                                182    Down payment on the previous application
# Name: Description, dtype: object
# ...

# %%
df = df.drop(["TARGET", "HOUR_APPR_PROCESS_START"], axis=1)

# %% [markdown]
# ### Ergebnis

# %%
df.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  AMT_APPLICATION  AMT_DOWN_PAYMENT  \
# 0     2030495      271877          17145.0               0.0
# 1     1696966      271877        1800000.0          180000.0
# 2     2154916      271877         108400.5               0.0
# 3     2802425      108129         607500.0               NaN
# 4     1536272      108129         450000.0               NaN
#
#    RATE_DOWN_PAYMENT  DAYS_DECISION  SELLERPLACE_AREA  CNT_PAYMENT  \
# 0           0.000000            -73                35         12.0
# 1           0.101325           -472                55         36.0
# 2           0.000000           -548               196         12.0
# 3                NaN           -164                -1         36.0
# 4                NaN           -515                 6         36.0
#
#    DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  DAYS_LAST_DUE_1ST_VERSION  \
# 0            365243.0           -42.0                      300.0
# ...

# %% [markdown]
# ### Speichern der metrischen Werte

# %%
df.to_csv(DATASET_DIR / "2. Datenaufbereitung" / "pa_mets.csv")
