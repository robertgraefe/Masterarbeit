# %% [markdown]
# ## 2. Datenaufbereitung Application

# %%
from pathlib import Path
from scipy import stats

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

from sklearn.linear_model import LogisticRegression

from IPython.display import display, Markdown

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
app_train = pd.read_csv(DATASET_DIR / "application_train.csv", index_col="SK_ID_CURR")
description = pd.read_csv(DATASET_DIR / "HomeCredit_columns_description.csv", encoding="latin", index_col=0)

# %%
des = description.loc[description['Table']=="application_{train|test}.csv", "Row":"Special"]

# %%
app_train.head()
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M            N
# 100003           0         Cash loans           F            N
# 100004           0    Revolving loans           M            Y
# 100006           0         Cash loans           F            N
# 100007           0         Cash loans           M            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                   Y             0          202500.0    406597.5
# 100003                   N             0          270000.0   1293502.5
# 100004                   Y             0           67500.0    135000.0
# 100006                   Y             0          135000.0    312682.5
# 100007                   Y             0          121500.0    513000.0
#
#             AMT_ANNUITY  AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# SK_ID_CURR
# 100002          24700.5         351000.0   Unaccompanied          Working
# 100003          35698.5        1129500.0          Family    State servant
# 100004           6750.0         135000.0   Unaccompanied          Working
# 100006          29686.5         297000.0   Unaccompanied          Working
# 100007          21865.5         513000.0   Unaccompanied          Working
#
#                       NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# SK_ID_CURR
# 100002      Secondary / secondary special  Single / not married
# 100003                   Higher education               Married
# 100004      Secondary / secondary special  Single / not married
# 100006      Secondary / secondary special        Civil marriage
# 100007      Secondary / secondary special  Single / not married
#
#             NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# SK_ID_CURR
# 100002      House / apartment                    0.018801       -9461
# 100003      House / apartment                    0.003541      -16765
# 100004      House / apartment                    0.010032      -19046
# 100006      House / apartment                    0.008019      -19005
# 100007      House / apartment                    0.028663      -19932
#
#             DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  \
# SK_ID_CURR
# 100002               -637            -3648.0            -2120          NaN
# 100003              -1188            -1186.0             -291          NaN
# 100004               -225            -4260.0            -2531         26.0
# 100006              -3039            -9833.0            -2437          NaN
# 100007              -3038            -4311.0            -3458          NaN
#
#             FLAG_MOBIL  FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  \
# SK_ID_CURR
# 100002               1               1                0                 1
# 100003               1               1                0                 1
# 100004               1               1                1                 1
# 100006               1               1                0                 1
# 100007               1               1                0                 1
#
#             FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# SK_ID_CURR
# 100002               1           0        Laborers              1.0
# 100003               1           0      Core staff              2.0
# 100004               1           0        Laborers              1.0
# 100006               0           0        Laborers              2.0
# 100007               0           0      Core staff              1.0
#
#             REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# SK_ID_CURR
# 100002                         2                            2
# 100003                         1                            1
# 100004                         2                            2
# 100006                         2                            2
# 100007                         2                            2
#
#            WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  \
# SK_ID_CURR
# 100002                      WEDNESDAY                       10
# 100003                         MONDAY                       11
# 100004                         MONDAY                        9
# 100006                      WEDNESDAY                       17
# 100007                       THURSDAY                       11
#
#             REG_REGION_NOT_LIVE_REGION  REG_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100002                               0                           0
# 100003                               0                           0
# 100004                               0                           0
# 100006                               0                           0
# 100007                               0                           0
#
#             LIVE_REGION_NOT_WORK_REGION  REG_CITY_NOT_LIVE_CITY  \
# SK_ID_CURR
# 100002                                0                       0
# 100003                                0                       0
# 100004                                0                       0
# 100006                                0                       0
# 100007                                0                       0
#
#             REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100002                           0                        0
# 100003                           0                        0
# 100004                           0                        0
# 100006                           0                        0
# 100007                           1                        1
#
#                  ORGANIZATION_TYPE  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# SK_ID_CURR
# 100002      Business Entity Type 3      0.083037      0.262949      0.139376
# 100003                      School      0.311267      0.622246           NaN
# 100004                  Government           NaN      0.555912      0.729567
# 100006      Business Entity Type 3           NaN      0.650442           NaN
# 100007                    Religion           NaN      0.322738           NaN
#
#             APARTMENTS_AVG  BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  \
# SK_ID_CURR
# 100002              0.0247            0.0369                       0.9722
# 100003              0.0959            0.0529                       0.9851
# 100004                 NaN               NaN                          NaN
# 100006                 NaN               NaN                          NaN
# 100007                 NaN               NaN                          NaN
#
#             YEARS_BUILD_AVG  COMMONAREA_AVG  ELEVATORS_AVG  ENTRANCES_AVG  \
# SK_ID_CURR
# 100002               0.6192          0.0143           0.00         0.0690
# 100003               0.7960          0.0605           0.08         0.0345
# 100004                  NaN             NaN            NaN            NaN
# 100006                  NaN             NaN            NaN            NaN
# 100007                  NaN             NaN            NaN            NaN
#
#             FLOORSMAX_AVG  FLOORSMIN_AVG  LANDAREA_AVG  LIVINGAPARTMENTS_AVG  \
# SK_ID_CURR
# 100002             0.0833         0.1250        0.0369                0.0202
# 100003             0.2917         0.3333        0.0130                0.0773
# 100004                NaN            NaN           NaN                   NaN
# 100006                NaN            NaN           NaN                   NaN
# 100007                NaN            NaN           NaN                   NaN
#
#             LIVINGAREA_AVG  NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  \
# SK_ID_CURR
# 100002              0.0190                   0.0000             0.0000
# 100003              0.0549                   0.0039             0.0098
# 100004                 NaN                      NaN                NaN
# 100006                 NaN                      NaN                NaN
# 100007                 NaN                      NaN                NaN
#
#             APARTMENTS_MODE  BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  \
# SK_ID_CURR
# 100002               0.0252             0.0383                        0.9722
# 100003               0.0924             0.0538                        0.9851
# 100004                  NaN                NaN                           NaN
# 100006                  NaN                NaN                           NaN
# 100007                  NaN                NaN                           NaN
#
#             YEARS_BUILD_MODE  COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  \
# SK_ID_CURR
# 100002                0.6341           0.0144          0.0000          0.0690
# 100003                0.8040           0.0497          0.0806          0.0345
# 100004                   NaN              NaN             NaN             NaN
# 100006                   NaN              NaN             NaN             NaN
# 100007                   NaN              NaN             NaN             NaN
#
#             FLOORSMAX_MODE  FLOORSMIN_MODE  LANDAREA_MODE  \
# SK_ID_CURR
# 100002              0.0833          0.1250         0.0377
# 100003              0.2917          0.3333         0.0128
# 100004                 NaN             NaN            NaN
# 100006                 NaN             NaN            NaN
# 100007                 NaN             NaN            NaN
#
#             LIVINGAPARTMENTS_MODE  LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  \
# SK_ID_CURR
# 100002                      0.022           0.0198                       0.0
# 100003                      0.079           0.0554                       0.0
# 100004                        NaN              NaN                       NaN
# 100006                        NaN              NaN                       NaN
# 100007                        NaN              NaN                       NaN
#
#             NONLIVINGAREA_MODE  APARTMENTS_MEDI  BASEMENTAREA_MEDI  \
# SK_ID_CURR
# 100002                     0.0           0.0250             0.0369
# 100003                     0.0           0.0968             0.0529
# 100004                     NaN              NaN                NaN
# 100006                     NaN              NaN                NaN
# 100007                     NaN              NaN                NaN
#
#             YEARS_BEGINEXPLUATATION_MEDI  YEARS_BUILD_MEDI  COMMONAREA_MEDI  \
# SK_ID_CURR
# 100002                            0.9722            0.6243           0.0144
# 100003                            0.9851            0.7987           0.0608
# 100004                               NaN               NaN              NaN
# 100006                               NaN               NaN              NaN
# 100007                               NaN               NaN              NaN
#
#             ELEVATORS_MEDI  ENTRANCES_MEDI  FLOORSMAX_MEDI  FLOORSMIN_MEDI  \
# SK_ID_CURR
# 100002                0.00          0.0690          0.0833          0.1250
# 100003                0.08          0.0345          0.2917          0.3333
# 100004                 NaN             NaN             NaN             NaN
# 100006                 NaN             NaN             NaN             NaN
# 100007                 NaN             NaN             NaN             NaN
#
#             LANDAREA_MEDI  LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  \
# SK_ID_CURR
# 100002             0.0375                 0.0205           0.0193
# 100003             0.0132                 0.0787           0.0558
# 100004                NaN                    NaN              NaN
# 100006                NaN                    NaN              NaN
# 100007                NaN                    NaN              NaN
#
#             NONLIVINGAPARTMENTS_MEDI  NONLIVINGAREA_MEDI FONDKAPREMONT_MODE  \
# SK_ID_CURR
# 100002                        0.0000                0.00   reg oper account
# 100003                        0.0039                0.01   reg oper account
# 100004                           NaN                 NaN                NaN
# 100006                           NaN                 NaN                NaN
# 100007                           NaN                 NaN                NaN
#
#             HOUSETYPE_MODE  TOTALAREA_MODE WALLSMATERIAL_MODE  \
# SK_ID_CURR
# 100002      block of flats          0.0149       Stone, brick
# 100003      block of flats          0.0714              Block
# 100004                 NaN             NaN                NaN
# 100006                 NaN             NaN                NaN
# 100007                 NaN             NaN                NaN
#
#            EMERGENCYSTATE_MODE  OBS_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                      No                       2.0
# 100003                      No                       1.0
# 100004                     NaN                       0.0
# 100006                     NaN                       2.0
# 100007                     NaN                       0.0
#
#             DEF_30_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100003                           0.0                       1.0
# 100004                           0.0                       0.0
# 100006                           0.0                       2.0
# 100007                           0.0                       0.0
#
#             DEF_60_CNT_SOCIAL_CIRCLE  DAYS_LAST_PHONE_CHANGE  FLAG_DOCUMENT_2  \
# SK_ID_CURR
# 100002                           2.0                 -1134.0                0
# 100003                           0.0                  -828.0                0
# 100004                           0.0                  -815.0                0
# 100006                           0.0                  -617.0                0
# 100007                           0.0                 -1106.0                0
#
#             FLAG_DOCUMENT_3  FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  \
# SK_ID_CURR
# 100002                    1                0                0
# 100003                    1                0                0
# 100004                    0                0                0
# 100006                    1                0                0
# 100007                    0                0                0
#
#             FLAG_DOCUMENT_6  FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  \
# SK_ID_CURR
# 100002                    0                0                0
# 100003                    0                0                0
# 100004                    0                0                0
# 100006                    0                0                0
# 100007                    0                0                1
#
#             FLAG_DOCUMENT_9  FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  \
# SK_ID_CURR
# 100002                    0                 0                 0
# 100003                    0                 0                 0
# 100004                    0                 0                 0
# 100006                    0                 0                 0
# 100007                    0                 0                 0
#
#             FLAG_DOCUMENT_12  FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_15  FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_21  AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100002                     0                         0.0
# 100003                     0                         0.0
# 100004                     0                         0.0
# 100006                     0                         NaN
# 100007                     0                         0.0
#
#             AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# SK_ID_CURR
# 100002                            0.0                         0.0
# 100003                            0.0                         0.0
# 100004                            0.0                         0.0
# 100006                            NaN                         NaN
# 100007                            0.0                         0.0
#
#             AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# SK_ID_CURR
# 100002                            0.0                        0.0
# 100003                            0.0                        0.0
# 100004                            0.0                        0.0
# 100006                            NaN                        NaN
# 100007                            0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR
# 100002                             1.0
# 100003                             0.0
# 100004                             0.0
# 100006                             NaN
# 100007                             0.0

# %%
# Spalten die innerhalb der Aufbereitung nicht verändert werden können
skip = ["TARGET", "SK_ID_CURR"]

# %%
# nominale und metrische Spalten
n_heads = ['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'WEEKDAY_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21']
o_heads = ["CNT_CHILDREN", "CNT_FAM_MEMBERS", "HOUR_APPR_PROCESS_START", "OBS_30_CNT_SOCIAL_CIRCLE", "DEF_30_CNT_SOCIAL_CIRCLE", "OBS_60_CNT_SOCIAL_CIRCLE", "DEF_60_CNT_SOCIAL_CIRCLE", "AMT_REQ_CREDIT_BUREAU_HOUR", "AMT_REQ_CREDIT_BUREAU_DAY", "AMT_REQ_CREDIT_BUREAU_WEEK", "AMT_REQ_CREDIT_BUREAU_MON", "AMT_REQ_CREDIT_BUREAU_QRT", "AMT_REQ_CREDIT_BUREAU_YEAR"]
m_heads = [head for head in app_train.columns.values if head not in n_heads and head not in o_heads]

# %% [markdown]
# ### kategorische Variablen

# %%
df = app_train[n_heads + o_heads].copy()

# %%
df.head()
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M            N
# 100003           0         Cash loans           F            N
# 100004           0    Revolving loans           M            Y
# 100006           0         Cash loans           F            N
# 100007           0         Cash loans           M            N
#
#            FLAG_OWN_REALTY NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# SK_ID_CURR
# 100002                   Y   Unaccompanied          Working
# 100003                   N          Family    State servant
# 100004                   Y   Unaccompanied          Working
# 100006                   Y   Unaccompanied          Working
# 100007                   Y   Unaccompanied          Working
#
#                       NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# SK_ID_CURR
# 100002      Secondary / secondary special  Single / not married
# 100003                   Higher education               Married
# 100004      Secondary / secondary special  Single / not married
# 100006      Secondary / secondary special        Civil marriage
# 100007      Secondary / secondary special  Single / not married
#
#             NAME_HOUSING_TYPE  FLAG_MOBIL  FLAG_EMP_PHONE  FLAG_WORK_PHONE  \
# SK_ID_CURR
# 100002      House / apartment           1               1                0
# 100003      House / apartment           1               1                0
# 100004      House / apartment           1               1                1
# 100006      House / apartment           1               1                0
# 100007      House / apartment           1               1                0
#
#             FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# SK_ID_CURR
# 100002                     1           1           0        Laborers
# 100003                     1           1           0      Core staff
# 100004                     1           1           0        Laborers
# 100006                     1           0           0        Laborers
# 100007                     1           0           0      Core staff
#
#             REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# SK_ID_CURR
# 100002                         2                            2
# 100003                         1                            1
# 100004                         2                            2
# 100006                         2                            2
# 100007                         2                            2
#
#            WEEKDAY_APPR_PROCESS_START  REG_REGION_NOT_LIVE_REGION  \
# SK_ID_CURR
# 100002                      WEDNESDAY                           0
# 100003                         MONDAY                           0
# 100004                         MONDAY                           0
# 100006                      WEDNESDAY                           0
# 100007                       THURSDAY                           0
#
#             REG_REGION_NOT_WORK_REGION  LIVE_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100002                               0                            0
# 100003                               0                            0
# 100004                               0                            0
# 100006                               0                            0
# 100007                               0                            0
#
#             REG_CITY_NOT_LIVE_CITY  REG_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100002                           0                       0
# 100003                           0                       0
# 100004                           0                       0
# 100006                           0                       0
# 100007                           0                       1
#
#             LIVE_CITY_NOT_WORK_CITY       ORGANIZATION_TYPE  \
# SK_ID_CURR
# 100002                            0  Business Entity Type 3
# 100003                            0                  School
# 100004                            0              Government
# 100006                            0  Business Entity Type 3
# 100007                            1                Religion
#
#            FONDKAPREMONT_MODE  HOUSETYPE_MODE WALLSMATERIAL_MODE  \
# SK_ID_CURR
# 100002       reg oper account  block of flats       Stone, brick
# 100003       reg oper account  block of flats              Block
# 100004                    NaN             NaN                NaN
# 100006                    NaN             NaN                NaN
# 100007                    NaN             NaN                NaN
#
#            EMERGENCYSTATE_MODE  FLAG_DOCUMENT_2  FLAG_DOCUMENT_3  \
# SK_ID_CURR
# 100002                      No                0                1
# 100003                      No                0                1
# 100004                     NaN                0                0
# 100006                     NaN                0                1
# 100007                     NaN                0                0
#
#             FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  FLAG_DOCUMENT_6  \
# SK_ID_CURR
# 100002                    0                0                0
# 100003                    0                0                0
# 100004                    0                0                0
# 100006                    0                0                0
# 100007                    0                0                0
#
#             FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  FLAG_DOCUMENT_9  \
# SK_ID_CURR
# 100002                    0                0                0
# 100003                    0                0                0
# 100004                    0                0                0
# 100006                    0                0                0
# 100007                    0                1                0
#
#             FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  FLAG_DOCUMENT_12  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  FLAG_DOCUMENT_15  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  FLAG_DOCUMENT_18  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             CNT_CHILDREN  CNT_FAM_MEMBERS  HOUR_APPR_PROCESS_START  \
# SK_ID_CURR
# 100002                 0              1.0                       10
# 100003                 0              2.0                       11
# 100004                 0              1.0                        9
# 100006                 0              2.0                       17
# 100007                 0              1.0                       11
#
#             OBS_30_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100003                           1.0                       0.0
# 100004                           0.0                       0.0
# 100006                           2.0                       0.0
# 100007                           0.0                       0.0
#
#             OBS_60_CNT_SOCIAL_CIRCLE  DEF_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100003                           1.0                       0.0
# 100004                           0.0                       0.0
# 100006                           2.0                       0.0
# 100007                           0.0                       0.0
#
#             AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# SK_ID_CURR
# 100002                             0.0                        0.0
# 100003                             0.0                        0.0
# 100004                             0.0                        0.0
# 100006                             NaN                        NaN
# 100007                             0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# SK_ID_CURR
# 100002                             0.0                        0.0
# 100003                             0.0                        0.0
# 100004                             0.0                        0.0
# 100006                             NaN                        NaN
# 100007                             0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR
# 100002                            0.0                         1.0
# 100003                            0.0                         0.0
# 100004                            0.0                         0.0
# 100006                            NaN                         NaN
# 100007                            0.0                         0.0

# %% [markdown]
# ### Löschung der Spalten mit weniger als 40% ausgefüllten Daten

# %%
result = {
          "header":[],
          "rate":[],
          "des":[]
         }
for key in df.keys():
    if key in skip:
        continue
    rate = df[key].isna().sum() / len(df[key]) * 100
    
    if rate > 60:
        result["header"].append(key)
        result["rate"].append(rate)
        result["des"].append(des[des["Row"] == key]["Description"])

result = pd.DataFrame(result)
result
# Out:
#                header       rate  \
# 0  FONDKAPREMONT_MODE  68.386172
#
#                                                                                                                                                                                                                                                                                                                            des
# 0  89    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object

# %%
df = df.drop(result.header.values, axis=1)

# %% [markdown]
# ### Bildung von Korrelationsclustern

# %% [markdown]
# #### nominale Daten

# %%
def contingency_corr(df, head_1, head_2):
    
    data = pd.crosstab(df[head_1], df[head_2], margins = False)
    
    sum_cols = data.sum(axis=0)
    sum_rows = data.sum(axis=1)
    sum_all = data.sum().sum()
    
    n = data.to_numpy()
    n = n.reshape(1,-1).squeeze()
    
    e = []
    for row in sum_rows:
        for col in sum_cols:
            e.append(row * col / sum_all)
    e = np.array(e)
    
    chi2 = (np.subtract(n, e)**2 / e).sum()
    
    K = np.sqrt(chi2/(sum_all+chi2))
    
    i = min(data.shape)
    i = (i-1)/i
    i = np.sqrt(i)
    
    K_ = K / i
    
    return K_

# %%
n_heads = [head for head in df.columns.values if head in n_heads]
result = {}
for head1 in n_heads:
    row = []
    for head2 in n_heads:
        corr = contingency_corr(df, head1, head2)
        row.append(corr)
    result[head1] = row
c = pd.DataFrame(result, index=n_heads) * 100
# Out:
# <ipython-input-12-945362e94b6c>:26: RuntimeWarning: invalid value encountered in double_scalars
#   K_ = K / i
# <ipython-input-12-945362e94b6c>:26: RuntimeWarning: invalid value encountered in double_scalars
#   K_ = K / i

# %%
families = []
for i, row in c.iterrows():
    r = row[row > 70]
    if len(r) > 1 and set(r.index) not in families:
        families.append(set(r.index))

for A in families:
    for B in families:
        if A == B:
            continue
        if A.issubset(B):
            families.remove(A)
families
# Out:
# [{'OCCUPATION_TYPE', 'ORGANIZATION_TYPE'},
#  {'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY'},
#  {'LIVE_REGION_NOT_WORK_REGION', 'REG_REGION_NOT_WORK_REGION'},
#  {'LIVE_CITY_NOT_WORK_CITY', 'REG_CITY_NOT_WORK_CITY'},
#  {'FLAG_DOCUMENT_6',
#   'FLAG_EMP_PHONE',
#   'NAME_INCOME_TYPE',
#   'OCCUPATION_TYPE',
#   'ORGANIZATION_TYPE'}]

# %%
result = {
          "family":[],
          "head":[],
          "r2":[],
          "na":[],
          "rate":[]
         }

for i, family in enumerate(families):
    headers = list(family)
    
    result["family"].append("")
    result["head"].append("")
    result["r2"].append("")
    result["na"].append("")
    result["rate"].append("")
    
    for head in headers:
        d = df[["TARGET"] + [head]]
        d.loc[:,head], cats = pd.factorize(d.loc[:,head])
        na = d[head].isna().sum() / len(d) * 100
        d = d.dropna()
        y = d[["TARGET"]]
        x = d[[head]]
        
        model = LogisticRegression().fit(x, y.values.ravel())
        r2 = round(model.score(x,y),5)
        
        result["family"].append(i)
        result["head"].append(head)
        result["r2"].append(round(r2,5))
        result["na"].append(round(na,2))
        result["rate"].append(r2/na)
    
result = pd.DataFrame(result)
# Out:
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# a:\workspace\python\masterarbeit\venv\lib\site-packages\pandas\core\indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# <ipython-input-15-5fa29037c272>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)

# %%
result
# Out:
#    family                         head       r2 na rate
# 0
# 1       0            ORGANIZATION_TYPE  0.91927  0  inf
# 2       0              OCCUPATION_TYPE  0.91927  0  inf
# 3
# 4       1  REGION_RATING_CLIENT_W_CITY  0.91927  0  inf
# 5       1         REGION_RATING_CLIENT  0.91927  0  inf
# 6
# 7       2  LIVE_REGION_NOT_WORK_REGION  0.91927  0  inf
# 8       2   REG_REGION_NOT_WORK_REGION  0.91927  0  inf
# 9
# 10      3      LIVE_CITY_NOT_WORK_CITY  0.91927  0  inf
# 11      3       REG_CITY_NOT_WORK_CITY  0.91927  0  inf
# 12
# 13      4             NAME_INCOME_TYPE  0.91927  0  inf
# 14      4              OCCUPATION_TYPE  0.91927  0  inf
# 15      4              FLAG_DOCUMENT_6  0.91927  0  inf
# 16      4            ORGANIZATION_TYPE  0.91927  0  inf
# 17      4               FLAG_EMP_PHONE  0.91927  0  inf

# %%
keep = ["NAME_INCOME_TYPE", "OCCUPATION_TYPE", "REGION_RATING_CLIENT", "REG_REGION_NOT_WORK_REGION", "REG_CITY_NOT_WORK_CITY"]

# %%
remove = [head for head in result["head"].values if head not in [""] + keep]

# %%
len(remove)
# Out:
# 7

# %%
df = df.drop(remove, axis=1)

# %% [markdown]
# #### ordinale Daten

# %%
c = df[o_heads].corr(method='spearman') * 100

# %%
families = []
for i, row in c.iterrows():
    r = row[row > 70]
    if len(r) > 1 and set(r.index) not in families:
        families.append(set(r.index))

for A in families:
    for B in families:
        if A == B:
            continue
        if A.issubset(B):
            families.remove(A)
families
# Out:
# [{'CNT_CHILDREN', 'CNT_FAM_MEMBERS'},
#  {'OBS_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE'},
#  {'DEF_30_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE'}]

# %%
result = {
          "family":[],
          "head":[],
          "r2":[],
          "na":[],
          "rate":[]
         }

for i, family in enumerate(families):
    headers = list(family)
    
    result["family"].append("")
    result["head"].append("")
    result["r2"].append("")
    result["na"].append("")
    result["rate"].append("")
    
    for head in headers:
        d = df[["TARGET"] + [head]]
        na = d[head].isna().sum() / len(d) * 100
        d = d.dropna()
        y = d[["TARGET"]]
        x = d[[head]]
        
        model = LogisticRegression().fit(x, y.values.ravel())
        r2 = round(model.score(x,y),5)
        
        result["family"].append(i)
        result["head"].append(head)
        result["r2"].append(round(r2,5))
        result["na"].append(round(na,2))
        result["rate"].append(r2/na)
    
result = pd.DataFrame(result)
# Out:
# <ipython-input-23-586a910cb784>:32: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)

# %%
result
# Out:
#   family                      head       r2    na     rate
# 0
# 1      0              CNT_CHILDREN  0.91927     0      inf
# 2      0           CNT_FAM_MEMBERS  0.91927     0  1413.43
# 3
# 4      1  OBS_60_CNT_SOCIAL_CIRCLE  0.91912  0.33  2.76826
# 5      1  OBS_30_CNT_SOCIAL_CIRCLE  0.91912  0.33  2.76826
# 6
# 7      2  DEF_30_CNT_SOCIAL_CIRCLE  0.91912  0.33  2.76826
# 8      2  DEF_60_CNT_SOCIAL_CIRCLE  0.91912  0.33  2.76826

# %%
remove = ["CNT_FAM_MEMBERS", "OBS_30_CNT_SOCIAL_CIRCLE", "DEF_60_CNT_SOCIAL_CIRCLE"]

# %%
len(remove)
# Out:
# 3

# %%
df = df.drop(remove, axis=1)

# %% [markdown]
# ### Unterscheidbarkeit von mindestens 5pP einer Kategorie

# %%
ID_Payback = app_train[app_train["TARGET"] == 0].index.values
ID_Default = app_train[app_train["TARGET"] == 1].index.values

# %%
payback = df.loc[ID_Payback]
default = df.loc[ID_Default]

# %%
result = {
    "head" : [],
    "cat" : [],
    "payback" : [],
    "default" : [],
    "diff" : []
}

for head in df.columns.values:
    df1 = payback[head].value_counts().rename_axis(head).reset_index(name='payback')
    df2 = default[head].value_counts().rename_axis(head).reset_index(name='default')
    
    df1["payback"] = df1["payback"]/df1["payback"].sum()*100
    df2["default"] = df2["default"]/df2["default"].sum()*100
    
    df_ = df1.merge(df2, how="outer", on=head)
    
    df_["diff"] = (df_["default"]-df_["payback"])
    
    df_ = df_.sort_values("diff", ascending=False)
    
    for diff in df_["diff"]:
        if np.isnan(diff):
            continue
        if diff > 5 or diff < -5:
            row = df_.loc[df_["diff"] == diff]
            cat = row[head][row[head].index[0]]
            
            result["head"].append(head)
            result["cat"].append(cat)
            result["payback"].append(round(row["payback"].values[0],2))
            result["default"].append(round(row["default"].values[0],2))
            result["diff"].append(round(diff,2))

result = pd.DataFrame(result)
result.sort_values("diff", ascending=False)
# Out:
#                       head                            cat  payback  default  \
# 2         NAME_INCOME_TYPE                        Working    50.78    61.33
# 0              CODE_GENDER                              M    33.40    42.92
# 4      NAME_EDUCATION_TYPE  Secondary / secondary special    70.35    78.65
# 8   REG_CITY_NOT_WORK_CITY                              1    22.41    30.29
# 10         FLAG_DOCUMENT_3                              1    70.41    77.79
# 7     REGION_RATING_CLIENT                              3    15.20    21.62
# 6          OCCUPATION_TYPE                       Laborers    25.63    31.48
# 3         NAME_INCOME_TYPE                      Pensioner    18.53    12.01
# 11         FLAG_DOCUMENT_3                              0    29.59    22.21
# 9   REG_CITY_NOT_WORK_CITY                              0    77.59    69.71
# 5      NAME_EDUCATION_TYPE               Higher education    25.06    16.15
# 1              CODE_GENDER                              F    66.60    57.08
#
#      diff
# 2   10.54
# 0    9.53
# 4    8.30
# 8    7.88
# 10   7.39
# 7    6.42
# 6    5.85
# 3   -6.52
# 11  -7.39
# 9   -7.88
# 5   -8.92
# 1   -9.52

# %%
remove = [head for head in df.columns.values if head not in list(result["head"].unique()) + skip]

# %%
df = df.drop(remove, axis=1)

# %% [markdown]
# ### Transformation von Kategorien in numerische Werte

# %%
# transformiert kategorische variablen in integer
for head in df.columns.values:
    df[head], cats = pd.factorize(df[head])

# %% [markdown]
# ### resultierende Variablen

# %%
result = {
    "head":[],
    "des":[]
}

for head in df.columns.values:
    if head in skip:
        continue
    result["head"].append(head)
    result["des"].append(des[des["Row"] == head]["Description"])
    
result = pd.DataFrame(result)
result
# Out:
#                      head  \
# 0             CODE_GENDER
# 1        NAME_INCOME_TYPE
# 2     NAME_EDUCATION_TYPE
# 3         OCCUPATION_TYPE
# 4    REGION_RATING_CLIENT
# 5  REG_CITY_NOT_WORK_CITY
# 6         FLAG_DOCUMENT_3
#
#                                                                                                                                           des
# 0                                                                                  6    Gender of the client
# Name: Description, dtype: object
# 1                                        15    Clients income type (businessman, working, maternity leave,
# )
# Name: Description, dtype: object
# 2                                                       16    Level of highest education the client achieved
# Name: Description, dtype: object
# 3                                                         31    What kind of occupation does the client have
# Name: Description, dtype: object
# 4                                                  33    Our rating of the region where client lives (1,2,3)
# Name: Description, dtype: object
# 5  41    Flag if client's permanent address does not match work address (1=different, 0=same, at city level)
# Name: Description, dtype: object
# 6                                                                       100    Did client provide document 3
# Name: Description, dtype: object

# %%
df = df.add_prefix("A_")

# %%
df = df.rename(columns={"A_TARGET": "TARGET"})

# %%
df.head()
# Out:
#             TARGET  A_CODE_GENDER  A_NAME_INCOME_TYPE  A_NAME_EDUCATION_TYPE  \
# SK_ID_CURR
# 100002           0              0                   0                      0
# 100003           1              1                   1                      1
# 100004           1              0                   0                      0
# 100006           1              1                   0                      0
# 100007           1              0                   0                      0
#
#             A_OCCUPATION_TYPE  A_REGION_RATING_CLIENT  \
# SK_ID_CURR
# 100002                      0                       0
# 100003                      1                       1
# 100004                      0                       0
# 100006                      0                       0
# 100007                      1                       0
#
#             A_REG_CITY_NOT_WORK_CITY  A_FLAG_DOCUMENT_3
# SK_ID_CURR
# 100002                             0                  0
# 100003                             0                  0
# 100004                             0                  1
# 100006                             0                  0
# 100007                             1                  1

# %% [markdown]
# ### Speichern der kategorischen Werte

# %%
cats = df

# %% [markdown]
# ### metrische Variablen

# %%
df = app_train[["TARGET"] + m_heads].copy()

# %%
df.head()
# Out:
#             TARGET  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# 100002           1          202500.0    406597.5      24700.5
# 100003           0          270000.0   1293502.5      35698.5
# 100004           0           67500.0    135000.0       6750.0
# 100006           0          135000.0    312682.5      29686.5
# 100007           0          121500.0    513000.0      21865.5
#
#             AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# SK_ID_CURR
# 100002             351000.0                    0.018801       -9461
# 100003            1129500.0                    0.003541      -16765
# 100004             135000.0                    0.010032      -19046
# 100006             297000.0                    0.008019      -19005
# 100007             513000.0                    0.028663      -19932
#
#             DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  \
# SK_ID_CURR
# 100002               -637            -3648.0            -2120          NaN
# 100003              -1188            -1186.0             -291          NaN
# 100004               -225            -4260.0            -2531         26.0
# 100006              -3039            -9833.0            -2437          NaN
# 100007              -3038            -4311.0            -3458          NaN
#
#             EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  APARTMENTS_AVG  \
# SK_ID_CURR
# 100002          0.083037      0.262949      0.139376          0.0247
# 100003          0.311267      0.622246           NaN          0.0959
# 100004               NaN      0.555912      0.729567             NaN
# 100006               NaN      0.650442           NaN             NaN
# 100007               NaN      0.322738           NaN             NaN
#
#             BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  YEARS_BUILD_AVG  \
# SK_ID_CURR
# 100002                0.0369                       0.9722           0.6192
# 100003                0.0529                       0.9851           0.7960
# 100004                   NaN                          NaN              NaN
# 100006                   NaN                          NaN              NaN
# 100007                   NaN                          NaN              NaN
#
#             COMMONAREA_AVG  ELEVATORS_AVG  ENTRANCES_AVG  FLOORSMAX_AVG  \
# SK_ID_CURR
# 100002              0.0143           0.00         0.0690         0.0833
# 100003              0.0605           0.08         0.0345         0.2917
# 100004                 NaN            NaN            NaN            NaN
# 100006                 NaN            NaN            NaN            NaN
# 100007                 NaN            NaN            NaN            NaN
#
#             FLOORSMIN_AVG  LANDAREA_AVG  LIVINGAPARTMENTS_AVG  LIVINGAREA_AVG  \
# SK_ID_CURR
# 100002             0.1250        0.0369                0.0202          0.0190
# 100003             0.3333        0.0130                0.0773          0.0549
# 100004                NaN           NaN                   NaN             NaN
# 100006                NaN           NaN                   NaN             NaN
# 100007                NaN           NaN                   NaN             NaN
#
#             NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  APARTMENTS_MODE  \
# SK_ID_CURR
# 100002                       0.0000             0.0000           0.0252
# 100003                       0.0039             0.0098           0.0924
# 100004                          NaN                NaN              NaN
# 100006                          NaN                NaN              NaN
# 100007                          NaN                NaN              NaN
#
#             BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  YEARS_BUILD_MODE  \
# SK_ID_CURR
# 100002                 0.0383                        0.9722            0.6341
# 100003                 0.0538                        0.9851            0.8040
# 100004                    NaN                           NaN               NaN
# 100006                    NaN                           NaN               NaN
# 100007                    NaN                           NaN               NaN
#
#             COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  FLOORSMAX_MODE  \
# SK_ID_CURR
# 100002               0.0144          0.0000          0.0690          0.0833
# 100003               0.0497          0.0806          0.0345          0.2917
# 100004                  NaN             NaN             NaN             NaN
# 100006                  NaN             NaN             NaN             NaN
# 100007                  NaN             NaN             NaN             NaN
#
#             FLOORSMIN_MODE  LANDAREA_MODE  LIVINGAPARTMENTS_MODE  \
# SK_ID_CURR
# 100002              0.1250         0.0377                  0.022
# 100003              0.3333         0.0128                  0.079
# 100004                 NaN            NaN                    NaN
# 100006                 NaN            NaN                    NaN
# 100007                 NaN            NaN                    NaN
#
#             LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_MODE  \
# SK_ID_CURR
# 100002               0.0198                       0.0                 0.0
# 100003               0.0554                       0.0                 0.0
# 100004                  NaN                       NaN                 NaN
# 100006                  NaN                       NaN                 NaN
# 100007                  NaN                       NaN                 NaN
#
#             APARTMENTS_MEDI  BASEMENTAREA_MEDI  YEARS_BEGINEXPLUATATION_MEDI  \
# SK_ID_CURR
# 100002               0.0250             0.0369                        0.9722
# 100003               0.0968             0.0529                        0.9851
# 100004                  NaN                NaN                           NaN
# 100006                  NaN                NaN                           NaN
# 100007                  NaN                NaN                           NaN
#
#             YEARS_BUILD_MEDI  COMMONAREA_MEDI  ELEVATORS_MEDI  ENTRANCES_MEDI  \
# SK_ID_CURR
# 100002                0.6243           0.0144            0.00          0.0690
# 100003                0.7987           0.0608            0.08          0.0345
# 100004                   NaN              NaN             NaN             NaN
# 100006                   NaN              NaN             NaN             NaN
# 100007                   NaN              NaN             NaN             NaN
#
#             FLOORSMAX_MEDI  FLOORSMIN_MEDI  LANDAREA_MEDI  \
# SK_ID_CURR
# 100002              0.0833          0.1250         0.0375
# 100003              0.2917          0.3333         0.0132
# 100004                 NaN             NaN            NaN
# 100006                 NaN             NaN            NaN
# 100007                 NaN             NaN            NaN
#
#             LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  NONLIVINGAPARTMENTS_MEDI  \
# SK_ID_CURR
# 100002                     0.0205           0.0193                    0.0000
# 100003                     0.0787           0.0558                    0.0039
# 100004                        NaN              NaN                       NaN
# 100006                        NaN              NaN                       NaN
# 100007                        NaN              NaN                       NaN
#
#             NONLIVINGAREA_MEDI  TOTALAREA_MODE  DAYS_LAST_PHONE_CHANGE
# SK_ID_CURR
# 100002                    0.00          0.0149                 -1134.0
# 100003                    0.01          0.0714                  -828.0
# 100004                     NaN             NaN                  -815.0
# 100006                     NaN             NaN                  -617.0
# 100007                     NaN             NaN                 -1106.0

# %% [markdown]
# ### Löschung der Spalten mit weniger als 40% ausgefüllten Daten

# %%
result = {
          "header":[],
          "rate":[],
          "des":[]
         }
for key in df.keys():
    if key in skip:
        continue
    rate = df[key].isna().sum() / len(df[key]) * 100
    if rate > 60:
        result["header"].append(key)
        result["rate"].append(rate)
        result["des"].append(des[des["Row"] == key]["Description"])

result = pd.DataFrame(result)
result
# Out:
#                       header       rate  \
# 0                OWN_CAR_AGE  65.990810
# 1            YEARS_BUILD_AVG  66.497784
# 2             COMMONAREA_AVG  69.872297
# 3              FLOORSMIN_AVG  67.848630
# 4       LIVINGAPARTMENTS_AVG  68.354953
# 5    NONLIVINGAPARTMENTS_AVG  69.432963
# 6           YEARS_BUILD_MODE  66.497784
# 7            COMMONAREA_MODE  69.872297
# 8             FLOORSMIN_MODE  67.848630
# 9      LIVINGAPARTMENTS_MODE  68.354953
# 10  NONLIVINGAPARTMENTS_MODE  69.432963
# 11          YEARS_BUILD_MEDI  66.497784
# 12           COMMONAREA_MEDI  69.872297
# 13            FLOORSMIN_MEDI  67.848630
# 14     LIVINGAPARTMENTS_MEDI  68.354953
# 15  NONLIVINGAPARTMENTS_MEDI  69.432963
#
#                                                                                                                                                                                                                                                                                                                             des
# 0                                                                                                                                                                                                                                                                    24    Age of client's car
# Name: Description, dtype: object
# 1   50    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 2   51    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 3   55    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 4   57    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 5   59    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 6   64    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 7   65    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 8   69    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 9   71    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 10  73    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 11  78    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 12  79    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 13  83    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 14  85    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 15  87    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object

# %%
df = df.drop(result.header.values, axis=1)

# %% [markdown]
# ### Bildung von Korrelationsclustern

# %%
c = df.corr(method='pearson') * 100

# %%
families = []
for i, row in c.iterrows():
    r = row[row > 70]
    if len(r) > 1 and set(r.index) not in families:
        families.append(set(r.index))

for A in families:
    for B in families:
        if A == B:
            continue
        if A.issubset(B):
            families.remove(A)
families
# Out:
# [{'AMT_ANNUITY', 'AMT_CREDIT', 'AMT_GOODS_PRICE'},
#  {'APARTMENTS_AVG',
#   'APARTMENTS_MEDI',
#   'APARTMENTS_MODE',
#   'ELEVATORS_AVG',
#   'ELEVATORS_MEDI',
#   'ELEVATORS_MODE',
#   'LIVINGAREA_AVG',
#   'LIVINGAREA_MEDI',
#   'LIVINGAREA_MODE',
#   'TOTALAREA_MODE'},
#  {'BASEMENTAREA_AVG', 'BASEMENTAREA_MEDI', 'BASEMENTAREA_MODE'},
#  {'YEARS_BEGINEXPLUATATION_AVG',
#   'YEARS_BEGINEXPLUATATION_MEDI',
#   'YEARS_BEGINEXPLUATATION_MODE'},
#  {'ENTRANCES_AVG', 'ENTRANCES_MEDI', 'ENTRANCES_MODE'},
#  {'FLOORSMAX_AVG', 'FLOORSMAX_MEDI', 'FLOORSMAX_MODE'},
#  {'LANDAREA_AVG', 'LANDAREA_MEDI', 'LANDAREA_MODE'},
#  {'NONLIVINGAREA_AVG', 'NONLIVINGAREA_MEDI', 'NONLIVINGAREA_MODE'}]

# %%
result = {
          "family":[],
          "head":[],
          "r2":[],
          "na":[],
          "rate":[]
         }

for i, family in enumerate(families):
    headers = list(family)
    
    result["family"].append("")
    result["head"].append("")
    result["r2"].append("")
    result["na"].append("")
    result["rate"].append("")
    
    for head in headers:
        d = df[["TARGET"] + [head]]
        na = d[head].isna().sum() / len(d) * 100
        d = d.dropna()
        y = d[["TARGET"]]
        x = d[[head]]
        
        model = LogisticRegression().fit(x, y.values.ravel())
        r2 = round(model.score(x,y),5)
        
        result["family"].append(i)
        result["head"].append(head)
        result["r2"].append(round(r2,5))
        result["na"].append(round(na,2))
        result["rate"].append(r2/na)
    
result = pd.DataFrame(result)
# Out:
# <ipython-input-45-586a910cb784>:32: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)

# %%
result
# Out:
#    family                          head       r2     na       rate
# 0
# 1       0                    AMT_CREDIT  0.91927      0        inf
# 2       0               AMT_GOODS_PRICE  0.91927   0.09    10.1685
# 3       0                   AMT_ANNUITY  0.91927      0    235.571
# 4
# 5       1               LIVINGAREA_MODE  0.93005  50.19  0.0185294
# 6       1                 ELEVATORS_AVG    0.931   53.3  0.0174685
# 7       1                ELEVATORS_MEDI    0.931   53.3  0.0174685
# 8       1               APARTMENTS_MODE  0.93041  50.75  0.0183333
# 9       1               LIVINGAREA_MEDI  0.93005  50.19  0.0185294
# 10      1               APARTMENTS_MEDI  0.93041  50.75  0.0183333
# 11      1                ELEVATORS_MODE    0.931   53.3  0.0174685
# 12      1                TOTALAREA_MODE   0.9301  48.27  0.0192693
# 13      1                APARTMENTS_AVG  0.93041  50.75  0.0183333
# 14      1                LIVINGAREA_AVG  0.93005  50.19  0.0185294
# 15
# 16      2              BASEMENTAREA_AVG  0.93112  58.52  0.0159122
# 17      2             BASEMENTAREA_MODE  0.93112  58.52  0.0159122
# 18      2             BASEMENTAREA_MEDI  0.93112  58.52  0.0159122
# 19
# 20      3   YEARS_BEGINEXPLUATATION_AVG  0.93005  48.78  0.0190658
# 21      3  YEARS_BEGINEXPLUATATION_MEDI  0.93005  48.78  0.0190658
# 22      3  YEARS_BEGINEXPLUATATION_MODE  0.93005  48.78  0.0190658
# 23
# 24      4                ENTRANCES_MODE  0.93048  50.35  0.0184807
# 25      4                 ENTRANCES_AVG  0.93048  50.35  0.0184807
# 26      4                ENTRANCES_MEDI  0.93048  50.35  0.0184807
# 27
# 28      5                FLOORSMAX_MODE  0.93035  49.76  0.0186964
# 29      5                 FLOORSMAX_AVG  0.93035  49.76  0.0186964
# 30      5                FLOORSMAX_MEDI  0.93035  49.76  0.0186964
# 31
# 32      6                  LANDAREA_AVG  0.93019  59.38  0.0156659
# 33      6                 LANDAREA_MODE  0.93019  59.38  0.0156659
# 34      6                 LANDAREA_MEDI  0.93019  59.38  0.0156659
# 35
# 36      7            NONLIVINGAREA_MODE  0.93111  55.18  0.0168743
# 37      7            NONLIVINGAREA_MEDI  0.93111  55.18  0.0168743
# 38      7             NONLIVINGAREA_AVG  0.93111  55.18  0.0168743

# %%
keep = ["AMT_CREDIT", "TOTALAREA_MODE", "BASEMENTAREA_AVG", "YEARS_BEGINEXPLUATATION_AVG", "ENTRANCES_AVG", "FLOORSMAX_AVG", "LANDAREA_AVG", "NONLIVINGAREA_AVG"]

# %%
remove = [head for head in list(result["head"]) if head not in keep + [""]]

# %%
len(remove)
# Out:
# 23

# %%
df = df.drop(remove, axis=1)

# %%
df.head()
# Out:
#             TARGET  AMT_INCOME_TOTAL  AMT_CREDIT  REGION_POPULATION_RELATIVE  \
# SK_ID_CURR
# 100002           1          202500.0    406597.5                    0.018801
# 100003           0          270000.0   1293502.5                    0.003541
# 100004           0           67500.0    135000.0                    0.010032
# 100006           0          135000.0    312682.5                    0.008019
# 100007           0          121500.0    513000.0                    0.028663
#
#             DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  \
# SK_ID_CURR
# 100002           -9461           -637            -3648.0            -2120
# 100003          -16765          -1188            -1186.0             -291
# 100004          -19046           -225            -4260.0            -2531
# 100006          -19005          -3039            -9833.0            -2437
# 100007          -19932          -3038            -4311.0            -3458
#
#             EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  BASEMENTAREA_AVG  \
# SK_ID_CURR
# 100002          0.083037      0.262949      0.139376            0.0369
# 100003          0.311267      0.622246           NaN            0.0529
# 100004               NaN      0.555912      0.729567               NaN
# 100006               NaN      0.650442           NaN               NaN
# 100007               NaN      0.322738           NaN               NaN
#
#             YEARS_BEGINEXPLUATATION_AVG  ENTRANCES_AVG  FLOORSMAX_AVG  \
# SK_ID_CURR
# 100002                           0.9722         0.0690         0.0833
# 100003                           0.9851         0.0345         0.2917
# 100004                              NaN            NaN            NaN
# 100006                              NaN            NaN            NaN
# 100007                              NaN            NaN            NaN
#
#             LANDAREA_AVG  NONLIVINGAREA_AVG  TOTALAREA_MODE  \
# SK_ID_CURR
# 100002            0.0369             0.0000          0.0149
# 100003            0.0130             0.0098          0.0714
# 100004               NaN                NaN             NaN
# 100006               NaN                NaN             NaN
# 100007               NaN                NaN             NaN
#
#             DAYS_LAST_PHONE_CHANGE
# SK_ID_CURR
# 100002                     -1134.0
# 100003                      -828.0
# 100004                      -815.0
# 100006                      -617.0
# 100007                     -1106.0

# %% [markdown]
# ### Betrachtung der Kausalität

# %%
result = {
    "head":[],
    "des":[]
}

for head in df.columns.values:
    if head in skip:
        continue
    result["head"].append(head)
    result["des"].append(des[des["Row"] == head]["Description"])
    
result = pd.DataFrame(result)
result
# Out:
#                            head  \
# 0              AMT_INCOME_TOTAL
# 1                    AMT_CREDIT
# 2    REGION_POPULATION_RELATIVE
# 3                    DAYS_BIRTH
# 4                 DAYS_EMPLOYED
# 5             DAYS_REGISTRATION
# 6               DAYS_ID_PUBLISH
# 7                  EXT_SOURCE_1
# 8                  EXT_SOURCE_2
# 9                  EXT_SOURCE_3
# 10             BASEMENTAREA_AVG
# 11  YEARS_BEGINEXPLUATATION_AVG
# 12                ENTRANCES_AVG
# 13                FLOORSMAX_AVG
# 14                 LANDAREA_AVG
# 15            NONLIVINGAREA_AVG
# 16               TOTALAREA_MODE
# 17       DAYS_LAST_PHONE_CHANGE
#
#                                                                                                                                                                                                                                                                                                                             des
# 0                                                                                                                                                                                                                                                                   10    Income of the client
# Name: Description, dtype: object
# 1                                                                                                                                                                                                                                                              11    Credit amount of the loan
# Name: Description, dtype: object
# 2                                                                                                                                                                     19    Normalized population of region where client lives (higher number means the client lives in more populated region)
# Name: Description, dtype: object
# 3                                                                                                                                                                                                                                        20    Client's age in days at the time of application
# Name: Description, dtype: object
# 4                                                                                                                                                                                                             21    How many days before the application the person started current employment
# Name: Description, dtype: object
# 5                                                                                                                                                                                                                22    How many days before the application did client change his registration
# Name: Description, dtype: object
# 6                                                                                                                                                                        23    How many days before the application did client change the identity document with which he applied for the loan
# Name: Description, dtype: object
# 7                                                                                                                                                                                                                                             44    Normalized score from external data source
# Name: Description, dtype: object
# 8                                                                                                                                                                                                                                             45    Normalized score from external data source
# Name: Description, dtype: object
# 9                                                                                                                                                                                                                                             46    Normalized score from external data source
# Name: Description, dtype: object
# 10  48    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 11  49    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 12  53    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 13  54    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 14  56    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 15  60    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 16  91    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 17                                                                                                                                                                                                                              98    How many days before application did client change phone
# Name: Description, dtype: object

# %%
remove = ["ENTRANCES_AVG", "FLOORSMAX_AVG"]

# %%
df = df.drop(remove, axis=1)

# %%
df = df.drop(["TARGET"], axis=1)

# %% [markdown]
# ### Variablenerstellung

# %% [markdown]
# Kredithöhe / Einkommen

# %%
df["CREDIT/INCOME"] = df["AMT_CREDIT"] / df["AMT_INCOME_TOTAL"]

# %% [markdown]
# ### Ergebnis

# %%
df = df.add_prefix("A_")

# %%
df.head()
# Out:
#             A_AMT_INCOME_TOTAL  A_AMT_CREDIT  A_REGION_POPULATION_RELATIVE  \
# SK_ID_CURR
# 100002                202500.0      406597.5                      0.018801
# 100003                270000.0     1293502.5                      0.003541
# 100004                 67500.0      135000.0                      0.010032
# 100006                135000.0      312682.5                      0.008019
# 100007                121500.0      513000.0                      0.028663
#
#             A_DAYS_BIRTH  A_DAYS_EMPLOYED  A_DAYS_REGISTRATION  \
# SK_ID_CURR
# 100002             -9461             -637              -3648.0
# 100003            -16765            -1188              -1186.0
# 100004            -19046             -225              -4260.0
# 100006            -19005            -3039              -9833.0
# 100007            -19932            -3038              -4311.0
#
#             A_DAYS_ID_PUBLISH  A_EXT_SOURCE_1  A_EXT_SOURCE_2  A_EXT_SOURCE_3  \
# SK_ID_CURR
# 100002                  -2120        0.083037        0.262949        0.139376
# 100003                   -291        0.311267        0.622246             NaN
# 100004                  -2531             NaN        0.555912        0.729567
# 100006                  -2437             NaN        0.650442             NaN
# 100007                  -3458             NaN        0.322738             NaN
#
#             A_BASEMENTAREA_AVG  A_YEARS_BEGINEXPLUATATION_AVG  A_LANDAREA_AVG  \
# SK_ID_CURR
# 100002                  0.0369                         0.9722          0.0369
# 100003                  0.0529                         0.9851          0.0130
# 100004                     NaN                            NaN             NaN
# 100006                     NaN                            NaN             NaN
# 100007                     NaN                            NaN             NaN
#
#             A_NONLIVINGAREA_AVG  A_TOTALAREA_MODE  A_DAYS_LAST_PHONE_CHANGE  \
# SK_ID_CURR
# 100002                   0.0000            0.0149                   -1134.0
# 100003                   0.0098            0.0714                    -828.0
# 100004                      NaN               NaN                    -815.0
# 100006                      NaN               NaN                    -617.0
# 100007                      NaN               NaN                   -1106.0
#
#             A_CREDIT/INCOME
# SK_ID_CURR
# 100002             2.007889
# 100003             4.790750
# 100004             2.000000
# 100006             2.316167
# 100007             4.222222

# %% [markdown]
# ### Speichern der metrischen Werte

# %%
df = pd.merge(cats, df, left_index=True, right_index=True)

# %%
df.to_csv(DATASET_DIR / "2. Datenaufbereitung" / "app_train.csv")
