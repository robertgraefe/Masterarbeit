# %% [markdown]
# ## <u>2. Datenaufbereitung Application</u>

# %% [markdown]
# In diesem Dokument werden für die Untersuchung unwichtige Variablen aus dem Application-Datensatz gelöscht. Dabei werden zuerst die kategorischen Variablen (nominale & ordinale) betrachtet, um anschließend die metrischen Variablen zu betrachten.
#
# *Vorgehensweise kategorische Variablen:*
# - Löschung von Variablen mit mehr als 60% fehlenden Daten
# - Löschung von nominalen Variablen mit weniger als 5pP relativer Anteilsdifferenz zwischen Paybacks und Defaults
# - Bildung von Korrelationsclustern (Kontingenzkoeffizent bei nominalen Daten)
# - Bildung von Korrelationsclustern (Spearman-Rangkorrelationskoeffizienz bei ordinalen Daten)
# - Löschung von Variablen ohne kausalen Einfluss auf die Kreditwürdigkeitsbestimmung
# - Transformation der nominalen Daten in Integer
#
# *Vorgehensweise metrischer Variablen:*
# - Löschung von Variablen mit mehr als 60% fehlenden Daten
# - Bildung von Korrelationsclustern (Pearson-Korrelationskoeffizient)
# - Löschung von Variablen ohne kausalen Einfluss auf die Kreditwürdigkeitsbestimmung

# %% [markdown]
# ## Initialisierung

# %%
from pathlib import Path
from scipy import stats

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

from sklearn.linear_model import LogisticRegression

from IPython.display import display, Markdown

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
app_train = pd.read_csv(DATASET_DIR / "application_train.csv", index_col="SK_ID_CURR")
description = pd.read_csv(DATASET_DIR / "HomeCredit_columns_description.csv", encoding="latin", index_col=0)

# %%
des = description.loc[description['Table']=="application_{train|test}.csv", "Row":"Special"]

# %%
app_train.head()
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M            N
# 100003           0         Cash loans           F            N
# 100004           0    Revolving loans           M            Y
# 100006           0         Cash loans           F            N
# 100007           0         Cash loans           M            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                   Y             0          202500.0    406597.5
# 100003                   N             0          270000.0   1293502.5
# 100004                   Y             0           67500.0    135000.0
# 100006                   Y             0          135000.0    312682.5
# 100007                   Y             0          121500.0    513000.0
#
#             AMT_ANNUITY  AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# SK_ID_CURR
# 100002          24700.5         351000.0   Unaccompanied          Working
# 100003          35698.5        1129500.0          Family    State servant
# 100004           6750.0         135000.0   Unaccompanied          Working
# 100006          29686.5         297000.0   Unaccompanied          Working
# 100007          21865.5         513000.0   Unaccompanied          Working
#
#                       NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# SK_ID_CURR
# 100002      Secondary / secondary special  Single / not married
# 100003                   Higher education               Married
# 100004      Secondary / secondary special  Single / not married
# 100006      Secondary / secondary special        Civil marriage
# 100007      Secondary / secondary special  Single / not married
#
#             NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# SK_ID_CURR
# 100002      House / apartment                    0.018801       -9461
# 100003      House / apartment                    0.003541      -16765
# 100004      House / apartment                    0.010032      -19046
# 100006      House / apartment                    0.008019      -19005
# 100007      House / apartment                    0.028663      -19932
#
#             DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  \
# SK_ID_CURR
# 100002               -637            -3648.0            -2120          NaN
# 100003              -1188            -1186.0             -291          NaN
# 100004               -225            -4260.0            -2531         26.0
# 100006              -3039            -9833.0            -2437          NaN
# 100007              -3038            -4311.0            -3458          NaN
#
#             FLAG_MOBIL  FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  \
# SK_ID_CURR
# 100002               1               1                0                 1
# 100003               1               1                0                 1
# 100004               1               1                1                 1
# 100006               1               1                0                 1
# 100007               1               1                0                 1
#
#             FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# SK_ID_CURR
# 100002               1           0        Laborers              1.0
# 100003               1           0      Core staff              2.0
# 100004               1           0        Laborers              1.0
# 100006               0           0        Laborers              2.0
# 100007               0           0      Core staff              1.0
#
#             REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# SK_ID_CURR
# 100002                         2                            2
# 100003                         1                            1
# 100004                         2                            2
# 100006                         2                            2
# 100007                         2                            2
#
#            WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  \
# SK_ID_CURR
# 100002                      WEDNESDAY                       10
# 100003                         MONDAY                       11
# 100004                         MONDAY                        9
# 100006                      WEDNESDAY                       17
# 100007                       THURSDAY                       11
#
#             REG_REGION_NOT_LIVE_REGION  REG_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100002                               0                           0
# 100003                               0                           0
# 100004                               0                           0
# 100006                               0                           0
# 100007                               0                           0
#
#             LIVE_REGION_NOT_WORK_REGION  REG_CITY_NOT_LIVE_CITY  \
# SK_ID_CURR
# 100002                                0                       0
# 100003                                0                       0
# 100004                                0                       0
# 100006                                0                       0
# 100007                                0                       0
#
#             REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100002                           0                        0
# 100003                           0                        0
# 100004                           0                        0
# 100006                           0                        0
# 100007                           1                        1
#
#                  ORGANIZATION_TYPE  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# SK_ID_CURR
# 100002      Business Entity Type 3      0.083037      0.262949      0.139376
# 100003                      School      0.311267      0.622246           NaN
# 100004                  Government           NaN      0.555912      0.729567
# 100006      Business Entity Type 3           NaN      0.650442           NaN
# 100007                    Religion           NaN      0.322738           NaN
#
#             APARTMENTS_AVG  BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  \
# SK_ID_CURR
# 100002              0.0247            0.0369                       0.9722
# 100003              0.0959            0.0529                       0.9851
# 100004                 NaN               NaN                          NaN
# 100006                 NaN               NaN                          NaN
# 100007                 NaN               NaN                          NaN
#
#             YEARS_BUILD_AVG  COMMONAREA_AVG  ELEVATORS_AVG  ENTRANCES_AVG  \
# SK_ID_CURR
# 100002               0.6192          0.0143           0.00         0.0690
# 100003               0.7960          0.0605           0.08         0.0345
# 100004                  NaN             NaN            NaN            NaN
# 100006                  NaN             NaN            NaN            NaN
# 100007                  NaN             NaN            NaN            NaN
#
#             FLOORSMAX_AVG  FLOORSMIN_AVG  LANDAREA_AVG  LIVINGAPARTMENTS_AVG  \
# SK_ID_CURR
# 100002             0.0833         0.1250        0.0369                0.0202
# 100003             0.2917         0.3333        0.0130                0.0773
# 100004                NaN            NaN           NaN                   NaN
# 100006                NaN            NaN           NaN                   NaN
# 100007                NaN            NaN           NaN                   NaN
#
#             LIVINGAREA_AVG  NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  \
# SK_ID_CURR
# 100002              0.0190                   0.0000             0.0000
# 100003              0.0549                   0.0039             0.0098
# 100004                 NaN                      NaN                NaN
# 100006                 NaN                      NaN                NaN
# 100007                 NaN                      NaN                NaN
#
#             APARTMENTS_MODE  BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  \
# SK_ID_CURR
# 100002               0.0252             0.0383                        0.9722
# 100003               0.0924             0.0538                        0.9851
# 100004                  NaN                NaN                           NaN
# 100006                  NaN                NaN                           NaN
# 100007                  NaN                NaN                           NaN
#
#             YEARS_BUILD_MODE  COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  \
# SK_ID_CURR
# 100002                0.6341           0.0144          0.0000          0.0690
# 100003                0.8040           0.0497          0.0806          0.0345
# 100004                   NaN              NaN             NaN             NaN
# 100006                   NaN              NaN             NaN             NaN
# 100007                   NaN              NaN             NaN             NaN
#
#             FLOORSMAX_MODE  FLOORSMIN_MODE  LANDAREA_MODE  \
# SK_ID_CURR
# 100002              0.0833          0.1250         0.0377
# 100003              0.2917          0.3333         0.0128
# 100004                 NaN             NaN            NaN
# 100006                 NaN             NaN            NaN
# 100007                 NaN             NaN            NaN
#
#             LIVINGAPARTMENTS_MODE  LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  \
# SK_ID_CURR
# 100002                      0.022           0.0198                       0.0
# 100003                      0.079           0.0554                       0.0
# 100004                        NaN              NaN                       NaN
# 100006                        NaN              NaN                       NaN
# 100007                        NaN              NaN                       NaN
#
#             NONLIVINGAREA_MODE  APARTMENTS_MEDI  BASEMENTAREA_MEDI  \
# SK_ID_CURR
# 100002                     0.0           0.0250             0.0369
# 100003                     0.0           0.0968             0.0529
# 100004                     NaN              NaN                NaN
# 100006                     NaN              NaN                NaN
# 100007                     NaN              NaN                NaN
#
#             YEARS_BEGINEXPLUATATION_MEDI  YEARS_BUILD_MEDI  COMMONAREA_MEDI  \
# SK_ID_CURR
# 100002                            0.9722            0.6243           0.0144
# 100003                            0.9851            0.7987           0.0608
# 100004                               NaN               NaN              NaN
# 100006                               NaN               NaN              NaN
# 100007                               NaN               NaN              NaN
#
#             ELEVATORS_MEDI  ENTRANCES_MEDI  FLOORSMAX_MEDI  FLOORSMIN_MEDI  \
# SK_ID_CURR
# 100002                0.00          0.0690          0.0833          0.1250
# 100003                0.08          0.0345          0.2917          0.3333
# 100004                 NaN             NaN             NaN             NaN
# 100006                 NaN             NaN             NaN             NaN
# 100007                 NaN             NaN             NaN             NaN
#
#             LANDAREA_MEDI  LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  \
# SK_ID_CURR
# 100002             0.0375                 0.0205           0.0193
# 100003             0.0132                 0.0787           0.0558
# 100004                NaN                    NaN              NaN
# 100006                NaN                    NaN              NaN
# 100007                NaN                    NaN              NaN
#
#             NONLIVINGAPARTMENTS_MEDI  NONLIVINGAREA_MEDI FONDKAPREMONT_MODE  \
# SK_ID_CURR
# 100002                        0.0000                0.00   reg oper account
# 100003                        0.0039                0.01   reg oper account
# 100004                           NaN                 NaN                NaN
# 100006                           NaN                 NaN                NaN
# 100007                           NaN                 NaN                NaN
#
#             HOUSETYPE_MODE  TOTALAREA_MODE WALLSMATERIAL_MODE  \
# SK_ID_CURR
# 100002      block of flats          0.0149       Stone, brick
# 100003      block of flats          0.0714              Block
# 100004                 NaN             NaN                NaN
# 100006                 NaN             NaN                NaN
# 100007                 NaN             NaN                NaN
#
#            EMERGENCYSTATE_MODE  OBS_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                      No                       2.0
# 100003                      No                       1.0
# 100004                     NaN                       0.0
# 100006                     NaN                       2.0
# 100007                     NaN                       0.0
#
#             DEF_30_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100003                           0.0                       1.0
# 100004                           0.0                       0.0
# 100006                           0.0                       2.0
# 100007                           0.0                       0.0
#
#             DEF_60_CNT_SOCIAL_CIRCLE  DAYS_LAST_PHONE_CHANGE  FLAG_DOCUMENT_2  \
# SK_ID_CURR
# 100002                           2.0                 -1134.0                0
# 100003                           0.0                  -828.0                0
# 100004                           0.0                  -815.0                0
# 100006                           0.0                  -617.0                0
# 100007                           0.0                 -1106.0                0
#
#             FLAG_DOCUMENT_3  FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  \
# SK_ID_CURR
# 100002                    1                0                0
# 100003                    1                0                0
# 100004                    0                0                0
# 100006                    1                0                0
# 100007                    0                0                0
#
#             FLAG_DOCUMENT_6  FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  \
# SK_ID_CURR
# 100002                    0                0                0
# 100003                    0                0                0
# 100004                    0                0                0
# 100006                    0                0                0
# 100007                    0                0                1
#
#             FLAG_DOCUMENT_9  FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  \
# SK_ID_CURR
# 100002                    0                 0                 0
# 100003                    0                 0                 0
# 100004                    0                 0                 0
# 100006                    0                 0                 0
# 100007                    0                 0                 0
#
#             FLAG_DOCUMENT_12  FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_15  FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_21  AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100002                     0                         0.0
# 100003                     0                         0.0
# 100004                     0                         0.0
# 100006                     0                         NaN
# 100007                     0                         0.0
#
#             AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# SK_ID_CURR
# 100002                            0.0                         0.0
# 100003                            0.0                         0.0
# 100004                            0.0                         0.0
# 100006                            NaN                         NaN
# 100007                            0.0                         0.0
#
#             AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# SK_ID_CURR
# 100002                            0.0                        0.0
# 100003                            0.0                        0.0
# 100004                            0.0                        0.0
# 100006                            NaN                        NaN
# 100007                            0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR
# 100002                             1.0
# 100003                             0.0
# 100004                             0.0
# 100006                             NaN
# 100007                             0.0

# %%
# Spalten die innerhalb der Aufbereitung nicht verändert werden können
skip = ["TARGET", "SK_ID_CURR"]

# %%
# nominale und metrische Spalten
n_heads = ['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'WEEKDAY_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21']
o_heads = ["CNT_CHILDREN", "CNT_FAM_MEMBERS", "HOUR_APPR_PROCESS_START", "OBS_30_CNT_SOCIAL_CIRCLE", "DEF_30_CNT_SOCIAL_CIRCLE", "OBS_60_CNT_SOCIAL_CIRCLE", "DEF_60_CNT_SOCIAL_CIRCLE", "AMT_REQ_CREDIT_BUREAU_HOUR", "AMT_REQ_CREDIT_BUREAU_DAY", "AMT_REQ_CREDIT_BUREAU_WEEK", "AMT_REQ_CREDIT_BUREAU_MON", "AMT_REQ_CREDIT_BUREAU_QRT", "AMT_REQ_CREDIT_BUREAU_YEAR"]
m_heads = [head for head in app_train.columns.values if head not in n_heads and head not in o_heads]

# %% [markdown]
# ## <u>kategorische Variablen

# %%
df = app_train[n_heads + o_heads].copy()

# %%
df.head()
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M            N
# 100003           0         Cash loans           F            N
# 100004           0    Revolving loans           M            Y
# 100006           0         Cash loans           F            N
# 100007           0         Cash loans           M            N
#
#            FLAG_OWN_REALTY NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# SK_ID_CURR
# 100002                   Y   Unaccompanied          Working
# 100003                   N          Family    State servant
# 100004                   Y   Unaccompanied          Working
# 100006                   Y   Unaccompanied          Working
# 100007                   Y   Unaccompanied          Working
#
#                       NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# SK_ID_CURR
# 100002      Secondary / secondary special  Single / not married
# 100003                   Higher education               Married
# 100004      Secondary / secondary special  Single / not married
# 100006      Secondary / secondary special        Civil marriage
# 100007      Secondary / secondary special  Single / not married
#
#             NAME_HOUSING_TYPE  FLAG_MOBIL  FLAG_EMP_PHONE  FLAG_WORK_PHONE  \
# SK_ID_CURR
# 100002      House / apartment           1               1                0
# 100003      House / apartment           1               1                0
# 100004      House / apartment           1               1                1
# 100006      House / apartment           1               1                0
# 100007      House / apartment           1               1                0
#
#             FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# SK_ID_CURR
# 100002                     1           1           0        Laborers
# 100003                     1           1           0      Core staff
# 100004                     1           1           0        Laborers
# 100006                     1           0           0        Laborers
# 100007                     1           0           0      Core staff
#
#             REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# SK_ID_CURR
# 100002                         2                            2
# 100003                         1                            1
# 100004                         2                            2
# 100006                         2                            2
# 100007                         2                            2
#
#            WEEKDAY_APPR_PROCESS_START  REG_REGION_NOT_LIVE_REGION  \
# SK_ID_CURR
# 100002                      WEDNESDAY                           0
# 100003                         MONDAY                           0
# 100004                         MONDAY                           0
# 100006                      WEDNESDAY                           0
# 100007                       THURSDAY                           0
#
#             REG_REGION_NOT_WORK_REGION  LIVE_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100002                               0                            0
# 100003                               0                            0
# 100004                               0                            0
# 100006                               0                            0
# 100007                               0                            0
#
#             REG_CITY_NOT_LIVE_CITY  REG_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100002                           0                       0
# 100003                           0                       0
# 100004                           0                       0
# 100006                           0                       0
# 100007                           0                       1
#
#             LIVE_CITY_NOT_WORK_CITY       ORGANIZATION_TYPE  \
# SK_ID_CURR
# 100002                            0  Business Entity Type 3
# 100003                            0                  School
# 100004                            0              Government
# 100006                            0  Business Entity Type 3
# 100007                            1                Religion
#
#            FONDKAPREMONT_MODE  HOUSETYPE_MODE WALLSMATERIAL_MODE  \
# SK_ID_CURR
# 100002       reg oper account  block of flats       Stone, brick
# 100003       reg oper account  block of flats              Block
# 100004                    NaN             NaN                NaN
# 100006                    NaN             NaN                NaN
# 100007                    NaN             NaN                NaN
#
#            EMERGENCYSTATE_MODE  FLAG_DOCUMENT_2  FLAG_DOCUMENT_3  \
# SK_ID_CURR
# 100002                      No                0                1
# 100003                      No                0                1
# 100004                     NaN                0                0
# 100006                     NaN                0                1
# 100007                     NaN                0                0
#
#             FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  FLAG_DOCUMENT_6  \
# SK_ID_CURR
# 100002                    0                0                0
# 100003                    0                0                0
# 100004                    0                0                0
# 100006                    0                0                0
# 100007                    0                0                0
#
#             FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  FLAG_DOCUMENT_9  \
# SK_ID_CURR
# 100002                    0                0                0
# 100003                    0                0                0
# 100004                    0                0                0
# 100006                    0                0                0
# 100007                    0                1                0
#
#             FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  FLAG_DOCUMENT_12  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  FLAG_DOCUMENT_15  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  FLAG_DOCUMENT_18  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             CNT_CHILDREN  CNT_FAM_MEMBERS  HOUR_APPR_PROCESS_START  \
# SK_ID_CURR
# 100002                 0              1.0                       10
# 100003                 0              2.0                       11
# 100004                 0              1.0                        9
# 100006                 0              2.0                       17
# 100007                 0              1.0                       11
#
#             OBS_30_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100003                           1.0                       0.0
# 100004                           0.0                       0.0
# 100006                           2.0                       0.0
# 100007                           0.0                       0.0
#
#             OBS_60_CNT_SOCIAL_CIRCLE  DEF_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100003                           1.0                       0.0
# 100004                           0.0                       0.0
# 100006                           2.0                       0.0
# 100007                           0.0                       0.0
#
#             AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# SK_ID_CURR
# 100002                             0.0                        0.0
# 100003                             0.0                        0.0
# 100004                             0.0                        0.0
# 100006                             NaN                        NaN
# 100007                             0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# SK_ID_CURR
# 100002                             0.0                        0.0
# 100003                             0.0                        0.0
# 100004                             0.0                        0.0
# 100006                             NaN                        NaN
# 100007                             0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR
# 100002                            0.0                         1.0
# 100003                            0.0                         0.0
# 100004                            0.0                         0.0
# 100006                            NaN                         NaN
# 100007                            0.0                         0.0

# %% [markdown]
# ### Löschung der Spalten mit weniger als 40% ausgefüllten Daten

# %%
result = {
          "header":[],
          "rate":[],
          "des":[]
         }
for key in df.keys():
    if key in skip:
        continue
    rate = df[key].isna().sum() / len(df[key]) * 100
    
    if rate > 60:
        result["header"].append(key)
        result["rate"].append(rate)
        result["des"].append(des[des["Row"] == key]["Description"])

result = pd.DataFrame(result)
result
# Out:
#                header       rate  \
# 0  FONDKAPREMONT_MODE  68.386172
#
#                                                                                                                                                                                                                                                                                                                            des
# 0  89    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object

# %% [markdown]
# FONDKAPREMONT_MODE wird mit 68.39% fehlenden Daten gelöscht.

# %%
n_heads = [head for head in n_heads if head not in result.header.values]
o_heads = [head for head in o_heads if head not in result.header.values]

# %%
df = df.drop(result.header.values, axis=1)

# %% [markdown]
# ### Unterscheidbarkeit von mindestens 5pP einer Kategorie

# %%
ID_Payback = app_train[app_train["TARGET"] == 0].index.values
ID_Default = app_train[app_train["TARGET"] == 1].index.values

# %%
payback = df.loc[ID_Payback]
default = df.loc[ID_Default]

# %%
result = {
    "head" : [],
    "cat" : [],
    "payback" : [],
    "default" : [],
    "diff" : []
}

for head in df[n_heads].columns.values:
    df1 = payback[head].value_counts().rename_axis(head).reset_index(name='payback')
    df2 = default[head].value_counts().rename_axis(head).reset_index(name='default')
    
    df1["payback"] = df1["payback"]/df1["payback"].sum()*100
    df2["default"] = df2["default"]/df2["default"].sum()*100
    
    df_ = df1.merge(df2, how="outer", on=head)
    
    df_["diff"] = (df_["default"]-df_["payback"])
    
    df_ = df_.sort_values("diff", ascending=False)
    
    for diff in df_["diff"]:
        if np.isnan(diff):
            continue
        if diff > 5 or diff < -5:
            row = df_.loc[df_["diff"] == diff]
            cat = row[head][row[head].index[0]]
            
            result["head"].append(head)
            result["cat"].append(cat)
            result["payback"].append(round(row["payback"].values[0],2))
            result["default"].append(round(row["default"].values[0],2))
            result["diff"].append(round(diff,2))

result = pd.DataFrame(result)
result.sort_values("diff", ascending=False)
# Out:
#                            head                            cat  payback  \
# 2              NAME_INCOME_TYPE                        Working    50.78
# 0                   CODE_GENDER                              M    33.40
# 4           NAME_EDUCATION_TYPE  Secondary / secondary special    70.35
# 11       REG_CITY_NOT_WORK_CITY                              1    22.41
# 14              FLAG_DOCUMENT_3                              1    70.41
# 6                FLAG_EMP_PHONE                              1    81.47
# 9          REGION_RATING_CLIENT                              3    15.20
# 10  REGION_RATING_CLIENT_W_CITY                              3    13.75
# 8               OCCUPATION_TYPE                       Laborers    25.63
# 7                FLAG_EMP_PHONE                              0    18.53
# 13            ORGANIZATION_TYPE                            XNA    18.53
# 3              NAME_INCOME_TYPE                      Pensioner    18.53
# 15              FLAG_DOCUMENT_3                              0    29.59
# 12       REG_CITY_NOT_WORK_CITY                              0    77.59
# 5           NAME_EDUCATION_TYPE               Higher education    25.06
# 1                   CODE_GENDER                              F    66.60
#
#     default   diff
# 2     61.33  10.54
# 0     42.92   9.53
# 4     78.65   8.30
# 11    30.29   7.88
# 14    77.79   7.39
# 6     87.95   6.49
# 9     21.62   6.42
# 10    20.15   6.40
# 8     31.48   5.85
# 7     12.05  -6.49
# 13    12.04  -6.49
# 3     12.01  -6.52
# 15    22.21  -7.39
# 12    69.71  -7.88
# 5     16.15  -8.92
# 1     57.08  -9.52

# %% [markdown]
# Defaults sind:
# - Arbeiter
# - Männer
# - Personen mit Sekundarabschluss
# - Arbeitsadresse ist eine andere als die Wohnadresse (Pendler, Reisender, etc.)
# - haben Dokument 3 zur Verfügung gestellt
#
# Paybacks sind:
# - Frauen
# - Akademiker
# - Arbeitsadresse und Wohnadresse stimmen überein
# - haben Dokument 3 nicht zur Verfügung gestellt
# - beziehen Rente als Einkommen
# - Arbeiten in Branchen, die im Datensatz nicht hinterlegt sind (sehr spezielle Branchen oder keine da Renter)
# - haben als Telefonnummer die Arbeitstelefonnummer hinterlegt

# %% [markdown]
# Alle hier nicht aufgeführten nominalen Variablen haben einen zu geringen Informationsgehalt zur Identifikation von Defaults und werden gelöscht.

# %%
keep = list(result["head"].unique())
remove = [head for head in n_heads if head not in keep + skip]

# %%
n_heads = [head for head in n_heads if head in df.columns.values]

# %%
df = df.drop(remove, axis=1)

# %% [markdown]
# ### Bildung von Korrelationsclustern

# %% [markdown]
# #### nominale Daten

# %%
def contingency_corr(df, head_1, head_2):
    
    data = pd.crosstab(df[head_1], df[head_2], margins = False)
    
    sum_cols = data.sum(axis=0)
    sum_rows = data.sum(axis=1)
    sum_all = data.sum().sum()
    
    n = data.to_numpy()
    n = n.reshape(1,-1).squeeze()
    
    e = []
    for row in sum_rows:
        for col in sum_cols:
            e.append(row * col / sum_all)
    e = np.array(e)
    
    chi2 = (np.subtract(n, e)**2 / e).sum()
    
    K = np.sqrt(chi2/(sum_all+chi2))
    
    i = min(data.shape)
    i = (i-1)/i
    i = np.sqrt(i)
    
    K_ = K / i
    
    return K_

# %%
n_heads = [head for head in df.columns.values if head in n_heads]
result = {}
for head1 in n_heads:
    row = []
    for head2 in n_heads:
        corr = contingency_corr(df, head1, head2)
        row.append(corr)
    result[head1] = row
c = pd.DataFrame(result, index=n_heads) * 100

# %% [markdown]
# Kontingenzkoeffizienten der einzelnen Variablen

# %%
c
# Out:
#                                  TARGET  CODE_GENDER  NAME_INCOME_TYPE  \
# TARGET                       100.000000     7.727091          9.010698
# CODE_GENDER                    7.727091   100.000000         20.501998
# NAME_INCOME_TYPE               9.010698    20.501998        100.000000
# NAME_EDUCATION_TYPE            8.128280     3.253923         22.760297
# FLAG_EMP_PHONE                 6.496004    21.969022         99.987941
# OCCUPATION_TYPE               11.489928    60.845086         36.232480
# REGION_RATING_CLIENT           8.316753     2.344752         23.044339
# REGION_RATING_CLIENT_W_CITY    8.607690     2.389310         21.988003
# REG_CITY_NOT_WORK_CITY         7.202348    19.276634         35.379443
# ORGANIZATION_TYPE             10.203796    39.184487         79.683528
# FLAG_DOCUMENT_3                6.265363    12.321069         35.168159
#
#                              NAME_EDUCATION_TYPE  FLAG_EMP_PHONE  \
# TARGET                                  8.128280        6.496004
# CODE_GENDER                             3.253923       21.969022
# NAME_INCOME_TYPE                       22.760297       99.987941
# NAME_EDUCATION_TYPE                   100.000000       19.544416
# FLAG_EMP_PHONE                         19.544416      100.000000
# OCCUPATION_TYPE                        44.871758        1.336271
# REGION_RATING_CLIENT                   12.334248        5.360049
# REGION_RATING_CLIENT_W_CITY            12.276476        5.654068
# REG_CITY_NOT_WORK_CITY                  4.260959       35.127768
# ORGANIZATION_TYPE                      27.875122       99.993393
# FLAG_DOCUMENT_3                         8.628719       34.110302
#
#                              OCCUPATION_TYPE  REGION_RATING_CLIENT  \
# TARGET                             11.489928              8.316753
# CODE_GENDER                        60.845086              2.344752
# NAME_INCOME_TYPE                   36.232480             23.044339
# NAME_EDUCATION_TYPE                44.871758             12.334248
# FLAG_EMP_PHONE                      1.336271              5.360049
# OCCUPATION_TYPE                   100.000000              9.864538
# REGION_RATING_CLIENT                9.864538            100.000000
# REGION_RATING_CLIENT_W_CITY         9.893453             98.485788
# REG_CITY_NOT_WORK_CITY             16.222021              4.608254
# ORGANIZATION_TYPE                  80.159933             16.101935
# FLAG_DOCUMENT_3                    19.113187             12.821528
#
#                              REGION_RATING_CLIENT_W_CITY  \
# TARGET                                          8.607690
# CODE_GENDER                                     2.389310
# NAME_INCOME_TYPE                               21.988003
# NAME_EDUCATION_TYPE                            12.276476
# FLAG_EMP_PHONE                                  5.654068
# OCCUPATION_TYPE                                 9.893453
# REGION_RATING_CLIENT                           98.485788
# REGION_RATING_CLIENT_W_CITY                   100.000000
# REG_CITY_NOT_WORK_CITY                          5.193054
# ORGANIZATION_TYPE                              16.019063
# FLAG_DOCUMENT_3                                12.638246
#
#                              REG_CITY_NOT_WORK_CITY  ORGANIZATION_TYPE  \
# TARGET                                     7.202348          10.203796
# CODE_GENDER                               19.276634          39.184487
# NAME_INCOME_TYPE                          35.379443          79.683528
# NAME_EDUCATION_TYPE                        4.260959          27.875122
# FLAG_EMP_PHONE                            35.127768          99.993393
# OCCUPATION_TYPE                           16.222021          80.159933
# REGION_RATING_CLIENT                       4.608254          16.101935
# REGION_RATING_CLIENT_W_CITY                5.193054          16.019063
# REG_CITY_NOT_WORK_CITY                   100.000000          38.386727
# ORGANIZATION_TYPE                         38.386727         100.000000
# FLAG_DOCUMENT_3                            7.945939          37.462472
#
#                              FLAG_DOCUMENT_3
# TARGET                              6.265363
# CODE_GENDER                        12.321069
# NAME_INCOME_TYPE                   35.168159
# NAME_EDUCATION_TYPE                 8.628719
# FLAG_EMP_PHONE                     34.110302
# OCCUPATION_TYPE                    19.113187
# REGION_RATING_CLIENT               12.821528
# REGION_RATING_CLIENT_W_CITY        12.638246
# REG_CITY_NOT_WORK_CITY              7.945939
# ORGANIZATION_TYPE                  37.462472
# FLAG_DOCUMENT_3                   100.000000

# %%
families = []
for i, row in c.iterrows():
    r = row[row > 80]
    if len(r) > 1 and set(r.index) not in families:
        families.append(set(r.index))

for A in families:
    for B in families:
        if A == B:
            continue
        if A.issubset(B):
            families.remove(A)
families
# Out:
# [{'FLAG_EMP_PHONE', 'NAME_INCOME_TYPE', 'ORGANIZATION_TYPE'},
#  {'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY'},
#  {'FLAG_EMP_PHONE', 'OCCUPATION_TYPE', 'ORGANIZATION_TYPE'}]

# %%
result = {
          "family":[],
          "head":[],
          "r2":[],
          "na":[],
          "rate":[]
         }

for i, family in enumerate(families):
    headers = list(family)
    
    result["family"].append("")
    result["head"].append("")
    result["r2"].append("")
    result["na"].append("")
    result["rate"].append("")
    
    for head in headers:
        d = df[["TARGET"] + [head]].copy()
        d.loc[:,head], cats = pd.factorize(d.loc[:,head])
        na = d[head].isna().sum() / len(d) * 100
        d = d.dropna()
        y = d[["TARGET"]]
        x = d[[head]]
        
        model = LogisticRegression().fit(x, y.values.ravel())
        r2 = model.score(x,y)
        
        result["family"].append(i)
        result["head"].append(head)
        result["r2"].append(round(r2,5))
        result["na"].append(round(na,2))
        result["rate"].append(r2/na)

result = pd.DataFrame(result)
result
# Out:
# <ipython-input-23-35ccfc96d69f>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# <ipython-input-23-35ccfc96d69f>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# <ipython-input-23-35ccfc96d69f>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# <ipython-input-23-35ccfc96d69f>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# <ipython-input-23-35ccfc96d69f>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# <ipython-input-23-35ccfc96d69f>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# <ipython-input-23-35ccfc96d69f>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
# <ipython-input-23-35ccfc96d69f>:33: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
#    family                         head       r2 na rate
# 0
# 1       0             NAME_INCOME_TYPE  0.91927  0  inf
# 2       0            ORGANIZATION_TYPE  0.91927  0  inf
# 3       0               FLAG_EMP_PHONE  0.91927  0  inf
# 4
# 5       1         REGION_RATING_CLIENT  0.91927  0  inf
# 6       1  REGION_RATING_CLIENT_W_CITY  0.91927  0  inf
# 7
# 8       2              OCCUPATION_TYPE  0.91927  0  inf
# 9       2            ORGANIZATION_TYPE  0.91927  0  inf
# 10      2               FLAG_EMP_PHONE  0.91927  0  inf

# %% [markdown]
# Es entstehen 3 Korrelationscluster mit Variablen, die zu mindestens 80% miteinander korrelieren. Es wird eine Variable aus Cluster#1 gelöscht, da beide Variablen das Rating der Region wiederspiegeln, sodass sich die Information doppelt. Die anderen Variablen werden nicht gelöscht, da sie trotz hoher Korrelation Kausal nicht das selbe sind. Ein Arbeiter (eher Default) der seine Privattelefonnummer hinterlegt (eher Payback) wäre vom Modell nicht mehr identifizierbar.

# %%
keep = ["NAME_INCOME_TYPE", "FLAG_EMP_PHONE", "ORGANIZATION_TYPE", "OCCUPATION_TYPE", "REGION_RATING_CLIENT"]

# %%
remove = [head for head in result["head"].values if head not in [""] + keep]

# %%
remove
# Out:
# ['REGION_RATING_CLIENT_W_CITY']

# %%
df = df.drop(remove, axis=1)

# %% [markdown]
# #### ordinale Daten

# %%
c = df[o_heads].corr(method='spearman') * 100

# %%
families = []
for i, row in c.iterrows():
    r = row[row > 80]
    if len(r) > 1 and set(r.index) not in families:
        families.append(set(r.index))

for A in families:
    for B in families:
        if A == B:
            continue
        if A.issubset(B):
            families.remove(A)
families
# Out:
# [{'CNT_CHILDREN', 'CNT_FAM_MEMBERS'},
#  {'OBS_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE'},
#  {'DEF_30_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE'}]

# %%
result = {
          "family":[],
          "head":[],
          "r2":[],
          "na":[],
          "rate":[]
         }

for i, family in enumerate(families):
    headers = list(family)
    
    result["family"].append("")
    result["head"].append("")
    result["r2"].append("")
    result["na"].append("")
    result["rate"].append("")
    
    for head in headers:
        d = df[["TARGET"] + [head]].copy()
        na = d[head].isna().sum() / len(d) * 100
        d = d.dropna()
        y = d[["TARGET"]]
        x = d[[head]]
        
        model = LogisticRegression().fit(x, y.values.ravel())
        r2 = round(model.score(x,y),5)
        
        result["family"].append(i)
        result["head"].append(head)
        result["r2"].append(round(r2,5))
        result["na"].append(round(na,2))
        result["rate"].append(r2/na)
    
result = pd.DataFrame(result)
result
# Out:
# <ipython-input-30-bc4fc74eb02f>:32: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
#   family                      head       r2    na     rate
# 0
# 1      0           CNT_FAM_MEMBERS  0.91927     0  1413.43
# 2      0              CNT_CHILDREN  0.91927     0      inf
# 3
# 4      1  OBS_60_CNT_SOCIAL_CIRCLE  0.91912  0.33  2.76826
# 5      1  OBS_30_CNT_SOCIAL_CIRCLE  0.91912  0.33  2.76826
# 6
# 7      2  DEF_60_CNT_SOCIAL_CIRCLE  0.91912  0.33  2.76826
# 8      2  DEF_30_CNT_SOCIAL_CIRCLE  0.91912  0.33  2.76826

# %% [markdown]
# Die Anzahl der Kinder ist fast immer auch die Anzahl der Familienmitglieder. Da es in der Anzahl der Familienmitglieder fehlende Daten gibt, wird die Anzahl der Kinder als Clusterprepräsentant gewählt.
#
# Die Anzahl der erwarteten Defaults im Sozialumfeld der letzten 30 Tage entspricht meist der Anzahl der letzten 60 Tage.
#
# Die Anzahl der eingetretenen Defaults im Sozialumfeld der letzten 30 Tage entspricht meist der Anzahl der letzten 60 Tage.

# %%
remove = ["CNT_FAM_MEMBERS", "OBS_30_CNT_SOCIAL_CIRCLE", "DEF_30_CNT_SOCIAL_CIRCLE"]

# %%
o_heads = [head for head in o_heads if head not in remove]

# %%
remove
# Out:
# ['CNT_FAM_MEMBERS', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE']

# %%
df = df.drop(remove, axis=1)

# %%
df.head()
# Out:
#             TARGET CODE_GENDER NAME_INCOME_TYPE  \
# SK_ID_CURR
# 100002           1           M          Working
# 100003           0           F    State servant
# 100004           0           M          Working
# 100006           0           F          Working
# 100007           0           M          Working
#
#                       NAME_EDUCATION_TYPE  FLAG_EMP_PHONE OCCUPATION_TYPE  \
# SK_ID_CURR
# 100002      Secondary / secondary special               1        Laborers
# 100003                   Higher education               1      Core staff
# 100004      Secondary / secondary special               1        Laborers
# 100006      Secondary / secondary special               1        Laborers
# 100007      Secondary / secondary special               1      Core staff
#
#             REGION_RATING_CLIENT  REG_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100002                         2                       0
# 100003                         1                       0
# 100004                         2                       0
# 100006                         2                       0
# 100007                         2                       1
#
#                  ORGANIZATION_TYPE  FLAG_DOCUMENT_3  CNT_CHILDREN  \
# SK_ID_CURR
# 100002      Business Entity Type 3                1             0
# 100003                      School                1             0
# 100004                  Government                0             0
# 100006      Business Entity Type 3                1             0
# 100007                    Religion                0             0
#
#             HOUR_APPR_PROCESS_START  OBS_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           10                       2.0
# 100003                           11                       1.0
# 100004                            9                       0.0
# 100006                           17                       2.0
# 100007                           11                       0.0
#
#             DEF_60_CNT_SOCIAL_CIRCLE  AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100002                           2.0                         0.0
# 100003                           0.0                         0.0
# 100004                           0.0                         0.0
# 100006                           0.0                         NaN
# 100007                           0.0                         0.0
#
#             AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# SK_ID_CURR
# 100002                            0.0                         0.0
# 100003                            0.0                         0.0
# 100004                            0.0                         0.0
# 100006                            NaN                         NaN
# 100007                            0.0                         0.0
#
#             AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# SK_ID_CURR
# 100002                            0.0                        0.0
# 100003                            0.0                        0.0
# 100004                            0.0                        0.0
# 100006                            NaN                        NaN
# 100007                            0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR
# 100002                             1.0
# 100003                             0.0
# 100004                             0.0
# 100006                             NaN
# 100007                             0.0

# %% [markdown]
# ### Transformation von Kategorien in numerische Werte

# %%
# transformiert kategorische variablen in integer
HEADS = [head for head in df.columns.values if df[head].dtype == "object"]

for head in HEADS:
    df[head], cats = pd.factorize(df[head])

# %% [markdown]
# ### Kausalitätsbetrachtung

# %%
result = {
    "head":[],
    "des":[]
}

for head in df.columns.values:
    if head in skip:
        continue
    result["head"].append(head)
    result["des"].append(des[des["Row"] == head]["Description"])
    
result = pd.DataFrame(result)
result
# Out:
#                           head  \
# 0                  CODE_GENDER
# 1             NAME_INCOME_TYPE
# 2          NAME_EDUCATION_TYPE
# 3               FLAG_EMP_PHONE
# 4              OCCUPATION_TYPE
# 5         REGION_RATING_CLIENT
# 6       REG_CITY_NOT_WORK_CITY
# 7            ORGANIZATION_TYPE
# 8              FLAG_DOCUMENT_3
# 9                 CNT_CHILDREN
# 10     HOUR_APPR_PROCESS_START
# 11    OBS_60_CNT_SOCIAL_CIRCLE
# 12    DEF_60_CNT_SOCIAL_CIRCLE
# 13  AMT_REQ_CREDIT_BUREAU_HOUR
# 14   AMT_REQ_CREDIT_BUREAU_DAY
# 15  AMT_REQ_CREDIT_BUREAU_WEEK
# 16   AMT_REQ_CREDIT_BUREAU_MON
# 17   AMT_REQ_CREDIT_BUREAU_QRT
# 18  AMT_REQ_CREDIT_BUREAU_YEAR
#
#                                                                                                                                                                    des
# 0                                                                                                           6    Gender of the client
# Name: Description, dtype: object
# 1                                                                 15    Clients income type (businessman, working, maternity leave,
# )
# Name: Description, dtype: object
# 2                                                                                16    Level of highest education the client achieved
# Name: Description, dtype: object
# 3                                                                                   26    Did client provide work phone (1=YES, 0=NO)
# Name: Description, dtype: object
# 4                                                                                  31    What kind of occupation does the client have
# Name: Description, dtype: object
# 5                                                                           33    Our rating of the region where client lives (1,2,3)
# Name: Description, dtype: object
# 6                           41    Flag if client's permanent address does not match work address (1=different, 0=same, at city level)
# Name: Description, dtype: object
# 7                                                                                       43    Type of organization where client works
# Name: Description, dtype: object
# 8                                                                                                100    Did client provide document 3
# Name: Description, dtype: object
# 9                                                                                              9    Number of children the client has
# Name: Description, dtype: object
# 10                                                                 36    Approximately at what hour did the client apply for the loan
# Name: Description, dtype: object
# 11                          96    How many observation of client's social surroundings with observable 60 DPD (days past due) default
# Name: Description, dtype: object
# 12                                     97    How many observation of client's social surroundings defaulted on 60 (days past due) DPD
# Name: Description, dtype: object
# 13                                           119    Number of enquiries to Credit Bureau about the client one hour before application
# Name: Description, dtype: object
# 14    120    Number of enquiries to Credit Bureau about the client one day before application (excluding one hour before application)
# Name: Description, dtype: object
# 15    121    Number of enquiries to Credit Bureau about the client one week before application (excluding one day before application)
# Name: Description, dtype: object
# 16  122    Number of enquiries to Credit Bureau about the client one month before application (excluding one week before application)
# Name: Description, dtype: object
# 17   123    Number of enquiries to Credit Bureau about the client 3 month before application (excluding one month before application)
# Name: Description, dtype: object
# 18             124    Number of enquiries to Credit Bureau about the client one day year (excluding last 3 months before application)
# Name: Description, dtype: object

# %% [markdown]
# Die Kreditwürdigkeit hängt nicht von der Uhrzeit ab

# %%
remove = ["HOUR_APPR_PROCESS_START"]

# %%
df = df.drop(remove, axis=1)

# %% [markdown]
# ### Einfügen eines Präfixes zur Wiedererkennbarkeit
# A = Application

# %%
df = df.add_prefix("A_")

# %%
df = df.rename(columns={"A_TARGET": "TARGET"})

# %% [markdown]
# ### Ergebnis

# %%
df.head()
# Out:
#             TARGET  A_CODE_GENDER  A_NAME_INCOME_TYPE  A_NAME_EDUCATION_TYPE  \
# SK_ID_CURR
# 100002           1              0                   0                      0
# 100003           0              1                   1                      1
# 100004           0              0                   0                      0
# 100006           0              1                   0                      0
# 100007           0              0                   0                      0
#
#             A_FLAG_EMP_PHONE  A_OCCUPATION_TYPE  A_REGION_RATING_CLIENT  \
# SK_ID_CURR
# 100002                     1                  0                       2
# 100003                     1                  1                       1
# 100004                     1                  0                       2
# 100006                     1                  0                       2
# 100007                     1                  1                       2
#
#             A_REG_CITY_NOT_WORK_CITY  A_ORGANIZATION_TYPE  A_FLAG_DOCUMENT_3  \
# SK_ID_CURR
# 100002                             0                    0                  1
# 100003                             0                    1                  1
# 100004                             0                    2                  0
# 100006                             0                    0                  1
# 100007                             1                    3                  0
#
#             A_CNT_CHILDREN  A_OBS_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                   0                         2.0
# 100003                   0                         1.0
# 100004                   0                         0.0
# 100006                   0                         2.0
# 100007                   0                         0.0
#
#             A_DEF_60_CNT_SOCIAL_CIRCLE  A_AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100002                             2.0                           0.0
# 100003                             0.0                           0.0
# 100004                             0.0                           0.0
# 100006                             0.0                           NaN
# 100007                             0.0                           0.0
#
#             A_AMT_REQ_CREDIT_BUREAU_DAY  A_AMT_REQ_CREDIT_BUREAU_WEEK  \
# SK_ID_CURR
# 100002                              0.0                           0.0
# 100003                              0.0                           0.0
# 100004                              0.0                           0.0
# 100006                              NaN                           NaN
# 100007                              0.0                           0.0
#
#             A_AMT_REQ_CREDIT_BUREAU_MON  A_AMT_REQ_CREDIT_BUREAU_QRT  \
# SK_ID_CURR
# 100002                              0.0                          0.0
# 100003                              0.0                          0.0
# 100004                              0.0                          0.0
# 100006                              NaN                          NaN
# 100007                              0.0                          0.0
#
#             A_AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR
# 100002                               1.0
# 100003                               0.0
# 100004                               0.0
# 100006                               NaN
# 100007                               0.0

# %%
cats = df

# %% [markdown]
# ## <u>metrische Variablen

# %%
df = app_train[["TARGET"] + m_heads].copy()

# %%
df.head()
# Out:
#             TARGET  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# 100002           1          202500.0    406597.5      24700.5
# 100003           0          270000.0   1293502.5      35698.5
# 100004           0           67500.0    135000.0       6750.0
# 100006           0          135000.0    312682.5      29686.5
# 100007           0          121500.0    513000.0      21865.5
#
#             AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# SK_ID_CURR
# 100002             351000.0                    0.018801       -9461
# 100003            1129500.0                    0.003541      -16765
# 100004             135000.0                    0.010032      -19046
# 100006             297000.0                    0.008019      -19005
# 100007             513000.0                    0.028663      -19932
#
#             DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  \
# SK_ID_CURR
# 100002               -637            -3648.0            -2120          NaN
# 100003              -1188            -1186.0             -291          NaN
# 100004               -225            -4260.0            -2531         26.0
# 100006              -3039            -9833.0            -2437          NaN
# 100007              -3038            -4311.0            -3458          NaN
#
#             EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  APARTMENTS_AVG  \
# SK_ID_CURR
# 100002          0.083037      0.262949      0.139376          0.0247
# 100003          0.311267      0.622246           NaN          0.0959
# 100004               NaN      0.555912      0.729567             NaN
# 100006               NaN      0.650442           NaN             NaN
# 100007               NaN      0.322738           NaN             NaN
#
#             BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  YEARS_BUILD_AVG  \
# SK_ID_CURR
# 100002                0.0369                       0.9722           0.6192
# 100003                0.0529                       0.9851           0.7960
# 100004                   NaN                          NaN              NaN
# 100006                   NaN                          NaN              NaN
# 100007                   NaN                          NaN              NaN
#
#             COMMONAREA_AVG  ELEVATORS_AVG  ENTRANCES_AVG  FLOORSMAX_AVG  \
# SK_ID_CURR
# 100002              0.0143           0.00         0.0690         0.0833
# 100003              0.0605           0.08         0.0345         0.2917
# 100004                 NaN            NaN            NaN            NaN
# 100006                 NaN            NaN            NaN            NaN
# 100007                 NaN            NaN            NaN            NaN
#
#             FLOORSMIN_AVG  LANDAREA_AVG  LIVINGAPARTMENTS_AVG  LIVINGAREA_AVG  \
# SK_ID_CURR
# 100002             0.1250        0.0369                0.0202          0.0190
# 100003             0.3333        0.0130                0.0773          0.0549
# 100004                NaN           NaN                   NaN             NaN
# 100006                NaN           NaN                   NaN             NaN
# 100007                NaN           NaN                   NaN             NaN
#
#             NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  APARTMENTS_MODE  \
# SK_ID_CURR
# 100002                       0.0000             0.0000           0.0252
# 100003                       0.0039             0.0098           0.0924
# 100004                          NaN                NaN              NaN
# 100006                          NaN                NaN              NaN
# 100007                          NaN                NaN              NaN
#
#             BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  YEARS_BUILD_MODE  \
# SK_ID_CURR
# 100002                 0.0383                        0.9722            0.6341
# 100003                 0.0538                        0.9851            0.8040
# 100004                    NaN                           NaN               NaN
# 100006                    NaN                           NaN               NaN
# 100007                    NaN                           NaN               NaN
#
#             COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  FLOORSMAX_MODE  \
# SK_ID_CURR
# 100002               0.0144          0.0000          0.0690          0.0833
# 100003               0.0497          0.0806          0.0345          0.2917
# 100004                  NaN             NaN             NaN             NaN
# 100006                  NaN             NaN             NaN             NaN
# 100007                  NaN             NaN             NaN             NaN
#
#             FLOORSMIN_MODE  LANDAREA_MODE  LIVINGAPARTMENTS_MODE  \
# SK_ID_CURR
# 100002              0.1250         0.0377                  0.022
# 100003              0.3333         0.0128                  0.079
# 100004                 NaN            NaN                    NaN
# 100006                 NaN            NaN                    NaN
# 100007                 NaN            NaN                    NaN
#
#             LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_MODE  \
# SK_ID_CURR
# 100002               0.0198                       0.0                 0.0
# 100003               0.0554                       0.0                 0.0
# 100004                  NaN                       NaN                 NaN
# 100006                  NaN                       NaN                 NaN
# 100007                  NaN                       NaN                 NaN
#
#             APARTMENTS_MEDI  BASEMENTAREA_MEDI  YEARS_BEGINEXPLUATATION_MEDI  \
# SK_ID_CURR
# 100002               0.0250             0.0369                        0.9722
# 100003               0.0968             0.0529                        0.9851
# 100004                  NaN                NaN                           NaN
# 100006                  NaN                NaN                           NaN
# 100007                  NaN                NaN                           NaN
#
#             YEARS_BUILD_MEDI  COMMONAREA_MEDI  ELEVATORS_MEDI  ENTRANCES_MEDI  \
# SK_ID_CURR
# 100002                0.6243           0.0144            0.00          0.0690
# 100003                0.7987           0.0608            0.08          0.0345
# 100004                   NaN              NaN             NaN             NaN
# 100006                   NaN              NaN             NaN             NaN
# 100007                   NaN              NaN             NaN             NaN
#
#             FLOORSMAX_MEDI  FLOORSMIN_MEDI  LANDAREA_MEDI  \
# SK_ID_CURR
# 100002              0.0833          0.1250         0.0375
# 100003              0.2917          0.3333         0.0132
# 100004                 NaN             NaN            NaN
# 100006                 NaN             NaN            NaN
# 100007                 NaN             NaN            NaN
#
#             LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  NONLIVINGAPARTMENTS_MEDI  \
# SK_ID_CURR
# 100002                     0.0205           0.0193                    0.0000
# 100003                     0.0787           0.0558                    0.0039
# 100004                        NaN              NaN                       NaN
# 100006                        NaN              NaN                       NaN
# 100007                        NaN              NaN                       NaN
#
#             NONLIVINGAREA_MEDI  TOTALAREA_MODE  DAYS_LAST_PHONE_CHANGE
# SK_ID_CURR
# 100002                    0.00          0.0149                 -1134.0
# 100003                    0.01          0.0714                  -828.0
# 100004                     NaN             NaN                  -815.0
# 100006                     NaN             NaN                  -617.0
# 100007                     NaN             NaN                 -1106.0

# %% [markdown]
# ### Löschung der Spalten mit weniger als 40% ausgefüllten Daten

# %%
result = {
          "header":[],
          "rate":[],
          "des":[]
         }
for key in df.keys():
    if key in skip:
        continue
    rate = df[key].isna().sum() / len(df[key]) * 100
    if rate > 60:
        result["header"].append(key)
        result["rate"].append(rate)
        result["des"].append(des[des["Row"] == key]["Description"])

result = pd.DataFrame(result)
result
# Out:
#                       header       rate  \
# 0                OWN_CAR_AGE  65.990810
# 1            YEARS_BUILD_AVG  66.497784
# 2             COMMONAREA_AVG  69.872297
# 3              FLOORSMIN_AVG  67.848630
# 4       LIVINGAPARTMENTS_AVG  68.354953
# 5    NONLIVINGAPARTMENTS_AVG  69.432963
# 6           YEARS_BUILD_MODE  66.497784
# 7            COMMONAREA_MODE  69.872297
# 8             FLOORSMIN_MODE  67.848630
# 9      LIVINGAPARTMENTS_MODE  68.354953
# 10  NONLIVINGAPARTMENTS_MODE  69.432963
# 11          YEARS_BUILD_MEDI  66.497784
# 12           COMMONAREA_MEDI  69.872297
# 13            FLOORSMIN_MEDI  67.848630
# 14     LIVINGAPARTMENTS_MEDI  68.354953
# 15  NONLIVINGAPARTMENTS_MEDI  69.432963
#
#                                                                                                                                                                                                                                                                                                                             des
# 0                                                                                                                                                                                                                                                                    24    Age of client's car
# Name: Description, dtype: object
# 1   50    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 2   51    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 3   55    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 4   57    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 5   59    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 6   64    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 7   65    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 8   69    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 9   71    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 10  73    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 11  78    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 12  79    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 13  83    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 14  85    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 15  87    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object

# %%
df = df.drop(result.header.values, axis=1)

# %% [markdown]
# Es werden 16 Variablen mit mehr als 60% fehlenden Daten gelöscht.

# %% [markdown]
# ### Bildung von Korrelationsclustern

# %%
c = df.corr(method='pearson') * 100

# %%
c
# Out:
#                                   TARGET  AMT_INCOME_TOTAL  AMT_CREDIT  \
# TARGET                        100.000000         -0.398187   -3.036929
# AMT_INCOME_TOTAL               -0.398187        100.000000   15.687027
# AMT_CREDIT                     -3.036929         15.687027  100.000000
# AMT_ANNUITY                    -1.281656         19.165743   77.013800
# AMT_GOODS_PRICE                -3.964528         15.961006   98.696831
# REGION_POPULATION_RELATIVE     -3.722715          7.479570    9.973788
# DAYS_BIRTH                      7.823931          2.726087   -5.543595
# DAYS_EMPLOYED                  -4.493166         -6.422340   -6.683834
# DAYS_REGISTRATION               4.197486          2.780542    0.962133
# DAYS_ID_PUBLISH                 5.145717          0.850624   -0.657477
# EXT_SOURCE_1                  -15.531713          2.623237   16.842890
# EXT_SOURCE_2                  -16.047167          6.092464   13.122794
# EXT_SOURCE_3                  -17.891870         -3.022905    4.351626
# APARTMENTS_AVG                 -2.949756          3.450054    6.043923
# BASEMENTAREA_AVG               -2.274574          1.730277    3.922616
# YEARS_BEGINEXPLUATATION_AVG    -0.972767          0.565810    0.624876
# ELEVATORS_AVG                  -3.419879          4.505278    8.063502
# ENTRANCES_AVG                  -1.917218          0.539441    1.492928
# FLOORSMAX_AVG                  -4.400337          6.017114   10.329577
# LANDAREA_AVG                   -1.088482         -0.159823    0.621797
# LIVINGAREA_AVG                 -3.299712          3.997567    7.214592
# NONLIVINGAREA_AVG              -1.357807          7.460417    3.788452
# APARTMENTS_MODE                -2.728387          2.999424    5.307205
# BASEMENTAREA_MODE              -1.995228          1.282130    3.121269
# YEARS_BEGINEXPLUATATION_MODE   -0.903645          0.528382    0.480385
# ELEVATORS_MODE                 -3.213117          4.103182    7.473989
# ENTRANCES_MODE                 -1.738742          0.202701    0.936122
# FLOORSMAX_MODE                 -4.322626          5.767546   10.041809
# LANDAREA_MODE                  -1.017410         -0.367382    0.253212
# LIVINGAREA_MODE                -3.068462          3.491465    6.414174
# NONLIVINGAREA_MODE             -1.271054          6.177807    3.239041
# APARTMENTS_MEDI                -2.918376          3.379773    5.868221
# BASEMENTAREA_MEDI              -2.208126          1.638131    3.728099
# YEARS_BEGINEXPLUATATION_MEDI   -0.999310          0.563881    0.576509
# ELEVATORS_MEDI                 -3.386288          4.415970    7.909438
# ENTRANCES_MEDI                 -1.902476          0.478697    1.369207
# FLOORSMAX_MEDI                 -4.376792          5.968199   10.277029
# LANDAREA_MEDI                  -1.125583         -0.189161    0.541497
# LIVINGAREA_MEDI                -3.273928          3.926142    7.085962
# NONLIVINGAREA_MEDI             -1.333672          7.084449    3.582943
# TOTALAREA_MODE                 -3.259555          4.198466    7.281803
# DAYS_LAST_PHONE_CHANGE          5.521848         -1.858512   -7.370111
#
#                               AMT_ANNUITY  AMT_GOODS_PRICE  \
# TARGET                          -1.281656        -3.964528
# AMT_INCOME_TOTAL                19.165743        15.961006
# AMT_CREDIT                      77.013800        98.696831
# AMT_ANNUITY                    100.000000        77.510927
# AMT_GOODS_PRICE                 77.510927       100.000000
# REGION_POPULATION_RELATIVE      11.842909        10.351971
# DAYS_BIRTH                       0.944547        -5.344231
# DAYS_EMPLOYED                  -10.433186        -6.484199
# DAYS_REGISTRATION                3.851425         1.156498
# DAYS_ID_PUBLISH                  1.126805        -0.926681
# EXT_SOURCE_1                    11.939838        17.550222
# EXT_SOURCE_2                    12.580400        13.936680
# EXT_SOURCE_3                     3.075182         4.771684
# APARTMENTS_AVG                   7.621259         6.491767
# BASEMENTAREA_AVG                 4.450711         4.398154
# YEARS_BEGINEXPLUATATION_AVG      1.329810         0.724476
# ELEVATORS_AVG                   10.143934         8.373558
# ENTRANCES_AVG                    1.474534         1.876357
# FLOORSMAX_AVG                   13.017365        10.851246
# LANDAREA_AVG                     0.861073         1.329653
# LIVINGAREA_AVG                   8.965913         7.730695
# NONLIVINGAREA_AVG                4.959269         4.191172
# APARTMENTS_MODE                  6.640083         5.752268
# BASEMENTAREA_MODE                3.444344         3.581102
# YEARS_BEGINEXPLUATATION_MODE     1.255473         0.579881
# ELEVATORS_MODE                   9.313110         7.797752
# ENTRANCES_MODE                   0.736217         1.333479
# FLOORSMAX_MODE                  12.630160        10.553212
# LANDAREA_MODE                    0.362104         0.937892
# LIVINGAREA_MODE                  7.942566         6.932426
# NONLIVINGAREA_MODE               4.141770         3.640300
# APARTMENTS_MEDI                  7.398706         6.318678
# BASEMENTAREA_MEDI                4.245173         4.198048
# YEARS_BEGINEXPLUATATION_MEDI     1.293984         0.683868
# ELEVATORS_MEDI                   9.955854         8.226581
# ENTRANCES_MEDI                   1.327609         1.758526
# FLOORSMAX_MEDI                  12.917901        10.793597
# LANDAREA_MEDI                    0.771076         1.255026
# LIVINGAREA_MEDI                  8.813429         7.602761
# NONLIVINGAREA_MEDI               4.700866         3.987395
# TOTALAREA_MODE                   9.041456         7.752690
# DAYS_LAST_PHONE_CHANGE          -6.374689        -7.631286
#
#                               REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# TARGET                                         -3.722715    7.823931
# AMT_INCOME_TOTAL                                7.479570    2.726087
# AMT_CREDIT                                      9.973788   -5.543595
# AMT_ANNUITY                                    11.842909    0.944547
# AMT_GOODS_PRICE                                10.351971   -5.344231
# REGION_POPULATION_RELATIVE                    100.000000   -2.958228
# DAYS_BIRTH                                     -2.958228  100.000000
# DAYS_EMPLOYED                                  -0.397979  -61.586420
# DAYS_REGISTRATION                              -5.381964   33.191208
# DAYS_ID_PUBLISH                                -0.399337   27.269066
# EXT_SOURCE_1                                    9.999729  -60.060997
# EXT_SOURCE_2                                   19.892417   -9.199587
# EXT_SOURCE_3                                   -0.600113  -20.547760
# APARTMENTS_AVG                                 20.594209    0.477888
# BASEMENTAREA_AVG                                9.842337   -0.439976
# YEARS_BEGINEXPLUATATION_AVG                    -0.668261    0.074389
# ELEVATORS_AVG                                  28.068507   -0.144750
# ENTRANCES_AVG                                   3.684005   -1.028123
# FLOORSMAX_AVG                                  32.265151    0.163364
# LANDAREA_AVG                                   -5.115989    0.301341
# LIVINGAREA_AVG                                 21.349113   -0.033354
# NONLIVINGAREA_AVG                               7.481561    0.571240
# APARTMENTS_MODE                                17.502863    0.495920
# BASEMENTAREA_MODE                               6.577913   -0.431910
# YEARS_BEGINEXPLUATATION_MODE                   -0.683724    0.071388
# ELEVATORS_MODE                                 25.153927   -0.088877
# ENTRANCES_MODE                                  1.598336   -0.937417
# FLOORSMAX_MODE                                 30.399203    0.129378
# LANDAREA_MODE                                  -6.055819    0.379983
# LIVINGAREA_MODE                                18.093152   -0.002027
# NONLIVINGAREA_MODE                              4.969550    0.553791
# APARTMENTS_MEDI                                20.138043    0.509188
# BASEMENTAREA_MEDI                               9.407531   -0.434478
# YEARS_BEGINEXPLUATATION_MEDI                   -0.671069    0.078726
# ELEVATORS_MEDI                                 27.439040   -0.129852
# ENTRANCES_MEDI                                  3.362828   -0.987594
# FLOORSMAX_MEDI                                 31.831898    0.179054
# LANDAREA_MEDI                                  -5.254729    0.334058
# LIVINGAREA_MEDI                                20.934720    0.009954
# NONLIVINGAREA_MEDI                              6.606027    0.632317
# TOTALAREA_MODE                                 20.214519    0.132948
# DAYS_LAST_PHONE_CHANGE                         -4.401321    8.293907
#
#                               DAYS_EMPLOYED  DAYS_REGISTRATION  \
# TARGET                            -4.493166           4.197486
# AMT_INCOME_TOTAL                  -6.422340           2.780542
# AMT_CREDIT                        -6.683834           0.962133
# AMT_ANNUITY                      -10.433186           3.851425
# AMT_GOODS_PRICE                   -6.484199           1.156498
# REGION_POPULATION_RELATIVE        -0.397979          -5.381964
# DAYS_BIRTH                       -61.586420          33.191208
# DAYS_EMPLOYED                    100.000000         -21.024178
# DAYS_REGISTRATION                -21.024178         100.000000
# DAYS_ID_PUBLISH                  -27.237804          10.189559
# EXT_SOURCE_1                      28.984780         -18.109459
# EXT_SOURCE_2                      -2.076710          -5.991282
# EXT_SOURCE_3                      11.343448         -10.754884
# APARTMENTS_AVG                    -1.635863           1.318569
# BASEMENTAREA_AVG                  -0.138204          -2.072946
# YEARS_BEGINEXPLUATATION_AVG        0.862909           1.103470
# ELEVATORS_AVG                     -0.979156           0.074619
# ENTRANCES_AVG                      0.401770          -6.309432
# FLOORSMAX_AVG                     -1.596957           4.970077
# LANDAREA_AVG                      -0.960876           0.310937
# LIVINGAREA_AVG                    -1.243810           0.741906
# NONLIVINGAREA_AVG                 -1.285785           4.901173
# APARTMENTS_MODE                   -1.463241           1.273227
# BASEMENTAREA_MODE                 -0.024291          -2.001059
# YEARS_BEGINEXPLUATATION_MODE       0.863706           0.878266
# ELEVATORS_MODE                    -0.880208           0.272931
# ENTRANCES_MODE                     0.494290          -6.008719
# FLOORSMAX_MODE                    -1.506369           4.965687
# LANDAREA_MODE                     -0.875768           0.335356
# LIVINGAREA_MODE                   -1.084709           0.745654
# NONLIVINGAREA_MODE                -1.172571           4.719655
# APARTMENTS_MEDI                   -1.623898           1.346335
# BASEMENTAREA_MEDI                 -0.153533          -2.150375
# YEARS_BEGINEXPLUATATION_MEDI       0.840453           1.103856
# ELEVATORS_MEDI                    -0.981703           0.172590
# ENTRANCES_MEDI                     0.413798          -6.259933
# FLOORSMAX_MEDI                    -1.605082           5.007612
# LANDAREA_MEDI                     -0.962651           0.296825
# LIVINGAREA_MEDI                   -1.263053           0.792554
# NONLIVINGAREA_MEDI                -1.297540           4.993146
# TOTALAREA_MODE                    -1.512620           1.949523
# DAYS_LAST_PHONE_CHANGE             2.303239           5.698257
#
#                               DAYS_ID_PUBLISH  EXT_SOURCE_1  EXT_SOURCE_2  \
# TARGET                               5.145717    -15.531713    -16.047167
# AMT_INCOME_TOTAL                     0.850624      2.623237      6.092464
# AMT_CREDIT                          -0.657477     16.842890     13.122794
# AMT_ANNUITY                          1.126805     11.939838     12.580400
# AMT_GOODS_PRICE                     -0.926681     17.550222     13.936680
# REGION_POPULATION_RELATIVE          -0.399337      9.999729     19.892417
# DAYS_BIRTH                          27.269066    -60.060997     -9.199587
# DAYS_EMPLOYED                      -27.237804     28.984780     -2.076710
# DAYS_REGISTRATION                   10.189559    -18.109459     -5.991282
# DAYS_ID_PUBLISH                    100.000000    -13.237490     -5.095513
# EXT_SOURCE_1                       -13.237490    100.000000     21.398238
# EXT_SOURCE_2                        -5.095513     21.398238    100.000000
# EXT_SOURCE_3                       -13.159687     18.684551     10.916729
# APARTMENTS_AVG                      -0.732157      5.403402      9.097104
# BASEMENTAREA_AVG                    -1.403181      3.996225      4.833827
# YEARS_BEGINEXPLUATATION_AVG         -0.341554      0.211955      0.906624
# ELEVATORS_AVG                       -1.055493      7.453847     11.505849
# ENTRANCES_AVG                       -1.537463      2.237836      3.248883
# FLOORSMAX_AVG                       -1.023531      9.315135     13.586325
# LANDAREA_AVG                        -0.749625      0.549417      2.227000
# LIVINGAREA_AVG                      -1.151470      6.820123      9.757929
# NONLIVINGAREA_AVG                    0.230794      3.150017      4.508297
# APARTMENTS_MODE                     -0.712937      4.758053      8.049630
# BASEMENTAREA_MODE                   -1.319181      3.469221      3.768175
# YEARS_BEGINEXPLUATATION_MODE        -0.259041      0.144242      0.816324
# ELEVATORS_MODE                      -1.063364      6.859538     10.618003
# ENTRANCES_MODE                      -1.554783      1.749914      2.377102
# FLOORSMAX_MODE                      -1.030816      8.976048     13.011661
# LANDAREA_MODE                       -0.802611      0.242600      1.731441
# LIVINGAREA_MODE                     -1.209608      6.204596      8.602637
# NONLIVINGAREA_MODE                   0.132127      2.642040      3.731341
# APARTMENTS_MEDI                     -0.713933      5.252364      8.929369
# BASEMENTAREA_MEDI                   -1.412888      3.949396      4.695062
# YEARS_BEGINEXPLUATATION_MEDI        -0.319344      0.207726      0.903506
# ELEVATORS_MEDI                      -1.044818      7.306587     11.346758
# ENTRANCES_MEDI                      -1.564717      2.148798      3.123609
# FLOORSMAX_MEDI                      -1.030744      9.210779     13.461180
# LANDAREA_MEDI                       -0.763417      0.499151      2.122683
# LIVINGAREA_MEDI                     -1.131529      6.711063      9.608190
# NONLIVINGAREA_MEDI                   0.248770      3.037532      4.263992
# TOTALAREA_MODE                      -1.115253      6.622712      9.468728
# DAYS_LAST_PHONE_CHANGE               8.857590    -13.260719    -19.576417
#
#                               EXT_SOURCE_3  APARTMENTS_AVG  BASEMENTAREA_AVG  \
# TARGET                          -17.891870       -2.949756         -2.274574
# AMT_INCOME_TOTAL                 -3.022905        3.450054          1.730277
# AMT_CREDIT                        4.351626        6.043923          3.922616
# AMT_ANNUITY                       3.075182        7.621259          4.450711
# AMT_GOODS_PRICE                   4.771684        6.491767          4.398154
# REGION_POPULATION_RELATIVE       -0.600113       20.594209          9.842337
# DAYS_BIRTH                      -20.547760        0.477888         -0.439976
# DAYS_EMPLOYED                    11.343448       -1.635863         -0.138204
# DAYS_REGISTRATION               -10.754884        1.318569         -2.072946
# DAYS_ID_PUBLISH                 -13.159687       -0.732157         -1.403181
# EXT_SOURCE_1                     18.684551        5.403402          3.996225
# EXT_SOURCE_2                     10.916729        9.097104          4.833827
# EXT_SOURCE_3                    100.000000        0.571472          0.923179
# APARTMENTS_AVG                    0.571472      100.000000         67.938858
# BASEMENTAREA_AVG                  0.923179       67.938858        100.000000
# YEARS_BEGINEXPLUATATION_AVG      -0.040572       10.009804          8.594998
# ELEVATORS_AVG                     0.736597       83.695804         56.490710
# ENTRANCES_AVG                     1.226793       61.124090         65.115957
# FLOORSMAX_AVG                     0.352293       61.874584         32.984335
# LANDAREA_AVG                      1.075060       49.685235         46.766058
# LIVINGAREA_AVG                    0.563406       91.361876         69.289063
# NONLIVINGAREA_AVG                -0.233613       29.971886         26.634917
# APARTMENTS_MODE                   0.487943       97.325946         66.602345
# BASEMENTAREA_MODE                 0.807806       66.147888         97.349578
# YEARS_BEGINEXPLUATATION_MODE     -0.061145        9.513082          5.842063
# ELEVATORS_MODE                    0.707155       82.255328         55.509615
# ENTRANCES_MODE                    1.090332       58.315803         62.638213
# FLOORSMAX_MODE                    0.437849       61.449755         32.875767
# LANDAREA_MODE                     0.939765       48.765145         46.196936
# LIVINGAREA_MODE                   0.543666       89.346312         67.715920
# NONLIVINGAREA_MODE               -0.266467       28.494223         26.004693
# APARTMENTS_MEDI                   0.553788       99.508082         67.817413
# BASEMENTAREA_MEDI                 0.934868       67.897692         99.431734
# YEARS_BEGINEXPLUATATION_MEDI      0.016827        9.962012          7.749044
# ELEVATORS_MEDI                    0.739755       83.512267         56.234692
# ENTRANCES_MEDI                    1.218100       60.762933         64.700652
# FLOORSMAX_MEDI                    0.380820       61.658145         32.794921
# LANDAREA_MEDI                     1.072523       49.905231         46.999398
# LIVINGAREA_MEDI                   0.548626       91.232957         68.931843
# NONLIVINGAREA_MEDI               -0.287608       29.745436         26.538177
# TOTALAREA_MODE                    0.623226       89.262693         67.239971
# DAYS_LAST_PHONE_CHANGE           -7.525615       -0.856399         -0.741843
#
#                               YEARS_BEGINEXPLUATATION_AVG  ELEVATORS_AVG  \
# TARGET                                          -0.972767      -3.419879
# AMT_INCOME_TOTAL                                 0.565810       4.505278
# AMT_CREDIT                                       0.624876       8.063502
# AMT_ANNUITY                                      1.329810      10.143934
# AMT_GOODS_PRICE                                  0.724476       8.373558
# REGION_POPULATION_RELATIVE                      -0.668261      28.068507
# DAYS_BIRTH                                       0.074389      -0.144750
# DAYS_EMPLOYED                                    0.862909      -0.979156
# DAYS_REGISTRATION                                1.103470       0.074619
# DAYS_ID_PUBLISH                                 -0.341554      -1.055493
# EXT_SOURCE_1                                     0.211955       7.453847
# EXT_SOURCE_2                                     0.906624      11.505849
# EXT_SOURCE_3                                    -0.040572       0.736597
# APARTMENTS_AVG                                  10.009804      83.695804
# BASEMENTAREA_AVG                                 8.594998      56.490710
# YEARS_BEGINEXPLUATATION_AVG                    100.000000       7.892072
# ELEVATORS_AVG                                    7.892072     100.000000
# ENTRANCES_AVG                                    4.207502      40.520492
# FLOORSMAX_AVG                                   12.757331      68.007807
# LANDAREA_AVG                                     7.391675      37.528020
# LIVINGAREA_AVG                                   9.273632      86.777567
# NONLIVINGAREA_AVG                                0.966581      28.336692
# APARTMENTS_MODE                                 10.066517      80.600903
# BASEMENTAREA_MODE                                8.075405      53.997268
# YEARS_BEGINEXPLUATATION_MODE                    97.189337       7.215839
# ELEVATORS_MODE                                   7.957835      97.883728
# ENTRANCES_MODE                                   3.756590      37.562583
# FLOORSMAX_MODE                                  12.708561      67.098782
# LANDAREA_MODE                                    7.000800      36.173291
# LIVINGAREA_MODE                                  8.912266      83.891972
# NONLIVINGAREA_MODE                               0.862709      26.470934
# APARTMENTS_MEDI                                 10.013191      83.452268
# BASEMENTAREA_MEDI                                8.525596      56.299901
# YEARS_BEGINEXPLUATATION_MEDI                    99.382542       7.770286
# ELEVATORS_MEDI                                   7.899495      99.609944
# ENTRANCES_MEDI                                   4.133435      40.170759
# FLOORSMAX_MEDI                                  12.727333      67.777056
# LANDAREA_MEDI                                    7.406669      37.653066
# LIVINGAREA_MEDI                                  9.217544      86.557949
# NONLIVINGAREA_MEDI                               0.845254      28.014232
# TOTALAREA_MODE                                  10.031935      84.462754
# DAYS_LAST_PHONE_CHANGE                           0.251481      -0.983571
#
#                               ENTRANCES_AVG  FLOORSMAX_AVG  LANDAREA_AVG  \
# TARGET                            -1.917218      -4.400337     -1.088482
# AMT_INCOME_TOTAL                   0.539441       6.017114     -0.159823
# AMT_CREDIT                         1.492928      10.329577      0.621797
# AMT_ANNUITY                        1.474534      13.017365      0.861073
# AMT_GOODS_PRICE                    1.876357      10.851246      1.329653
# REGION_POPULATION_RELATIVE         3.684005      32.265151     -5.115989
# DAYS_BIRTH                        -1.028123       0.163364      0.301341
# DAYS_EMPLOYED                      0.401770      -1.596957     -0.960876
# DAYS_REGISTRATION                 -6.309432       4.970077      0.310937
# DAYS_ID_PUBLISH                   -1.537463      -1.023531     -0.749625
# EXT_SOURCE_1                       2.237836       9.315135      0.549417
# EXT_SOURCE_2                       3.248883      13.586325      2.227000
# EXT_SOURCE_3                       1.226793       0.352293      1.075060
# APARTMENTS_AVG                    61.124090      61.874584     49.685235
# BASEMENTAREA_AVG                  65.115957      32.984335     46.766058
# YEARS_BEGINEXPLUATATION_AVG        4.207502      12.757331      7.391675
# ELEVATORS_AVG                     40.520492      68.007807     37.528020
# ENTRANCES_AVG                    100.000000       8.870764     50.825578
# FLOORSMAX_AVG                      8.870764     100.000000     21.886536
# LANDAREA_AVG                      50.825578      21.886536    100.000000
# LIVINGAREA_AVG                    61.888171      63.057684     50.157120
# NONLIVINGAREA_AVG                 16.572923      25.384403     16.353834
# APARTMENTS_MODE                   61.236401      58.596370     49.739547
# BASEMENTAREA_MODE                 65.363671      29.905679     47.100369
# YEARS_BEGINEXPLUATATION_MODE       3.743978      10.368359      5.122628
# ELEVATORS_MODE                    40.403802      65.625407     37.759184
# ENTRANCES_MODE                    97.774256       6.271922     49.715502
# FLOORSMAX_MODE                     9.210551      98.568942     22.158472
# LANDAREA_MODE                     51.070477      20.303221     97.369606
# LIVINGAREA_MODE                   62.282232      59.706418     50.179721
# NONLIVINGAREA_MODE                17.093041      22.517172     16.219268
# APARTMENTS_MEDI                   61.158704      61.524291     49.751984
# BASEMENTAREA_MEDI                 65.304718      32.584221     46.911722
# YEARS_BEGINEXPLUATATION_MEDI       4.056455      12.548908      6.847650
# ELEVATORS_MEDI                    40.487332      67.630558     37.565084
# ENTRANCES_MEDI                    99.688637       8.456265     50.685204
# FLOORSMAX_MEDI                     8.764193      99.703414     21.858997
# LANDAREA_MEDI                     51.114048      21.917038     99.160953
# LIVINGAREA_MEDI                   61.931192      62.715386     50.105008
# NONLIVINGAREA_MEDI                16.699800      24.709877     16.479747
# TOTALAREA_MODE                    59.529022      63.259471     49.109104
# DAYS_LAST_PHONE_CHANGE            -1.218715      -0.712982     -0.058131
#
#                               LIVINGAREA_AVG  NONLIVINGAREA_AVG  \
# TARGET                             -3.299712          -1.357807
# AMT_INCOME_TOTAL                    3.997567           7.460417
# AMT_CREDIT                          7.214592           3.788452
# AMT_ANNUITY                         8.965913           4.959269
# AMT_GOODS_PRICE                     7.730695           4.191172
# REGION_POPULATION_RELATIVE         21.349113           7.481561
# DAYS_BIRTH                         -0.033354           0.571240
# DAYS_EMPLOYED                      -1.243810          -1.285785
# DAYS_REGISTRATION                   0.741906           4.901173
# DAYS_ID_PUBLISH                    -1.151470           0.230794
# EXT_SOURCE_1                        6.820123           3.150017
# EXT_SOURCE_2                        9.757929           4.508297
# EXT_SOURCE_3                        0.563406          -0.233613
# APARTMENTS_AVG                     91.361876          29.971886
# BASEMENTAREA_AVG                   69.289063          26.634917
# YEARS_BEGINEXPLUATATION_AVG         9.273632           0.966581
# ELEVATORS_AVG                      86.777567          28.336692
# ENTRANCES_AVG                      61.888171          16.572923
# FLOORSMAX_AVG                      63.057684          25.384403
# LANDAREA_AVG                       50.157120          16.353834
# LIVINGAREA_AVG                    100.000000          30.210059
# NONLIVINGAREA_AVG                  30.210059         100.000000
# APARTMENTS_MODE                    89.072103          28.712943
# BASEMENTAREA_MODE                  67.435930          25.655041
# YEARS_BEGINEXPLUATATION_MODE        7.523029          -1.133993
# ELEVATORS_MODE                     85.259050          27.453777
# ENTRANCES_MODE                     59.040467          15.561290
# FLOORSMAX_MODE                     62.616751          24.849855
# LANDAREA_MODE                      49.123453          15.714693
# LIVINGAREA_MODE                    97.204984          28.677915
# NONLIVINGAREA_MODE                 28.607232          96.608655
# APARTMENTS_MEDI                    91.250418          29.710486
# BASEMENTAREA_MEDI                  69.261271          26.594852
# YEARS_BEGINEXPLUATATION_MEDI        8.889159           1.154250
# ELEVATORS_MEDI                     86.580480          28.046845
# ENTRANCES_MEDI                     61.507379          16.289330
# FLOORSMAX_MEDI                     62.857064          25.289292
# LANDAREA_MEDI                      50.350648          16.348885
# LIVINGAREA_MEDI                    99.559591          29.818676
# NONLIVINGAREA_MEDI                 30.000178          99.044353
# TOTALAREA_MODE                     92.503871          36.660437
# DAYS_LAST_PHONE_CHANGE             -1.064541          -0.170659
#
#                               APARTMENTS_MODE  BASEMENTAREA_MODE  \
# TARGET                              -2.728387          -1.995228
# AMT_INCOME_TOTAL                     2.999424           1.282130
# AMT_CREDIT                           5.307205           3.121269
# AMT_ANNUITY                          6.640083           3.444344
# AMT_GOODS_PRICE                      5.752268           3.581102
# REGION_POPULATION_RELATIVE          17.502863           6.577913
# DAYS_BIRTH                           0.495920          -0.431910
# DAYS_EMPLOYED                       -1.463241          -0.024291
# DAYS_REGISTRATION                    1.273227          -2.001059
# DAYS_ID_PUBLISH                     -0.712937          -1.319181
# EXT_SOURCE_1                         4.758053           3.469221
# EXT_SOURCE_2                         8.049630           3.768175
# EXT_SOURCE_3                         0.487943           0.807806
# APARTMENTS_AVG                      97.325946          66.147888
# BASEMENTAREA_AVG                    66.602345          97.349578
# YEARS_BEGINEXPLUATATION_AVG         10.066517           8.075405
# ELEVATORS_AVG                       80.600903          53.997268
# ENTRANCES_AVG                       61.236401          65.363671
# FLOORSMAX_AVG                       58.596370          29.905679
# LANDAREA_AVG                        49.739547          47.100369
# LIVINGAREA_AVG                      89.072103          67.435930
# NONLIVINGAREA_AVG                   28.712943          25.655041
# APARTMENTS_MODE                    100.000000          67.856525
# BASEMENTAREA_MODE                   67.856525         100.000000
# YEARS_BEGINEXPLUATATION_MODE        10.102058           5.689467
# ELEVATORS_MODE                      82.621593          55.375142
# ENTRANCES_MODE                      61.578185          65.414182
# FLOORSMAX_MODE                      59.576133          30.949343
# LANDAREA_MODE                       50.816029          48.333298
# LIVINGAREA_MODE                     91.037644          69.037921
# NONLIVINGAREA_MODE                  29.458067          27.227894
# APARTMENTS_MEDI                     97.719306          66.395506
# BASEMENTAREA_MEDI                   66.878325          97.793837
# YEARS_BEGINEXPLUATATION_MEDI         9.984973           7.226237
# ELEVATORS_MEDI                      80.885759          54.106084
# ENTRANCES_MEDI                      61.253593          65.257914
# FLOORSMAX_MEDI                      58.500726          29.861345
# LANDAREA_MEDI                       50.143963          47.509020
# LIVINGAREA_MEDI                     89.412210          67.364841
# NONLIVINGAREA_MEDI                  28.983932          26.135669
# TOTALAREA_MODE                      86.362840          64.927397
# DAYS_LAST_PHONE_CHANGE              -0.759791          -0.638883
#
#                               YEARS_BEGINEXPLUATATION_MODE  ELEVATORS_MODE  \
# TARGET                                           -0.903645       -3.213117
# AMT_INCOME_TOTAL                                  0.528382        4.103182
# AMT_CREDIT                                        0.480385        7.473989
# AMT_ANNUITY                                       1.255473        9.313110
# AMT_GOODS_PRICE                                   0.579881        7.797752
# REGION_POPULATION_RELATIVE                       -0.683724       25.153927
# DAYS_BIRTH                                        0.071388       -0.088877
# DAYS_EMPLOYED                                     0.863706       -0.880208
# DAYS_REGISTRATION                                 0.878266        0.272931
# DAYS_ID_PUBLISH                                  -0.259041       -1.063364
# EXT_SOURCE_1                                      0.144242        6.859538
# EXT_SOURCE_2                                      0.816324       10.618003
# EXT_SOURCE_3                                     -0.061145        0.707155
# APARTMENTS_AVG                                    9.513082       82.255328
# BASEMENTAREA_AVG                                  5.842063       55.509615
# YEARS_BEGINEXPLUATATION_AVG                      97.189337        7.957835
# ELEVATORS_AVG                                     7.215839       97.883728
# ENTRANCES_AVG                                     3.743978       40.403802
# FLOORSMAX_AVG                                    10.368359       65.625407
# LANDAREA_AVG                                      5.122628       37.759184
# LIVINGAREA_AVG                                    7.523029       85.259050
# NONLIVINGAREA_AVG                                -1.133993       27.453777
# APARTMENTS_MODE                                  10.102058       82.621593
# BASEMENTAREA_MODE                                 5.689467       55.375142
# YEARS_BEGINEXPLUATATION_MODE                    100.000000        7.650309
# ELEVATORS_MODE                                    7.650309      100.000000
# ENTRANCES_MODE                                    3.577785       40.209562
# FLOORSMAX_MODE                                   10.650675       66.091278
# LANDAREA_MODE                                     5.022183       37.920891
# LIVINGAREA_MODE                                   7.363205       85.597794
# NONLIVINGAREA_MODE                               -0.479001       27.378963
# APARTMENTS_MEDI                                   9.543401       82.561928
# BASEMENTAREA_MEDI                                 5.786377       55.615979
# YEARS_BEGINEXPLUATATION_MEDI                     96.353870        7.854952
# ELEVATORS_MEDI                                    7.267140       98.282789
# ENTRANCES_MEDI                                    3.699110       40.420219
# FLOORSMAX_MEDI                                   10.348969       65.561979
# LANDAREA_MEDI                                     5.140585       37.998888
# LIVINGAREA_MEDI                                   7.497505       85.576656
# NONLIVINGAREA_MEDI                               -1.216126       27.525237
# TOTALAREA_MODE                                    9.798727       82.081298
# DAYS_LAST_PHONE_CHANGE                            0.175297       -0.901204
#
#                               ENTRANCES_MODE  FLOORSMAX_MODE  LANDAREA_MODE  \
# TARGET                             -1.738742       -4.322626      -1.017410
# AMT_INCOME_TOTAL                    0.202701        5.767546      -0.367382
# AMT_CREDIT                          0.936122       10.041809       0.253212
# AMT_ANNUITY                         0.736217       12.630160       0.362104
# AMT_GOODS_PRICE                     1.333479       10.553212       0.937892
# REGION_POPULATION_RELATIVE          1.598336       30.399203      -6.055819
# DAYS_BIRTH                         -0.937417        0.129378       0.379983
# DAYS_EMPLOYED                       0.494290       -1.506369      -0.875768
# DAYS_REGISTRATION                  -6.008719        4.965687       0.335356
# DAYS_ID_PUBLISH                    -1.554783       -1.030816      -0.802611
# EXT_SOURCE_1                        1.749914        8.976048       0.242600
# EXT_SOURCE_2                        2.377102       13.011661       1.731441
# EXT_SOURCE_3                        1.090332        0.437849       0.939765
# APARTMENTS_AVG                     58.315803       61.449755      48.765145
# BASEMENTAREA_AVG                   62.638213       32.875767      46.196936
# YEARS_BEGINEXPLUATATION_AVG         3.756590       12.708561       7.000800
# ELEVATORS_AVG                      37.562583       67.098782      36.173291
# ENTRANCES_AVG                      97.774256        9.210551      51.070477
# FLOORSMAX_AVG                       6.271922       98.568942      20.303221
# LANDAREA_AVG                       49.715502       22.158472      97.369606
# LIVINGAREA_AVG                     59.040467       62.616751      49.123453
# NONLIVINGAREA_AVG                  15.561290       24.849855      15.714693
# APARTMENTS_MODE                    61.578185       59.576133      50.816029
# BASEMENTAREA_MODE                  65.414182       30.949343      48.333298
# YEARS_BEGINEXPLUATATION_MODE        3.577785       10.650675       5.022183
# ELEVATORS_MODE                     40.209562       66.091278      37.920891
# ENTRANCES_MODE                    100.000000        7.762604      51.679462
# FLOORSMAX_MODE                      7.762604      100.000000      21.307512
# LANDAREA_MODE                      51.679462       21.307512     100.000000
# LIVINGAREA_MODE                    62.289131       60.588490      51.253138
# NONLIVINGAREA_MODE                 17.634882       23.113837      17.043067
# APARTMENTS_MEDI                    58.795138       61.257045      48.993207
# BASEMENTAREA_MEDI                  63.132107       32.551992      46.513934
# YEARS_BEGINEXPLUATATION_MEDI        3.587820       12.464904       6.455335
# ELEVATORS_MEDI                     37.930077       66.919164      36.382506
# ENTRANCES_MEDI                     98.067716        8.781825      51.072429
# FLOORSMAX_MEDI                      6.202666       98.823749      20.300829
# LANDAREA_MEDI                      50.123723       22.187298      98.083549
# LIVINGAREA_MEDI                    59.482949       62.432151      49.242162
# NONLIVINGAREA_MEDI                 15.992533       24.378500      16.132132
# TOTALAREA_MODE                     56.122755       62.537417      47.838203
# DAYS_LAST_PHONE_CHANGE             -1.125495       -0.674930      -0.111092
#
#                               LIVINGAREA_MODE  NONLIVINGAREA_MODE  \
# TARGET                              -3.068462           -1.271054
# AMT_INCOME_TOTAL                     3.491465            6.177807
# AMT_CREDIT                           6.414174            3.239041
# AMT_ANNUITY                          7.942566            4.141770
# AMT_GOODS_PRICE                      6.932426            3.640300
# REGION_POPULATION_RELATIVE          18.093152            4.969550
# DAYS_BIRTH                          -0.002027            0.553791
# DAYS_EMPLOYED                       -1.084709           -1.172571
# DAYS_REGISTRATION                    0.745654            4.719655
# DAYS_ID_PUBLISH                     -1.209608            0.132127
# EXT_SOURCE_1                         6.204596            2.642040
# EXT_SOURCE_2                         8.602637            3.731341
# EXT_SOURCE_3                         0.543666           -0.266467
# APARTMENTS_AVG                      89.346312           28.494223
# BASEMENTAREA_AVG                    67.715920           26.004693
# YEARS_BEGINEXPLUATATION_AVG          8.912266            0.862709
# ELEVATORS_AVG                       83.891972           26.470934
# ENTRANCES_AVG                       62.282232           17.093041
# FLOORSMAX_AVG                       59.706418           22.517172
# LANDAREA_AVG                        50.179721           16.219268
# LIVINGAREA_AVG                      97.204984           28.607232
# NONLIVINGAREA_AVG                   28.677915           96.608655
# APARTMENTS_MODE                     91.037644           29.458067
# BASEMENTAREA_MODE                   69.037921           27.227894
# YEARS_BEGINEXPLUATATION_MODE         7.363205           -0.479001
# ELEVATORS_MODE                      85.597794           27.378963
# ENTRANCES_MODE                      62.289131           17.634882
# FLOORSMAX_MODE                      60.588490           23.113837
# LANDAREA_MODE                       51.253138           17.043067
# LIVINGAREA_MODE                    100.000000           29.572491
# NONLIVINGAREA_MODE                  29.572491          100.000000
# APARTMENTS_MEDI                     89.613405           28.588418
# BASEMENTAREA_MEDI                   68.054891           26.266448
# YEARS_BEGINEXPLUATATION_MEDI         8.473605            0.663786
# ELEVATORS_MEDI                      84.107310           26.534826
# ENTRANCES_MEDI                      62.223489           17.066367
# FLOORSMAX_MEDI                      59.619274           22.547815
# LANDAREA_MEDI                       50.552937           16.374621
# LIVINGAREA_MEDI                     97.474338           28.518926
# NONLIVINGAREA_MEDI                  29.036838           97.583853
# TOTALAREA_MODE                      89.924693           34.695690
# DAYS_LAST_PHONE_CHANGE              -0.960683           -0.139347
#
#                               APARTMENTS_MEDI  BASEMENTAREA_MEDI  \
# TARGET                              -2.918376          -2.208126
# AMT_INCOME_TOTAL                     3.379773           1.638131
# AMT_CREDIT                           5.868221           3.728099
# AMT_ANNUITY                          7.398706           4.245173
# AMT_GOODS_PRICE                      6.318678           4.198048
# REGION_POPULATION_RELATIVE          20.138043           9.407531
# DAYS_BIRTH                           0.509188          -0.434478
# DAYS_EMPLOYED                       -1.623898          -0.153533
# DAYS_REGISTRATION                    1.346335          -2.150375
# DAYS_ID_PUBLISH                     -0.713933          -1.412888
# EXT_SOURCE_1                         5.252364           3.949396
# EXT_SOURCE_2                         8.929369           4.695062
# EXT_SOURCE_3                         0.553788           0.934868
# APARTMENTS_AVG                      99.508082          67.897692
# BASEMENTAREA_AVG                    67.817413          99.431734
# YEARS_BEGINEXPLUATATION_AVG         10.013191           8.525596
# ELEVATORS_AVG                       83.452268          56.299901
# ENTRANCES_AVG                       61.158704          65.304718
# FLOORSMAX_AVG                       61.524291          32.584221
# LANDAREA_AVG                        49.751984          46.911722
# LIVINGAREA_AVG                      91.250418          69.261271
# NONLIVINGAREA_AVG                   29.710486          26.594852
# APARTMENTS_MODE                     97.719306          66.878325
# BASEMENTAREA_MODE                   66.395506          97.793837
# YEARS_BEGINEXPLUATATION_MODE         9.543401           5.786377
# ELEVATORS_MODE                      82.561928          55.615979
# ENTRANCES_MODE                      58.795138          63.132107
# FLOORSMAX_MODE                      61.257045          32.551992
# LANDAREA_MODE                       48.993207          46.513934
# LIVINGAREA_MODE                     89.613405          68.054891
# NONLIVINGAREA_MODE                  28.588418          26.266448
# APARTMENTS_MEDI                    100.000000          68.048038
# BASEMENTAREA_MEDI                   68.048038         100.000000
# YEARS_BEGINEXPLUATATION_MEDI         9.996547           7.678212
# ELEVATORS_MEDI                      83.744731          56.301943
# ENTRANCES_MEDI                      61.144063          65.154599
# FLOORSMAX_MEDI                      61.433681          32.433290
# LANDAREA_MEDI                       50.084763          47.190043
# LIVINGAREA_MEDI                     91.594734          69.140076
# NONLIVINGAREA_MEDI                  29.758449          26.733935
# TOTALAREA_MODE                      88.656825          66.939829
# DAYS_LAST_PHONE_CHANGE              -0.869024          -0.785158
#
#                               YEARS_BEGINEXPLUATATION_MEDI  ELEVATORS_MEDI  \
# TARGET                                           -0.999310       -3.386288
# AMT_INCOME_TOTAL                                  0.563881        4.415970
# AMT_CREDIT                                        0.576509        7.909438
# AMT_ANNUITY                                       1.293984        9.955854
# AMT_GOODS_PRICE                                   0.683868        8.226581
# REGION_POPULATION_RELATIVE                       -0.671069       27.439040
# DAYS_BIRTH                                        0.078726       -0.129852
# DAYS_EMPLOYED                                     0.840453       -0.981703
# DAYS_REGISTRATION                                 1.103856        0.172590
# DAYS_ID_PUBLISH                                  -0.319344       -1.044818
# EXT_SOURCE_1                                      0.207726        7.306587
# EXT_SOURCE_2                                      0.903506       11.346758
# EXT_SOURCE_3                                      0.016827        0.739755
# APARTMENTS_AVG                                    9.962012       83.512267
# BASEMENTAREA_AVG                                  7.749044       56.234692
# YEARS_BEGINEXPLUATATION_AVG                      99.382542        7.899495
# ELEVATORS_AVG                                     7.770286       99.609944
# ENTRANCES_AVG                                     4.056455       40.487332
# FLOORSMAX_AVG                                    12.548908       67.630558
# LANDAREA_AVG                                      6.847650       37.565084
# LIVINGAREA_AVG                                    8.889159       86.580480
# NONLIVINGAREA_AVG                                 1.154250       28.046845
# APARTMENTS_MODE                                   9.984973       80.885759
# BASEMENTAREA_MODE                                 7.226237       54.106084
# YEARS_BEGINEXPLUATATION_MODE                     96.353870        7.267140
# ELEVATORS_MODE                                    7.854952       98.282789
# ENTRANCES_MODE                                    3.587820       37.930077
# FLOORSMAX_MODE                                   12.464904       66.919164
# LANDAREA_MODE                                     6.455335       36.382506
# LIVINGAREA_MODE                                   8.473605       84.107310
# NONLIVINGAREA_MODE                                0.663786       26.534826
# APARTMENTS_MEDI                                   9.996547       83.744731
# BASEMENTAREA_MEDI                                 7.678212       56.301943
# YEARS_BEGINEXPLUATATION_MEDI                    100.000000        7.789616
# ELEVATORS_MEDI                                    7.789616      100.000000
# ENTRANCES_MEDI                                    3.986872       40.458912
# FLOORSMAX_MEDI                                   12.555662       67.578745
# LANDAREA_MEDI                                     6.861319       37.777600
# LIVINGAREA_MEDI                                   8.863838       86.834069
# NONLIVINGAREA_MEDI                                1.054719       28.002671
# TOTALAREA_MODE                                    9.905514       83.802761
# DAYS_LAST_PHONE_CHANGE                            0.279930       -1.007041
#
#                               ENTRANCES_MEDI  FLOORSMAX_MEDI  LANDAREA_MEDI  \
# TARGET                             -1.902476       -4.376792      -1.125583
# AMT_INCOME_TOTAL                    0.478697        5.968199      -0.189161
# AMT_CREDIT                          1.369207       10.277029       0.541497
# AMT_ANNUITY                         1.327609       12.917901       0.771076
# AMT_GOODS_PRICE                     1.758526       10.793597       1.255026
# REGION_POPULATION_RELATIVE          3.362828       31.831898      -5.254729
# DAYS_BIRTH                         -0.987594        0.179054       0.334058
# DAYS_EMPLOYED                       0.413798       -1.605082      -0.962651
# DAYS_REGISTRATION                  -6.259933        5.007612       0.296825
# DAYS_ID_PUBLISH                    -1.564717       -1.030744      -0.763417
# EXT_SOURCE_1                        2.148798        9.210779       0.499151
# EXT_SOURCE_2                        3.123609       13.461180       2.122683
# EXT_SOURCE_3                        1.218100        0.380820       1.072523
# APARTMENTS_AVG                     60.762933       61.658145      49.905231
# BASEMENTAREA_AVG                   64.700652       32.794921      46.999398
# YEARS_BEGINEXPLUATATION_AVG         4.133435       12.727333       7.406669
# ELEVATORS_AVG                      40.170759       67.777056      37.653066
# ENTRANCES_AVG                      99.688637        8.764193      51.114048
# FLOORSMAX_AVG                       8.456265       99.703414      21.917038
# LANDAREA_AVG                       50.685204       21.858997      99.160953
# LIVINGAREA_AVG                     61.507379       62.857064      50.350648
# NONLIVINGAREA_AVG                  16.289330       25.289292      16.348885
# APARTMENTS_MODE                    61.253593       58.500726      50.143963
# BASEMENTAREA_MODE                  65.257914       29.861345      47.509020
# YEARS_BEGINEXPLUATATION_MODE        3.699110       10.348969       5.140585
# ELEVATORS_MODE                     40.420219       65.561979      37.998888
# ENTRANCES_MODE                     98.067716        6.202666      50.123723
# FLOORSMAX_MODE                      8.781825       98.823749      22.187298
# LANDAREA_MODE                      51.072429       20.300829      98.083549
# LIVINGAREA_MODE                    62.223489       59.619274      50.552937
# NONLIVINGAREA_MODE                 17.066367       22.547815      16.374621
# APARTMENTS_MEDI                    61.144063       61.433681      50.084763
# BASEMENTAREA_MEDI                  65.154599       32.433290      47.190043
# YEARS_BEGINEXPLUATATION_MEDI        3.986872       12.555662       6.861319
# ELEVATORS_MEDI                     40.458912       67.578745      37.777600
# ENTRANCES_MEDI                    100.000000        8.290915      51.058658
# FLOORSMAX_MEDI                      8.290915      100.000000      21.901265
# LANDAREA_MEDI                      51.058658       21.901265     100.000000
# LIVINGAREA_MEDI                    61.896328       62.638207      50.389034
# NONLIVINGAREA_MEDI                 16.591554       24.724665      16.614160
# TOTALAREA_MODE                     58.861802       62.996542      49.255939
# DAYS_LAST_PHONE_CHANGE             -1.232358       -0.707768      -0.124124
#
#                               LIVINGAREA_MEDI  NONLIVINGAREA_MEDI  \
# TARGET                              -3.273928           -1.333672
# AMT_INCOME_TOTAL                     3.926142            7.084449
# AMT_CREDIT                           7.085962            3.582943
# AMT_ANNUITY                          8.813429            4.700866
# AMT_GOODS_PRICE                      7.602761            3.987395
# REGION_POPULATION_RELATIVE          20.934720            6.606027
# DAYS_BIRTH                           0.009954            0.632317
# DAYS_EMPLOYED                       -1.263053           -1.297540
# DAYS_REGISTRATION                    0.792554            4.993146
# DAYS_ID_PUBLISH                     -1.131529            0.248770
# EXT_SOURCE_1                         6.711063            3.037532
# EXT_SOURCE_2                         9.608190            4.263992
# EXT_SOURCE_3                         0.548626           -0.287608
# APARTMENTS_AVG                      91.232957           29.745436
# BASEMENTAREA_AVG                    68.931843           26.538177
# YEARS_BEGINEXPLUATATION_AVG          9.217544            0.845254
# ELEVATORS_AVG                       86.557949           28.014232
# ENTRANCES_AVG                       61.931192           16.699800
# FLOORSMAX_AVG                       62.715386           24.709877
# LANDAREA_AVG                        50.105008           16.479747
# LIVINGAREA_AVG                      99.559591           30.000178
# NONLIVINGAREA_AVG                   29.818676           99.044353
# APARTMENTS_MODE                     89.412210           28.983932
# BASEMENTAREA_MODE                   67.364841           26.135669
# YEARS_BEGINEXPLUATATION_MODE         7.497505           -1.216126
# ELEVATORS_MODE                      85.576656           27.525237
# ENTRANCES_MODE                      59.482949           15.992533
# FLOORSMAX_MODE                      62.432151           24.378500
# LANDAREA_MODE                       49.242162           16.132132
# LIVINGAREA_MODE                     97.474338           29.036838
# NONLIVINGAREA_MODE                  28.518926           97.583853
# APARTMENTS_MEDI                     91.594734           29.758449
# BASEMENTAREA_MEDI                   69.140076           26.733935
# YEARS_BEGINEXPLUATATION_MEDI         8.863838            1.054719
# ELEVATORS_MEDI                      86.834069           28.002671
# ENTRANCES_MEDI                      61.896328           16.591554
# FLOORSMAX_MEDI                      62.638207           24.724665
# LANDAREA_MEDI                       50.389034           16.614160
# LIVINGAREA_MEDI                    100.000000           29.822121
# NONLIVINGAREA_MEDI                  29.822121          100.000000
# TOTALAREA_MODE                      91.936332           36.162730
# DAYS_LAST_PHONE_CHANGE              -1.079498           -0.191377
#
#                               TOTALAREA_MODE  DAYS_LAST_PHONE_CHANGE
# TARGET                             -3.259555                5.521848
# AMT_INCOME_TOTAL                    4.198466               -1.858512
# AMT_CREDIT                          7.281803               -7.370111
# AMT_ANNUITY                         9.041456               -6.374689
# AMT_GOODS_PRICE                     7.752690               -7.631286
# REGION_POPULATION_RELATIVE         20.214519               -4.401321
# DAYS_BIRTH                          0.132948                8.293907
# DAYS_EMPLOYED                      -1.512620                2.303239
# DAYS_REGISTRATION                   1.949523                5.698257
# DAYS_ID_PUBLISH                    -1.115253                8.857590
# EXT_SOURCE_1                        6.622712              -13.260719
# EXT_SOURCE_2                        9.468728              -19.576417
# EXT_SOURCE_3                        0.623226               -7.525615
# APARTMENTS_AVG                     89.262693               -0.856399
# BASEMENTAREA_AVG                   67.239971               -0.741843
# YEARS_BEGINEXPLUATATION_AVG        10.031935                0.251481
# ELEVATORS_AVG                      84.462754               -0.983571
# ENTRANCES_AVG                      59.529022               -1.218715
# FLOORSMAX_AVG                      63.259471               -0.712982
# LANDAREA_AVG                       49.109104               -0.058131
# LIVINGAREA_AVG                     92.503871               -1.064541
# NONLIVINGAREA_AVG                  36.660437               -0.170659
# APARTMENTS_MODE                    86.362840               -0.759791
# BASEMENTAREA_MODE                  64.927397               -0.638883
# YEARS_BEGINEXPLUATATION_MODE        9.798727                0.175297
# ELEVATORS_MODE                     82.081298               -0.901204
# ENTRANCES_MODE                     56.122755               -1.125495
# FLOORSMAX_MODE                     62.537417               -0.674930
# LANDAREA_MODE                      47.838203               -0.111092
# LIVINGAREA_MODE                    89.924693               -0.960683
# NONLIVINGAREA_MODE                 34.695690               -0.139347
# APARTMENTS_MEDI                    88.656825               -0.869024
# BASEMENTAREA_MEDI                  66.939829               -0.785158
# YEARS_BEGINEXPLUATATION_MEDI        9.905514                0.279930
# ELEVATORS_MEDI                     83.802761               -1.007041
# ENTRANCES_MEDI                     58.861802               -1.232358
# FLOORSMAX_MEDI                     62.996542               -0.707768
# LANDAREA_MEDI                      49.255939               -0.124124
# LIVINGAREA_MEDI                    91.936332               -1.079498
# NONLIVINGAREA_MEDI                 36.162730               -0.191377
# TOTALAREA_MODE                    100.000000               -0.828350
# DAYS_LAST_PHONE_CHANGE             -0.828350              100.000000

# %%
families = []
for i, row in c.iterrows():
    r = row[row > 80]
    if len(r) > 1 and set(r.index) not in families:
        families.append(set(r.index))

for A in families:
    for B in families:
        if A == B:
            continue
        if A.issubset(B):
            families.remove(A)
families
# Out:
# [{'AMT_CREDIT', 'AMT_GOODS_PRICE'},
#  {'APARTMENTS_AVG',
#   'APARTMENTS_MEDI',
#   'APARTMENTS_MODE',
#   'ELEVATORS_AVG',
#   'ELEVATORS_MEDI',
#   'ELEVATORS_MODE',
#   'LIVINGAREA_AVG',
#   'LIVINGAREA_MEDI',
#   'LIVINGAREA_MODE',
#   'TOTALAREA_MODE'},
#  {'BASEMENTAREA_AVG', 'BASEMENTAREA_MEDI', 'BASEMENTAREA_MODE'},
#  {'YEARS_BEGINEXPLUATATION_AVG',
#   'YEARS_BEGINEXPLUATATION_MEDI',
#   'YEARS_BEGINEXPLUATATION_MODE'},
#  {'ENTRANCES_AVG', 'ENTRANCES_MEDI', 'ENTRANCES_MODE'},
#  {'FLOORSMAX_AVG', 'FLOORSMAX_MEDI', 'FLOORSMAX_MODE'},
#  {'LANDAREA_AVG', 'LANDAREA_MEDI', 'LANDAREA_MODE'},
#  {'NONLIVINGAREA_AVG', 'NONLIVINGAREA_MEDI', 'NONLIVINGAREA_MODE'}]

# %%
result = {
          "family":[],
          "head":[],
          "r2":[],
          "na":[],
          "rate":[]
         }

for i, family in enumerate(families):
    headers = list(family)
    
    result["family"].append("")
    result["head"].append("")
    result["r2"].append("")
    result["na"].append("")
    result["rate"].append("")
    
    for head in headers:
        d = df[["TARGET"] + [head]]
        na = d[head].isna().sum() / len(d) * 100
        d = d.dropna()
        y = d[["TARGET"]]
        x = d[[head]]
        
        model = LogisticRegression().fit(x, y.values.ravel())
        r2 = round(model.score(x,y),5)
        
        result["family"].append(i)
        result["head"].append(head)
        result["r2"].append(round(r2,5))
        result["na"].append(round(na,2))
        result["rate"].append(r2/na)
    
result = pd.DataFrame(result)
result
# Out:
# <ipython-input-51-e640230d1b21>:32: RuntimeWarning: divide by zero encountered in double_scalars
#   result["rate"].append(r2/na)
#    family                          head       r2     na       rate
# 0
# 1       0                    AMT_CREDIT  0.91927      0        inf
# 2       0               AMT_GOODS_PRICE  0.91927   0.09    10.1685
# 3
# 4       1                ELEVATORS_MODE    0.931   53.3  0.0174685
# 5       1               LIVINGAREA_MODE  0.93005  50.19  0.0185294
# 6       1               APARTMENTS_MODE  0.93041  50.75  0.0183333
# 7       1                TOTALAREA_MODE   0.9301  48.27  0.0192693
# 8       1                ELEVATORS_MEDI    0.931   53.3  0.0174685
# 9       1                LIVINGAREA_AVG  0.93005  50.19  0.0185294
# 10      1               LIVINGAREA_MEDI  0.93005  50.19  0.0185294
# 11      1                APARTMENTS_AVG  0.93041  50.75  0.0183333
# 12      1               APARTMENTS_MEDI  0.93041  50.75  0.0183333
# 13      1                 ELEVATORS_AVG    0.931   53.3  0.0174685
# 14
# 15      2              BASEMENTAREA_AVG  0.93112  58.52  0.0159122
# 16      2             BASEMENTAREA_MEDI  0.93112  58.52  0.0159122
# 17      2             BASEMENTAREA_MODE  0.93112  58.52  0.0159122
# 18
# 19      3  YEARS_BEGINEXPLUATATION_MODE  0.93005  48.78  0.0190658
# 20      3  YEARS_BEGINEXPLUATATION_MEDI  0.93005  48.78  0.0190658
# 21      3   YEARS_BEGINEXPLUATATION_AVG  0.93005  48.78  0.0190658
# 22
# 23      4                 ENTRANCES_AVG  0.93048  50.35  0.0184807
# 24      4                ENTRANCES_MODE  0.93048  50.35  0.0184807
# 25      4                ENTRANCES_MEDI  0.93048  50.35  0.0184807
# 26
# 27      5                FLOORSMAX_MODE  0.93035  49.76  0.0186964
# 28      5                FLOORSMAX_MEDI  0.93035  49.76  0.0186964
# 29      5                 FLOORSMAX_AVG  0.93035  49.76  0.0186964
# 30
# 31      6                  LANDAREA_AVG  0.93019  59.38  0.0156659
# 32      6                 LANDAREA_MEDI  0.93019  59.38  0.0156659
# 33      6                 LANDAREA_MODE  0.93019  59.38  0.0156659
# 34
# 35      7            NONLIVINGAREA_MEDI  0.93111  55.18  0.0168743
# 36      7             NONLIVINGAREA_AVG  0.93111  55.18  0.0168743
# 37      7            NONLIVINGAREA_MODE  0.93111  55.18  0.0168743

# %% [markdown]
# Es bilden sich 8 Cluster meist durch die Existenz von Durchschnitt, Median und Modus. In diesen Fällen wird stets der Durchschnitt als Repräsentant gewählt. Cluster#1 wird durch TOTALAREA_MODE am besten Repräsentiert, wie der Score anzeigt. Cluster#0 wird durch AMT_CREDIT Repräsentiert, da AMT_GOODS_PRICE fehlende Daten beinhaltet.

# %%
keep = ["AMT_CREDIT", "TOTALAREA_MODE", "BASEMENTAREA_AVG", "YEARS_BEGINEXPLUATATION_AVG", "ENTRANCES_AVG", "FLOORSMAX_AVG", "LANDAREA_AVG", "NONLIVINGAREA_AVG"]

# %%
remove = [head for head in list(result["head"]) if head not in keep + [""]]

# %%
remove
# Out:
# ['AMT_GOODS_PRICE',
#  'ELEVATORS_MODE',
#  'LIVINGAREA_MODE',
#  'APARTMENTS_MODE',
#  'ELEVATORS_MEDI',
#  'LIVINGAREA_AVG',
#  'LIVINGAREA_MEDI',
#  'APARTMENTS_AVG',
#  'APARTMENTS_MEDI',
#  'ELEVATORS_AVG',
#  'BASEMENTAREA_MEDI',
#  'BASEMENTAREA_MODE',
#  'YEARS_BEGINEXPLUATATION_MODE',
#  'YEARS_BEGINEXPLUATATION_MEDI',
#  'ENTRANCES_MODE',
#  'ENTRANCES_MEDI',
#  'FLOORSMAX_MODE',
#  'FLOORSMAX_MEDI',
#  'LANDAREA_MEDI',
#  'LANDAREA_MODE',
#  'NONLIVINGAREA_MEDI',
#  'NONLIVINGAREA_MODE']

# %%
df = df.drop(remove, axis=1)

# %%
df.head()
# Out:
#             TARGET  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# 100002           1          202500.0    406597.5      24700.5
# 100003           0          270000.0   1293502.5      35698.5
# 100004           0           67500.0    135000.0       6750.0
# 100006           0          135000.0    312682.5      29686.5
# 100007           0          121500.0    513000.0      21865.5
#
#             REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# SK_ID_CURR
# 100002                        0.018801       -9461           -637
# 100003                        0.003541      -16765          -1188
# 100004                        0.010032      -19046           -225
# 100006                        0.008019      -19005          -3039
# 100007                        0.028663      -19932          -3038
#
#             DAYS_REGISTRATION  DAYS_ID_PUBLISH  EXT_SOURCE_1  EXT_SOURCE_2  \
# SK_ID_CURR
# 100002                -3648.0            -2120      0.083037      0.262949
# 100003                -1186.0             -291      0.311267      0.622246
# 100004                -4260.0            -2531           NaN      0.555912
# 100006                -9833.0            -2437           NaN      0.650442
# 100007                -4311.0            -3458           NaN      0.322738
#
#             EXT_SOURCE_3  BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  \
# SK_ID_CURR
# 100002          0.139376            0.0369                       0.9722
# 100003               NaN            0.0529                       0.9851
# 100004          0.729567               NaN                          NaN
# 100006               NaN               NaN                          NaN
# 100007               NaN               NaN                          NaN
#
#             ENTRANCES_AVG  FLOORSMAX_AVG  LANDAREA_AVG  NONLIVINGAREA_AVG  \
# SK_ID_CURR
# 100002             0.0690         0.0833        0.0369             0.0000
# 100003             0.0345         0.2917        0.0130             0.0098
# 100004                NaN            NaN           NaN                NaN
# 100006                NaN            NaN           NaN                NaN
# 100007                NaN            NaN           NaN                NaN
#
#             TOTALAREA_MODE  DAYS_LAST_PHONE_CHANGE
# SK_ID_CURR
# 100002              0.0149                 -1134.0
# 100003              0.0714                  -828.0
# 100004                 NaN                  -815.0
# 100006                 NaN                  -617.0
# 100007                 NaN                 -1106.0

# %% [markdown]
# ### Betrachtung der Kausalität

# %%
result = {
    "head":[],
    "des":[]
}

for head in df.columns.values:
    if head in skip:
        continue
    result["head"].append(head)
    result["des"].append(des[des["Row"] == head]["Description"])
    
result = pd.DataFrame(result)
result
# Out:
#                            head  \
# 0              AMT_INCOME_TOTAL
# 1                    AMT_CREDIT
# 2                   AMT_ANNUITY
# 3    REGION_POPULATION_RELATIVE
# 4                    DAYS_BIRTH
# 5                 DAYS_EMPLOYED
# 6             DAYS_REGISTRATION
# 7               DAYS_ID_PUBLISH
# 8                  EXT_SOURCE_1
# 9                  EXT_SOURCE_2
# 10                 EXT_SOURCE_3
# 11             BASEMENTAREA_AVG
# 12  YEARS_BEGINEXPLUATATION_AVG
# 13                ENTRANCES_AVG
# 14                FLOORSMAX_AVG
# 15                 LANDAREA_AVG
# 16            NONLIVINGAREA_AVG
# 17               TOTALAREA_MODE
# 18       DAYS_LAST_PHONE_CHANGE
#
#                                                                                                                                                                                                                                                                                                                             des
# 0                                                                                                                                                                                                                                                                   10    Income of the client
# Name: Description, dtype: object
# 1                                                                                                                                                                                                                                                              11    Credit amount of the loan
# Name: Description, dtype: object
# 2                                                                                                                                                                                                                                                                           12    Loan annuity
# Name: Description, dtype: object
# 3                                                                                                                                                                     19    Normalized population of region where client lives (higher number means the client lives in more populated region)
# Name: Description, dtype: object
# 4                                                                                                                                                                                                                                        20    Client's age in days at the time of application
# Name: Description, dtype: object
# 5                                                                                                                                                                                                             21    How many days before the application the person started current employment
# Name: Description, dtype: object
# 6                                                                                                                                                                                                                22    How many days before the application did client change his registration
# Name: Description, dtype: object
# 7                                                                                                                                                                        23    How many days before the application did client change the identity document with which he applied for the loan
# Name: Description, dtype: object
# 8                                                                                                                                                                                                                                             44    Normalized score from external data source
# Name: Description, dtype: object
# 9                                                                                                                                                                                                                                             45    Normalized score from external data source
# Name: Description, dtype: object
# 10                                                                                                                                                                                                                                            46    Normalized score from external data source
# Name: Description, dtype: object
# 11  48    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 12  49    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 13  53    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 14  54    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 15  56    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 16  60    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 17  91    Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor
# Name: Description, dtype: object
# 18                                                                                                                                                                                                                              98    How many days before application did client change phone
# Name: Description, dtype: object

# %% [markdown]
# Die Kreditwürdigkeit hängt nicht Informationen wie Stockwerke, Eingänge oder Telefonänderungen ab.

# %%
remove = ["ENTRANCES_AVG", "FLOORSMAX_AVG", "DAYS_LAST_PHONE_CHANGE"]

# %%
df = df.drop(remove, axis=1)

# %%
df = df.drop(["TARGET"], axis=1)

# %% [markdown]
# ### Variablenerstellung

# %% [markdown]
# Kredithöhe / Einkommen

# %%
df["CREDIT/INCOME"] = df["AMT_CREDIT"] / df["AMT_INCOME_TOTAL"]

# %% [markdown]
# ### Ergebnis

# %%
df = df.add_prefix("A_")

# %%
df.head()
# Out:
#             A_AMT_INCOME_TOTAL  A_AMT_CREDIT  A_AMT_ANNUITY  \
# SK_ID_CURR
# 100002                202500.0      406597.5        24700.5
# 100003                270000.0     1293502.5        35698.5
# 100004                 67500.0      135000.0         6750.0
# 100006                135000.0      312682.5        29686.5
# 100007                121500.0      513000.0        21865.5
#
#             A_REGION_POPULATION_RELATIVE  A_DAYS_BIRTH  A_DAYS_EMPLOYED  \
# SK_ID_CURR
# 100002                          0.018801         -9461             -637
# 100003                          0.003541        -16765            -1188
# 100004                          0.010032        -19046             -225
# 100006                          0.008019        -19005            -3039
# 100007                          0.028663        -19932            -3038
#
#             A_DAYS_REGISTRATION  A_DAYS_ID_PUBLISH  A_EXT_SOURCE_1  \
# SK_ID_CURR
# 100002                  -3648.0              -2120        0.083037
# 100003                  -1186.0               -291        0.311267
# 100004                  -4260.0              -2531             NaN
# 100006                  -9833.0              -2437             NaN
# 100007                  -4311.0              -3458             NaN
#
#             A_EXT_SOURCE_2  A_EXT_SOURCE_3  A_BASEMENTAREA_AVG  \
# SK_ID_CURR
# 100002            0.262949        0.139376              0.0369
# 100003            0.622246             NaN              0.0529
# 100004            0.555912        0.729567                 NaN
# 100006            0.650442             NaN                 NaN
# 100007            0.322738             NaN                 NaN
#
#             A_YEARS_BEGINEXPLUATATION_AVG  A_LANDAREA_AVG  \
# SK_ID_CURR
# 100002                             0.9722          0.0369
# 100003                             0.9851          0.0130
# 100004                                NaN             NaN
# 100006                                NaN             NaN
# 100007                                NaN             NaN
#
#             A_NONLIVINGAREA_AVG  A_TOTALAREA_MODE  A_CREDIT/INCOME
# SK_ID_CURR
# 100002                   0.0000            0.0149         2.007889
# 100003                   0.0098            0.0714         4.790750
# 100004                      NaN               NaN         2.000000
# 100006                      NaN               NaN         2.316167
# 100007                      NaN               NaN         4.222222

# %% [markdown]
# ### Speichern der Ergebnisse

# %%
df = pd.merge(cats, df, left_index=True, right_index=True)

# %%
df.to_csv(DATASET_DIR / "2. Datenaufbereitung" / "app_train.csv")
