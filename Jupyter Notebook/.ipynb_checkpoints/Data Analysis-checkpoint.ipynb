# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

# %%
DATASET_DIR = Path(r"C:\Users\rober\Documents\Masterarbeit\Kaggle Home Credit Datensatz")

# %%
app_test = pd.read_csv(DATASET_DIR / "application_test.csv")
app_train = pd.read_csv(DATASET_DIR / "application_train.csv")
bureau = pd.read_csv(DATASET_DIR / "bureau.csv")
bureau_balance = pd.read_csv(DATASET_DIR / "bureau_balance.csv")
credit_card_balance = pd.read_csv(DATASET_DIR / "credit_card_balance.csv")
installments_payments = pd.read_csv(DATASET_DIR / "installments_payments.csv")
pcb = pd.read_csv(DATASET_DIR / "POS_CASH_balance.csv")
previous_application = pd.read_csv(DATASET_DIR / "previous_application.csv")

# %%
description = pd.read_csv(DATASET_DIR / "HomeCredit_columns_description.csv", encoding="latin", index_col=0)

# %%
# Names of Table Heads
description["Table"].unique()

# %%
# Print Description of CSVs
description.loc[description['Table']=="application_{train|test}.csv"]

# %%
description.loc[description['Table']=="bureau.csv"]
# Out:
#           Table                     Row  \
# 125  bureau.csv              SK_ID_CURR
# 126  bureau.csv            SK_BUREAU_ID
# 127  bureau.csv           CREDIT_ACTIVE
# 128  bureau.csv         CREDIT_CURRENCY
# 129  bureau.csv             DAYS_CREDIT
# 130  bureau.csv      CREDIT_DAY_OVERDUE
# 131  bureau.csv     DAYS_CREDIT_ENDDATE
# 132  bureau.csv       DAYS_ENDDATE_FACT
# 133  bureau.csv  AMT_CREDIT_MAX_OVERDUE
# 134  bureau.csv      CNT_CREDIT_PROLONG
# 135  bureau.csv          AMT_CREDIT_SUM
# 136  bureau.csv     AMT_CREDIT_SUM_DEBT
# 137  bureau.csv    AMT_CREDIT_SUM_LIMIT
# 138  bureau.csv  AMT_CREDIT_SUM_OVERDUE
# 139  bureau.csv             CREDIT_TYPE
# 140  bureau.csv      DAYS_CREDIT_UPDATE
# 141  bureau.csv             AMT_ANNUITY
#
#                                                                                                              Description  \
# ...

# %%
description.loc[description['Table']=="bureau_balance.csv"]

# %%
description.loc[description['Table']=="POS_CASH_balance.csv"]

# %%
description.loc[description['Table']=="credit_card_balance.csv"]

# %%
description.loc[description['Table']=="previous_application.csv"]

# %%
description.loc[description['Table']=="installments_payments.csv"]

# %%
payback = app_train[app_train["TARGET"] == 0]
default = app_train[app_train["TARGET"] == 1]

# %%
# Function to draw a Piechart
def draw_piechart(sizes,labels):
    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, normalize=False)
    ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

    plt.show()

# %%
# Relation Payback vs Default
n_payback = len(payback)
n_default = len(default)
n = len(app_train["TARGET"])

labels = 'payback', 'default'
sizes = [n_payback/n, n_default/n]

draw_piechart(sizes, labels)

# %%
# Payback Male vs. Female
payback_female, payback_male, other= payback["CODE_GENDER"].value_counts()
n = len(payback["CODE_GENDER"])

labels = 'Female', 'Male'
sizes = [payback_female/n, payback_male/n]

draw_piechart(sizes, labels)

# %%
# Default Male vs. Female
default_female, default_male = default["CODE_GENDER"].value_counts()
n = len(default["CODE_GENDER"])

labels = 'Female', 'Male'
sizes = [default_female/n, default_male/n]

draw_piechart(sizes, labels)

# %%
bureau.head()
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
# 1      215354       5714463        Active      currency 1         -208
# 2      215354       5714464        Active      currency 1         -203
# 3      215354       5714465        Active      currency 1         -203
# 4      215354       5714466        Active      currency 1         -629
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0               -153.0             -153.0
# 1                   0               1075.0                NaN
# 2                   0                528.0                NaN
# 3                   0                  NaN                NaN
# 4                   0               1197.0                NaN
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                     NaN                   0         91323.0
# ...
