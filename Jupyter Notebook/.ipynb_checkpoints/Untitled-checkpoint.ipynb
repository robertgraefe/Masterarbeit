# %%
from pathlib import Path
from scipy import stats

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

from sklearn.linear_model import LogisticRegression

from IPython.display import display, Markdown

import json

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
MODEL_APPLICATION = "1.1. Esembler_Logistic_application.json"
MODEL_BUREAU = "1.2. Esembler_Logistic_bureau.json"
MODEL_PA_POS = "1.3. Esembler_Logistic_pa_pos.json"
MODEL_PA_IP = "1.4. Esembler_Logistic_pa_ip.json"
MODEL_PA_CC = "1.5. Esembler_Logistic_pa_cc.json"

# %%
with open(DATASET_DIR / "Models" / MODEL_APPLICATION, 'r') as file:
    application_log = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_BUREAU, 'r') as file:
    bureau_log = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_POS, 'r') as file:
    pa_pos_log = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_IP, 'r') as file:
    pa_ip_log = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_CC, 'r') as file:
    pa_cc_log = json.load(file)

LOG_LIST = [application_log, bureau_log, pa_pos_log, pa_ip_log, pa_cc_log]

# %%
MODEL_APPLICATION = "2.1. Esembler_DecisionTree_Application.json"
MODEL_BUREAU = "2.2. Esembler_DecisionTree_bureau.json"
MODEL_PA_POS = "2.3. Esembler_DecisionTree_pa_pos.json"
MODEL_PA_IP = "2.4. Esembler_DecisionTree_pa_ip.json"
MODEL_PA_CC = "2.5. Esembler_DecisionTree_pa_cc.json"

# %%
with open(DATASET_DIR / "Models" / MODEL_APPLICATION, 'r') as file:
    application_dt = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_BUREAU, 'r') as file:
    bureau_dt = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_POS, 'r') as file:
    pa_pos_dt = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_IP, 'r') as file:
    pa_ip_dt = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_CC, 'r') as file:
    pa_cc_dt = json.load(file)

DT_LIST = [application_dt, bureau_dt, pa_pos_dt, pa_ip_dt, pa_cc_dt]

# %%
MODEL_APPLICATION = "3.1. Esembler_RandomForest_Application.json"
MODEL_BUREAU = "3.2. Esembler_RandomForest_bureau.json"
MODEL_PA_POS = "3.3. Esembler_RandomForest_pa_pos.json"
MODEL_PA_IP = "3.4. Esembler_RandomForest_pa_ip.json"
MODEL_PA_CC = "3.5. Esembler_RandomForest_pa_cc.json"

# %%
with open(DATASET_DIR / "Models" / MODEL_APPLICATION, 'r') as file:
    application_rf = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_BUREAU, 'r') as file:
    bureau_rf = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_POS, 'r') as file:
    pa_pos_rf = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_IP, 'r') as file:
    pa_ip_rf = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_CC, 'r') as file:
    pa_cc_rf = json.load(file)

RF_LIST = [application_rf, bureau_rf, pa_pos_rf, pa_ip_rf, pa_cc_rf]

# %% [markdown]
# # Anzahl Parameter

# %%
df = pd.DataFrame({"Datensatz":["Application", "Bureau", "PA_POS", "PA_IP", "PA_CC"]})
df = df.set_index("Datensatz")
df["# Parameter"] = [len(x["keep"]) + len(x["drop"]) for x in LOG_LIST]

df["# Parameter log. R."] = [len(x["keep"]) for x in LOG_LIST]
df["AUC log. R."] = [round(x["auc"][-1],4) for x in LOG_LIST]
df["# Parameter DT"] = [len(x["keep"]) for x in DT_LIST]
df["AUC DT"] = [round(x["auc"][-1],4) for x in DT_LIST]
df["# Parameter RF"] = [len(x["keep"]) for x in RF_LIST]
df["AUC RF"] = [round(x["auc"][-1],4) for x in RF_LIST]

df.loc["SUM"] = [df["# Parameter"].sum(), df["# Parameter log. R."].sum(), "-", df["# Parameter DT"].sum(), "-", df["# Parameter RF"].sum(), "-"]
df
# Out:
# SUM # Parameter: 137
# SUM # Parameter log. R.: 101
# SUM # Parameter DT: 60
# SUM # Parameter RF: 82
#              # Parameter  # Parameter log. R. AUC log. R.  # Parameter DT  \
# Datensatz
# Application           35                   29      0.7868              12
# Bureau                 9                    6      0.5926               6
# PA_POS                21                   20      0.6354              12
# PA_IP                 37                   24      0.6294              16
# PA_CC                 35                   22      0.6224              14
# SUM                  137                  101           -              60
#
#              AUC DT  # Parameter RF  AUC RF
# Datensatz
# Application  0.8007              10  0.8131
# Bureau       0.5996               7  0.6125
# PA_POS       0.6168              17  0.6361
# PA_IP        0.6075              27  0.6362
# PA_CC        0.6346              21  0.6509
# SUM               -              82       -

# %% [markdown]
# # Application

# %%
log = application_log["keep"]
dt = application_dt["keep"]
rf = application_rf["keep"]

# %%
df = pd.DataFrame()
df = pd.concat([df,pd.DataFrame({"logistische Regression":log})],axis=1)
df = pd.concat([df,pd.DataFrame({"Entscheidungsbaum":dt})],axis=1)
df = pd.concat([df,pd.DataFrame({"Random Forest":rf})],axis=1)
df[0:10]
# Out:
#   logistische Regression             Entscheidungsbaum  \
# 0         A_EXT_SOURCE_1                A_EXT_SOURCE_3
# 1           A_DAYS_BIRTH   A_AMT_REQ_CREDIT_BUREAU_DAY
# 2         A_EXT_SOURCE_3                  A_DAYS_BIRTH
# 3         A_LANDAREA_AVG                A_EXT_SOURCE_1
# 4         A_EXT_SOURCE_2                A_EXT_SOURCE_2
# 5       A_TOTALAREA_MODE   A_AMT_REQ_CREDIT_BUREAU_QRT
# 6           A_AMT_CREDIT  A_AMT_REQ_CREDIT_BUREAU_WEEK
# 7          A_AMT_ANNUITY            A_BASEMENTAREA_AVG
# 8        A_CREDIT/INCOME                A_LANDAREA_AVG
# 9          A_CODE_GENDER                 A_AMT_ANNUITY
#
#                    Random Forest
# 0                 A_EXT_SOURCE_3
# 1                 A_EXT_SOURCE_1
# 2                 A_EXT_SOURCE_2
# 3    A_AMT_REQ_CREDIT_BUREAU_DAY
# 4   A_AMT_REQ_CREDIT_BUREAU_HOUR
# 5  A_YEARS_BEGINEXPLUATATION_AVG
# 6                A_DAYS_EMPLOYED
# 7                   A_DAYS_BIRTH
# 8             A_BASEMENTAREA_AVG
# ...

# %%
df
# Out:
#            logistische Regression             Entscheidungsbaum  \
# 0                  A_EXT_SOURCE_1                A_EXT_SOURCE_3
# 1                    A_DAYS_BIRTH   A_AMT_REQ_CREDIT_BUREAU_DAY
# 2                  A_EXT_SOURCE_3                  A_DAYS_BIRTH
# 3                  A_LANDAREA_AVG                A_EXT_SOURCE_1
# 4                  A_EXT_SOURCE_2                A_EXT_SOURCE_2
# 5                A_TOTALAREA_MODE   A_AMT_REQ_CREDIT_BUREAU_QRT
# 6                    A_AMT_CREDIT  A_AMT_REQ_CREDIT_BUREAU_WEEK
# 7                   A_AMT_ANNUITY            A_BASEMENTAREA_AVG
# 8                 A_CREDIT/INCOME                A_LANDAREA_AVG
# 9                   A_CODE_GENDER                 A_AMT_ANNUITY
# 10                A_DAYS_EMPLOYED            A_AMT_INCOME_TOTAL
# 11              A_FLAG_DOCUMENT_3           A_ORGANIZATION_TYPE
# 12   A_REGION_POPULATION_RELATIVE                           NaN
# 13             A_BASEMENTAREA_AVG                           NaN
# ...

# %%
a = np.intersect1d(log, dt)
a = np.intersect1d(a, rf)
a
# Out:
# array(['A_AMT_REQ_CREDIT_BUREAU_DAY', 'A_BASEMENTAREA_AVG',
#        'A_DAYS_BIRTH', 'A_EXT_SOURCE_1', 'A_EXT_SOURCE_2',
#        'A_EXT_SOURCE_3', 'A_LANDAREA_AVG'], dtype='<U29')

# %% [markdown]
# # Bureau

# %%
log = bureau_log["keep"]
dt = bureau_dt["keep"]
rf = bureau_rf["keep"]

# %%
df = pd.DataFrame()
df = pd.concat([df,pd.DataFrame({"logistische Regression":log})],axis=1)
df = pd.concat([df,pd.DataFrame({"Entscheidungsbaum":dt})],axis=1)
df = pd.concat([df,pd.DataFrame({"Random Forest":rf})],axis=1)
df[0:10]
# Out:
#      logistische Regression      Entscheidungsbaum             Random Forest
# 0                  B_Closed               B_Closed                  B_Active
# 1                  B_Active               B_Active                  B_Closed
# 2      B_CREDIT_DAY_OVERDUE       B_AMT_CREDIT_SUM          B_AMT_CREDIT_SUM
# 3  B_AMT_CREDIT_SUM_OVERDUE  B_DAYS_CREDIT_ENDDATE     B_AMT_CREDIT_SUM_DEBT
# 4     B_DAYS_CREDIT_ENDDATE  B_AMT_CREDIT_SUM_DEBT     B_DAYS_CREDIT_ENDDATE
# 5             B_AMT_ANNUITY             CNT_BURAEU  B_AMT_CREDIT_SUM_OVERDUE
# 6                       NaN                    NaN             B_AMT_ANNUITY

# %%
df
# Out:
#      logistische Regression      Entscheidungsbaum             Random Forest
# 0                  B_Closed               B_Closed                  B_Active
# 1                  B_Active               B_Active                  B_Closed
# 2      B_CREDIT_DAY_OVERDUE       B_AMT_CREDIT_SUM          B_AMT_CREDIT_SUM
# 3  B_AMT_CREDIT_SUM_OVERDUE  B_DAYS_CREDIT_ENDDATE     B_AMT_CREDIT_SUM_DEBT
# 4     B_DAYS_CREDIT_ENDDATE  B_AMT_CREDIT_SUM_DEBT     B_DAYS_CREDIT_ENDDATE
# 5             B_AMT_ANNUITY             CNT_BURAEU  B_AMT_CREDIT_SUM_OVERDUE
# 6                       NaN                    NaN             B_AMT_ANNUITY

# %%
a = np.intersect1d(log, dt)
a = np.intersect1d(a, rf)
a
# Out:
# array(['B_Active', 'B_Closed', 'B_DAYS_CREDIT_ENDDATE'], dtype='<U24')

# %% [markdown]
# # PA_POS

# %%
log = pa_pos_log["keep"]
dt = pa_pos_dt["keep"]
rf = pa_pos_rf["keep"]

# %%
df = pd.DataFrame()
df = pd.concat([df,pd.DataFrame({"logistische Regression":log})],axis=1)
df = pd.concat([df,pd.DataFrame({"Entscheidungsbaum":dt})],axis=1)
df = pd.concat([df,pd.DataFrame({"Random Forest":rf})],axis=1)
df[0:10]
# Out:
#                                   logistische Regression  \
# 0                                          PA_AMT_CREDIT
# 1                                         PA_AMT_ANNUITY
# 2                                     PA_AMT_APPLICATION
# 3                                     PA_AMT_GOODS_PRICE
# 4                           PA_CNT_NAME_YIELD_GROUP_high
# 5                    PA_CNT_NAME_CONTRACT_STATUS_Refused
# 6                                         PA_CNT_CREDITS
# 7                               PA_POS_CNT_PAYMENTS_LEFT
# 8                                    PA_AMT_DOWN_PAYMENT
# 9  PA_CNT_PRODUCT_COMBINATION_POS industry with interest
#
#                      Entscheidungsbaum                        Random Forest
# 0  PA_CNT_NAME_CONTRACT_STATUS_Refused  PA_CNT_NAME_CONTRACT_STATUS_Refused
# 1                       PA_AMT_ANNUITY                       PA_AMT_ANNUITY
# 2                       PA_POS_CNT_DPD                   PA_AMT_GOODS_PRICE
# ...

# %%
df
# Out:
#                                    logistische Regression  \
# 0                                           PA_AMT_CREDIT
# 1                                          PA_AMT_ANNUITY
# 2                                      PA_AMT_APPLICATION
# 3                                      PA_AMT_GOODS_PRICE
# 4                            PA_CNT_NAME_YIELD_GROUP_high
# 5                     PA_CNT_NAME_CONTRACT_STATUS_Refused
# 6                                          PA_CNT_CREDITS
# 7                                PA_POS_CNT_PAYMENTS_LEFT
# 8                                     PA_AMT_DOWN_PAYMENT
# 9   PA_CNT_PRODUCT_COMBINATION_POS industry with interest
# 10              PA_CNT_NAME_CONTRACT_TYPE_Revolving loans
# 11                            PA_CNT_NAME_CLIENT_TYPE_New
# 12                                   PA_RATE_DOWN_PAYMENT
# 13            PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low
# 14                                         PA_POS_CNT_DPD
# ...

# %%
a = np.intersect1d(log, dt)
a = np.intersect1d(a, rf)
a
# Out:
# array(['PA_AMT_ANNUITY', 'PA_AMT_CREDIT', 'PA_AMT_DOWN_PAYMENT',
#        'PA_CNT_CREDITS', 'PA_CNT_NAME_CLIENT_TYPE_New',
#        'PA_CNT_NAME_CONTRACT_STATUS_Refused',
#        'PA_CNT_NAME_CONTRACT_TYPE_Revolving loans',
#        'PA_CNT_NAME_PRODUCT_TYPE_walk-in', 'PA_CNT_NAME_YIELD_GROUP_high',
#        'PA_CNT_NAME_YIELD_GROUP_low_normal', 'PA_POS_CNT_DPD',
#        'PA_POS_CNT_PAYMENTS_LEFT'], dtype='<U53')

# %% [markdown]
# # PA_IP

# %%
log = pa_ip_log["keep"]
dt = pa_ip_dt["keep"]
rf = pa_ip_rf["keep"]

# %%
df = pd.DataFrame()
df = pd.concat([df,pd.DataFrame({"logistische Regression":log})],axis=1)
df = pd.concat([df,pd.DataFrame({"Entscheidungsbaum":dt})],axis=1)
df = pd.concat([df,pd.DataFrame({"Random Forest":rf})],axis=1)
df[0:10]
# Out:
#                                   logistische Regression  \
# 0                                         PA_AMT_ANNUITY
# 1                                          PA_AMT_CREDIT
# 2                                         PA_CNT_CREDITS
# 3                    PA_CNT_NAME_CONTRACT_STATUS_Refused
# 4                     PA_CNT_NAME_YIELD_GROUP_low_normal
# 5              PA_CNT_NAME_CONTRACT_TYPE_Revolving loans
# 6                                     PA_IP_DAYS_DIFF_60
# 7                            PA_CNT_NAME_PORTFOLIO_Cards
# 8                            PA_CNT_NAME_CLIENT_TYPE_New
# 9  PA_CNT_PRODUCT_COMBINATION_POS industry with interest
#
#                      Entscheidungsbaum                        Random Forest
# 0     PA_CNT_NAME_PRODUCT_TYPE_walk-in     PA_CNT_NAME_PRODUCT_TYPE_walk-in
# 1                   PA_IP_DAYS_DIFF_30                   PA_IP_DAYS_DIFF_60
# 2  PA_CNT_NAME_CONTRACT_STATUS_Refused  PA_CNT_NAME_CONTRACT_STATUS_Refused
# ...

# %%
df
# Out:
#                                    logistische Regression  \
# 0                                          PA_AMT_ANNUITY
# 1                                           PA_AMT_CREDIT
# 2                                          PA_CNT_CREDITS
# 3                     PA_CNT_NAME_CONTRACT_STATUS_Refused
# 4                      PA_CNT_NAME_YIELD_GROUP_low_normal
# 5               PA_CNT_NAME_CONTRACT_TYPE_Revolving loans
# 6                                      PA_IP_DAYS_DIFF_60
# 7                             PA_CNT_NAME_PORTFOLIO_Cards
# 8                             PA_CNT_NAME_CLIENT_TYPE_New
# 9   PA_CNT_PRODUCT_COMBINATION_POS industry with interest
# 10                       PA_CNT_NAME_PRODUCT_TYPE_walk-in
# 11                      PA_CNT_NAME_CLIENT_TYPE_Refreshed
# 12                                     PA_AMT_APPLICATION
# 13                                    PA_AMT_DOWN_PAYMENT
# 14            PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low
# ...

# %%
a = np.intersect1d(log, dt)
a = np.intersect1d(a, rf)
a
# Out:
# array(['PA_AMT_ANNUITY', 'PA_AMT_APPLICATION',
#        'PA_CNT_NAME_CONTRACT_STATUS_Refused',
#        'PA_CNT_NAME_PRODUCT_TYPE_walk-in',
#        'PA_CNT_NAME_YIELD_GROUP_low_normal', 'PA_IP_DAYS_DIFF_150',
#        'PA_IP_DAYS_DIFF_180', 'PA_IP_DAYS_DIFF_30', 'PA_IP_DAYS_DIFF_60',
#        'PA_IP_PAYMENT_60', 'PA_RATE_DOWN_PAYMENT'], dtype='<U53')

# %% [markdown]
# # PA_CC

# %%
log = pa_cc_log["keep"]
dt = pa_cc_dt["keep"]
rf = pa_cc_rf["keep"]

# %%
df = pd.DataFrame()
df = pd.concat([df,pd.DataFrame({"logistische Regression":log})],axis=1)
df = pd.concat([df,pd.DataFrame({"Entscheidungsbaum":dt})],axis=1)
df = pd.concat([df,pd.DataFrame({"Random Forest":rf})],axis=1)
df[0:10]
# Out:
#                 logistische Regression  \
# 0                       PA_AMT_ANNUITY
# 1                        PA_AMT_CREDIT
# 2                         PA_CC_DPD_30
# 3                    PA_CC_BALANCE_180
# 4  PA_CNT_NAME_CONTRACT_STATUS_Refused
# 5   PA_CNT_NAME_YIELD_GROUP_low_normal
# 6          PA_CNT_NAME_CLIENT_TYPE_New
# 7                     PA_CC_BALANCE_60
# 8     PA_CNT_NAME_PRODUCT_TYPE_walk-in
# 9          PA_CNT_NAME_PORTFOLIO_Cards
#
#                              Entscheidungsbaum  \
# 0                             PA_CC_BALANCE_60
# 1             PA_CNT_NAME_PRODUCT_TYPE_walk-in
# 2                             PA_CC_BALANCE_90
# 3          PA_CNT_NAME_CONTRACT_STATUS_Refused
# 4                            PA_CC_PAYMENT_180
# 5  PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low
# 6                            PA_CC_BALANCE_150
# 7                                 PA_CC_DPD_30
# 8                                 PA_CC_DPD_90
# 9                             PA_CC_PAYMENT_30
#
# ...

# %%
df
# Out:
#                                    logistische Regression  \
# 0                                          PA_AMT_ANNUITY
# 1                                           PA_AMT_CREDIT
# 2                                            PA_CC_DPD_30
# 3                                       PA_CC_BALANCE_180
# 4                     PA_CNT_NAME_CONTRACT_STATUS_Refused
# 5                      PA_CNT_NAME_YIELD_GROUP_low_normal
# 6                             PA_CNT_NAME_CLIENT_TYPE_New
# 7                                        PA_CC_BALANCE_60
# 8                        PA_CNT_NAME_PRODUCT_TYPE_walk-in
# 9                             PA_CNT_NAME_PORTFOLIO_Cards
# 10              PA_CNT_NAME_CONTRACT_TYPE_Revolving loans
# 11  PA_CNT_PRODUCT_COMBINATION_POS industry with interest
# 12                                           PA_CC_DPD_60
# 13                                       PA_CC_PAYMENT_60
# 14                      PA_CNT_NAME_CLIENT_TYPE_Refreshed
# ...

# %%
a = np.intersect1d(log, dt)
a = np.intersect1d(a, rf)
a
# Out:
# array(['PA_CC_BALANCE_60', 'PA_CC_DPD_180',
#        'PA_CNT_CODE_REJECT_REASON_HC',
#        'PA_CNT_NAME_CONTRACT_STATUS_Refused',
#        'PA_CNT_NAME_PRODUCT_TYPE_walk-in'], dtype='<U53')
