# %%
import pandas as pd
import numpy as np
import lightgbm as lgb

from pathlib import Path
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
DATASET_DIR = Path(r"C:\Users\rober\Google Drive\Universität\Masterarbeit\Datensatz\2. Datasets Kaggle")

# %%
# read in the datasets
app_test = pd.read_csv(DATASET_DIR / "application_test.csv", index_col = "SK_ID_CURR")
app_train = pd.read_csv(DATASET_DIR / "application_train.csv", index_col = "SK_ID_CURR")

# %%
app_train.head()
# Out:
#             TARGET  NAME_CONTRACT_TYPE  CODE_GENDER  FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1                   0            0             0
# 100003           0                   0            1             0
# 100004           0                   1            0             1
# 100006           0                   0            1             0
# 100007           0                   0            0             0
#
#             FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                    0             0          202500.0    406597.5
# 100003                    1             0          270000.0   1293502.5
# 100004                    0             0           67500.0    135000.0
# 100006                    0             0          135000.0    312682.5
# 100007                    0             0          121500.0    513000.0
#
#             AMT_ANNUITY  AMT_GOODS_PRICE  NAME_TYPE_SUITE  NAME_INCOME_TYPE  \
# SK_ID_CURR
# ...

# %%
# function that factorizes categorical features
def factorize_cat(df):
    heads = df.columns.values
    for head in heads:
        if df[head].dtype == "object":
            df[head], uniques = pd.factorize(df[head])
    return df

# %%
app_test = factorize_cat(app_test)
app_train = factorize_cat(app_train)

# %%
y = app_train["TARGET"]
x = app_train.drop(["TARGET"], axis=1)

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=18)

# %%
params = {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc',
          'learning_rate': 0.01, 'num_leaves': 48,  'verbose': 0,'num_iteration': 5000,
          'colsample_bytree': .8, 'subsample': .9, 'max_depth': 7, 'reg_alpha': .1, 'reg_lambda': .1,
          'min_split_gain': .01, 'min_child_weight': 1}

# %%
lgb_train = lgb.Dataset(data=x_train, label=y_train)
lgb_eval = lgb.Dataset(data=x_val, label=y_val)

# %%
model = lgb.train(params, lgb_train, valid_sets=lgb_eval, early_stopping_rounds=150, verbose_eval=200)
# Out:
# a:\workspace\python\masterarbeit\venv\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.189505 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# Training until validation scores don't improve for 150 rounds
# [200]	valid_0's auc: 0.744853
# [400]	valid_0's auc: 0.752454
# [600]	valid_0's auc: 0.755987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
lgb.plot_importance(model, figsize=(12, 25), max_num_features=100)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>
