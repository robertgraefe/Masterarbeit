# %%
from pathlib import Path
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score

from sklearn.model_selection import KFold
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import auc

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

from IPython.display import clear_output

import json

import warnings

from sklearn import preprocessing

# %%
# Entscheidungsbaum
TREE_PARAMS = {
    "random_state" : 0,
    "max_depth": 7,
}

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
app_train = pd.read_csv(DATASET_DIR / "4. FillNA" / "application.csv")
bureau = pd.read_csv(DATASET_DIR / "4. FillNA" / "bureau.csv")
pa_pos = pd.read_csv(DATASET_DIR / "4. FillNA" / "pa_pos.csv")
pa_ip = pd.read_csv(DATASET_DIR / "4. FillNA" / "pa_ip.csv")
pa_cc = pd.read_csv(DATASET_DIR / "4. FillNA" / "pa_cc.csv")

# %%
app_train = app_train.set_index("SK_ID_CURR")
bureau = bureau.set_index("SK_ID_CURR")
pa_pos = pa_pos.set_index("SK_ID_CURR")
pa_ip = pa_ip.set_index("SK_ID_CURR")
pa_cc = pa_cc.set_index("SK_ID_CURR")

# %%
MODEL_APPLICATION = "2.1. Esembler_DecisionTree_Application.json"
MODEL_BUREAU = "2.2. Esembler_DecisionTree_bureau.json"
MODEL_PA_POS = "2.3. Esembler_DecisionTree_pa_pos.json"
MODEL_PA_IP = "2.4. Esembler_DecisionTree_pa_ip.json"
MODEL_PA_CC = "2.5. Esembler_DecisionTree_pa_cc.json"

# %%
with open(DATASET_DIR / "Models" / MODEL_APPLICATION, 'r') as file:
    model_application_data = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_BUREAU, 'r') as file:
    model_bureau_data = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_POS, 'r') as file:
    model_pa_pos_data = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_IP, 'r') as file:
    model_pa_ip_data = json.load(file)
    
with open(DATASET_DIR / "Models" / MODEL_PA_CC, 'r') as file:
    model_pa_cc_data = json.load(file)

# %%
model_application = DecisionTreeClassifier(**TREE_PARAMS)
model_bureau = DecisionTreeClassifier(**TREE_PARAMS)
model_pa_pos = DecisionTreeClassifier(**TREE_PARAMS)
model_pa_ip = DecisionTreeClassifier(**TREE_PARAMS)
model_pa_cc = DecisionTreeClassifier(**TREE_PARAMS)

# %%
df = app_train[["TARGET"]]
df.head()
# Out:
#             TARGET
# SK_ID_CURR
# 100002         1.0
# 100003         0.0
# 100004         0.0
# 100006         0.0
# 100007         0.0

# %%
# application prediction

# %%
x = app_train[model_application_data["keep"]]
x.head()
# Out:
#             A_EXT_SOURCE_3  A_AMT_REQ_CREDIT_BUREAU_DAY  A_DAYS_BIRTH  \
# SK_ID_CURR
# 100002            0.139376                     0.000000       -9461.0
# 100003            0.361809                     0.000000      -16765.0
# 100004            0.729567                     0.000000      -19046.0
# 100006            0.565391                     0.005328      -19005.0
# 100007            0.565607                     0.000000      -19932.0
#
#             A_EXT_SOURCE_1  A_EXT_SOURCE_2  A_LANDAREA_AVG  \
# SK_ID_CURR
# 100002            0.083037        0.262949        0.036900
# 100003            0.311267        0.622246        0.013000
# 100004            0.550253        0.555912        0.071173
# 100006            0.664796        0.650442        0.071143
# 100007            0.557628        0.322738        0.053231
#
#             A_AMT_REQ_CREDIT_BUREAU_HOUR  A_AMT_INCOME_TOTAL  \
# SK_ID_CURR
# 100002                          0.000000            202500.0
# 100003                          0.000000            270000.0
# 100004                          0.000000             67500.0
# 100006                          0.007517            135000.0
# 100007                          0.000000            121500.0
#
#             A_DAYS_ID_PUBLISH  A_CODE_GENDER  A_OCCUPATION_TYPE  \
# SK_ID_CURR
# 100002                -2120.0            0.0                0.0
# 100003                 -291.0            1.0                1.0
# 100004                -2531.0            0.0                0.0
# 100006                -2437.0            1.0                0.0
# 100007                -3458.0            0.0                1.0
#
#             A_ORGANIZATION_TYPE  A_NAME_INCOME_TYPE  A_REGION_RATING_CLIENT
# SK_ID_CURR
# 100002                      0.0                 0.0                     2.0
# 100003                      1.0                 1.0                     1.0
# 100004                      2.0                 0.0                     2.0
# 100006                      0.0                 0.0                     2.0
# 100007                      3.0                 0.0                     2.0

# %%
y = app_train.loc[app_train.index]["TARGET"]
y.head()
# Out:
# SK_ID_CURR
# 100002    1.0
# 100003    0.0
# 100004    0.0
# 100006    0.0
# 100007    0.0
# Name: TARGET, dtype: float64

# %%
model_application.fit(x,y)
# Out:
# DecisionTreeClassifier(max_depth=7, random_state=0)

# %%
predicted = pd.DataFrame(model_application.predict_proba(x), index=app_train.index)
predicted.columns = ["A_PAYBACK", "A_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT
# SK_ID_CURR
# 100002         1.0   0.573145   0.426855
# 100003         0.0   0.780943   0.219057
# 100004         0.0   0.977739   0.022261
# 100006         0.0   0.996350   0.003650
# 100007         0.0   0.962839   0.037161

# %%
# bureau prediction

# %%
x = bureau[model_bureau_data["keep"]]
x.head()
# Out:
#             B_Closed  B_Active
# SK_ID_CURR
# 100002           6.0       2.0
# 100003           3.0       1.0
# 100004           2.0       0.0
# 100007           1.0       0.0
# 100008           2.0       1.0

# %%
y = app_train.loc[bureau.index]["TARGET"]
y.head()
# Out:
# SK_ID_CURR
# 100002    1.0
# 100003    0.0
# 100004    0.0
# 100007    0.0
# 100008    0.0
# Name: TARGET, dtype: float64

# %%
model_bureau.fit(x,y)
# Out:
# DecisionTreeClassifier(max_depth=7, random_state=0)

# %%
predicted = pd.DataFrame(model_bureau.predict_proba(x), index=bureau.index)
predicted.columns = ["B_PAYBACK", "B_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT
# SK_ID_CURR
# 100002         1.0   0.573145   0.426855   0.944348   0.055652
# 100003         0.0   0.780943   0.219057   0.938875   0.061125
# 100004         0.0   0.977739   0.022261   0.945874   0.054126
# 100006         0.0   0.996350   0.003650        NaN        NaN
# 100007         0.0   0.962839   0.037161   0.930100   0.069900

# %%
# pa_pos prediction

# %%
x = pa_pos[model_pa_pos_data["keep"]]
x.head()
# Out:
#             PA_AMT_ANNUITY  PA_CNT_NAME_CONTRACT_STATUS_Refused  \
# SK_ID_CURR
# 158271            6404.310                                  0.0
# 252457            4951.350                                  0.0
# 260094           97839.945                                  1.0
# 176456           14713.605                                  0.0
# 256657           60139.575                                  7.0
#
#             PA_POS_CNT_DPD  PA_CNT_NAME_PRODUCT_TYPE_walk-in  \
# SK_ID_CURR
# 158271                 0.0                               0.0
# 252457                 0.0                               1.0
# 260094                 0.0                               1.0
# 176456                 0.0                               0.0
# 256657                 0.0                               5.0
#
#             PA_AMT_APPLICATION  PA_AMT_DOWN_PAYMENT  PA_RATE_DOWN_PAYMENT  \
# SK_ID_CURR
# 158271               58905.000             0.000000              0.000000
# 252457               47056.275             4.275000              0.000088
# 260094             2023469.370          8765.370000              0.312513
# 176456              123486.075         12349.575000              0.101388
# 256657             1115806.500         10246.286731              0.699443
#
#             PA_AMT_GOODS_PRICE  PA_POS_CNT_PAYMENTS_LEFT  \
# SK_ID_CURR
# 158271               58905.000                       0.0
# 252457               47056.275                       9.0
# 260094             2023469.370                      70.0
# 176456              123486.075                       0.0
# 256657             1115806.500                      28.0
#
#             PA_CNT_NAME_YIELD_GROUP_high  PA_CNT_NAME_CLIENT_TYPE_New  \
# SK_ID_CURR
# 158271                               0.0                          1.0
# 252457                               0.0                          0.0
# 260094                               4.0                          1.0
# 176456                               0.0                          1.0
# 256657                               0.0                          1.0
#
#             PA_CNT_NAME_YIELD_GROUP_low_normal  \
# SK_ID_CURR
# 158271                                     0.0
# 252457                                     0.0
# 260094                                     3.0
# 176456                                     0.0
# 256657                                     2.0
#
#             PA_CNT_NAME_CONTRACT_TYPE_Revolving loans  PA_CNT_CREDITS  \
# SK_ID_CURR
# 158271                                            0.0             1.0
# 252457                                            1.0             1.0
# 260094                                            0.0             9.0
# 176456                                            0.0             1.0
# 256657                                            2.0             3.0
#
#             PA_CNT_PRODUCT_COMBINATION_Card Street  \
# SK_ID_CURR
# 158271                                         0.0
# 252457                                         1.0
# 260094                                         0.0
# 176456                                         0.0
# 256657                                         1.0
#
#             PA_CNT_NAME_CLIENT_TYPE_Refreshed  PA_CNT_NAME_PORTFOLIO_Cards  \
# SK_ID_CURR
# 158271                                    0.0                          0.0
# 252457                                    2.0                          1.0
# 260094                                    1.0                          0.0
# 176456                                    0.0                          0.0
# 256657                                    0.0                          2.0
#
#             PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low
# SK_ID_CURR
# 158271                                              0.0
# 252457                                              0.0
# 260094                                              4.0
# 176456                                              0.0
# 256657                                              0.0

# %%
y = app_train.loc[pa_pos.index]["TARGET"]
y.head()
# Out:
# SK_ID_CURR
# 158271    0.0
# 252457    0.0
# 260094    0.0
# 176456    0.0
# 256657    0.0
# Name: TARGET, dtype: float64

# %%
model_pa_pos.fit(x,y)
# Out:
# DecisionTreeClassifier(max_depth=7, random_state=0)

# %%
predicted = pd.DataFrame(model_pa_pos.predict_proba(x), index=pa_pos.index)
predicted.columns = ["PA_POS_PAYBACK", "PA_POS_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  \
# SK_ID_CURR
# 100002         1.0   0.573145   0.426855   0.944348   0.055652
# 100003         0.0   0.780943   0.219057   0.938875   0.061125
# 100004         0.0   0.977739   0.022261   0.945874   0.054126
# 100006         0.0   0.996350   0.003650        NaN        NaN
# 100007         0.0   0.962839   0.037161   0.930100   0.069900
#
#             PA_POS_PAYBACK  PA_POS_DEFAULT
# SK_ID_CURR
# 100002            0.913482        0.086518
# 100003            0.958792        0.041208
# 100004            0.912298        0.087702
# 100006            0.941321        0.058679
# 100007            0.926242        0.073758

# %%
# pa_ip prediction

# %%
x = pa_ip[model_pa_ip_data["keep"]]
x.head()
# Out:
#             PA_CNT_NAME_PRODUCT_TYPE_walk-in  PA_AMT_ANNUITY  \
# SK_ID_CURR
# 252457                                   1.0     4951.350000
# 256657                                   5.0    49054.770000
# 198678                                   0.0    51759.551912
# 394447                                   1.0     2250.000000
# 156331                                   0.0    40866.795000
#
#             PA_CNT_NAME_CONTRACT_STATUS_Refused  PA_IP_AMT_DIFF_180  \
# SK_ID_CURR
# 252457                                      0.0                 0.0
# 256657                                      7.0                 0.0
# 198678                                      0.0                 0.0
# 394447                                      0.0                 0.0
# 156331                                      0.0                 0.0
#
#             PA_IP_DAYS_DIFF_90  PA_IP_PAYMENT_120  PA_IP_DAYS_DIFF_30  \
# SK_ID_CURR
# 252457                   -17.0           0.912871                 0.0
# 256657                   -12.0           0.204124                -6.0
# 198678                    -6.5          -0.000407               -20.0
# 394447                    -1.0          -0.867506                 0.0
# 156331                     0.0          -1.114368                 0.0
#
#             PA_IP_DAYS_DIFF_60  PA_IP_AMT_DIFF_60  \
# SK_ID_CURR
# 252457                   -15.0                0.0
# 256657                   -13.0                0.0
# 198678                   -21.5                0.0
# 394447                    -1.0                0.0
# 156331                     0.0                0.0
#
#             PA_CNT_NAME_YIELD_GROUP_low_normal  PA_IP_PAYMENT_90  \
# SK_ID_CURR
# 252457                                     0.0      9.128709e-01
# 256657                                     2.0      2.041241e-01
# 198678                                     0.0      4.540312e-08
# 394447                                     0.0     -1.044958e+00
# 156331                                     1.0      1.416426e-02
#
#             PA_AMT_APPLICATION  PA_IP_PAYMENT_60  PA_CNT_NAME_PORTFOLIO_Cards  \
# SK_ID_CURR
# 252457               47056.275      9.128709e-01                          1.0
# 256657              978570.000      2.041241e-01                          2.0
# 198678              921721.500      4.540312e-08                          0.0
# 394447               45000.000      8.148280e-01                          1.0
# 156331              793035.000      1.416426e-02                          1.0
#
#             PA_CNT_NAME_CLIENT_TYPE_New  PA_IP_AMT_DIFF_120  \
# SK_ID_CURR
# 252457                              0.0                 0.0
# 256657                              1.0                 0.0
# 198678                              1.0                 0.0
# 394447                              2.0                 0.0
# 156331                              1.0                 0.0
#
#             PA_AMT_DOWN_PAYMENT  PA_CNT_NAME_CONTRACT_TYPE_Revolving loans  \
# SK_ID_CURR
# 252457                    4.275                                        1.0
# 256657                15714.000                                        2.0
# 198678                13347.000                                        0.0
# 394447                    0.000                                        1.0
# 156331                    0.000                                        2.0
#
#             PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low
# SK_ID_CURR
# 252457                                              0.0
# 256657                                              0.0
# 198678                                              0.0
# 394447                                              0.0
# 156331                                              0.0

# %%
y = app_train.loc[pa_ip.index]["TARGET"]
y.head()
# Out:
# SK_ID_CURR
# 252457    0.0
# 256657    0.0
# 198678    0.0
# 394447    0.0
# 156331    0.0
# Name: TARGET, dtype: float64

# %%
model_pa_ip.fit(x,y)
# Out:
# DecisionTreeClassifier(max_depth=7, random_state=0)

# %%
predicted = pd.DataFrame(model_pa_ip.predict_proba(x), index=pa_ip.index)
predicted.columns = ["PA_IP_PAYBACK", "PA_IP_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  \
# SK_ID_CURR
# 100002         1.0   0.573145   0.426855   0.944348   0.055652
# 100003         0.0   0.780943   0.219057   0.938875   0.061125
# 100004         0.0   0.977739   0.022261   0.945874   0.054126
# 100006         0.0   0.996350   0.003650        NaN        NaN
# 100007         0.0   0.962839   0.037161   0.930100   0.069900
#
#             PA_POS_PAYBACK  PA_POS_DEFAULT  PA_IP_PAYBACK  PA_IP_DEFAULT
# SK_ID_CURR
# 100002            0.913482        0.086518       0.936357       0.063643
# 100003            0.958792        0.041208            NaN            NaN
# 100004            0.912298        0.087702            NaN            NaN
# 100006            0.941321        0.058679       0.927720       0.072280
# 100007            0.926242        0.073758       0.897748       0.102252

# %%
# pa_cc prediction

# %%
x = pa_cc[model_pa_cc_data["keep"]]
x.head()
# Out:
#             PA_CC_BALANCE_60  PA_CNT_NAME_PRODUCT_TYPE_walk-in  \
# SK_ID_CURR
# 394447              1.434002                               1.0
# 361282              0.828945                               1.0
# 436351              0.000000                               1.0
# 181153              0.000000                               1.0
# 309691              0.000000                               1.0
#
#             PA_CC_BALANCE_90  PA_CNT_NAME_CONTRACT_STATUS_Refused  \
# SK_ID_CURR
# 394447              0.992963                                  0.0
# 361282              0.861611                                  0.0
# 436351              0.000000                                  3.0
# 181153              0.000000                                  3.0
# 309691              0.000000                                  0.0
#
#             PA_CC_PAYMENT_180  PA_CNT_PRODUCT_COMBINATION_Cash X-Sell: low  \
# SK_ID_CURR
# 394447               1.318045                                          0.0
# 361282              -1.152838                                          0.0
# 436351               0.000000                                          3.0
# 181153               0.000000                                          0.0
# 309691               0.000000                                          1.0
#
#             PA_CC_BALANCE_150  PA_CC_DPD_30  PA_CC_DPD_90  PA_CC_PAYMENT_30  \
# SK_ID_CURR
# 394447              -0.415697           0.0           0.0         -1.389108
# 361282              -1.074370           0.0           0.0          0.850318
# 436351               0.000000           0.0           0.0          0.000000
# 181153               0.000000           0.0           0.0          0.000000
# 309691               0.000000           0.0           0.0          0.000000
#
#             PA_CC_DPD_180  PA_CC_DPD_120  PA_CNT_CODE_REJECT_REASON_HC  \
# SK_ID_CURR
# 394447                0.0            0.0                           0.0
# 361282                0.0            0.0                           0.0
# 436351                0.0            0.0                           3.0
# 181153                0.0            0.0                           0.0
# 309691                0.0            0.0                           0.0
#
#             PA_CNT_CREDITS
# SK_ID_CURR
# 394447                 1.0
# 361282                 1.0
# 436351                 1.0
# 181153                 1.0
# 309691                 1.0

# %%
y = app_train.loc[pa_cc.index]["TARGET"]
y.head()
# Out:
# SK_ID_CURR
# 394447    0.0
# 361282    0.0
# 436351    0.0
# 181153    0.0
# 309691    0.0
# Name: TARGET, dtype: float64

# %%
model_pa_cc.fit(x,y)
# Out:
# DecisionTreeClassifier(max_depth=7, random_state=0)

# %%
predicted = pd.DataFrame(model_pa_cc.predict_proba(x), index=pa_cc.index)
predicted.columns = ["PA_CC_PAYBACK", "PA_CC_DEFAULT"]

# %%
df = pd.merge(df, predicted, how="left", left_index=True, right_index=True)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  \
# SK_ID_CURR
# 100002         1.0   0.573145   0.426855   0.944348   0.055652
# 100003         0.0   0.780943   0.219057   0.938875   0.061125
# 100004         0.0   0.977739   0.022261   0.945874   0.054126
# 100006         0.0   0.996350   0.003650        NaN        NaN
# 100007         0.0   0.962839   0.037161   0.930100   0.069900
#
#             PA_POS_PAYBACK  PA_POS_DEFAULT  PA_IP_PAYBACK  PA_IP_DEFAULT  \
# SK_ID_CURR
# 100002            0.913482        0.086518       0.936357       0.063643
# 100003            0.958792        0.041208            NaN            NaN
# 100004            0.912298        0.087702            NaN            NaN
# 100006            0.941321        0.058679       0.927720       0.072280
# 100007            0.926242        0.073758       0.897748       0.102252
#
#             PA_CC_PAYBACK  PA_CC_DEFAULT
# SK_ID_CURR
# 100002                NaN            NaN
# 100003                NaN            NaN
# 100004                NaN            NaN
# 100006           0.950272       0.049728
# 100007                NaN            NaN

# %%
df = df.fillna(0.5)
df.head()
# Out:
#             TARGET  A_PAYBACK  A_DEFAULT  B_PAYBACK  B_DEFAULT  \
# SK_ID_CURR
# 100002         1.0   0.573145   0.426855   0.944348   0.055652
# 100003         0.0   0.780943   0.219057   0.938875   0.061125
# 100004         0.0   0.977739   0.022261   0.945874   0.054126
# 100006         0.0   0.996350   0.003650   0.500000   0.500000
# 100007         0.0   0.962839   0.037161   0.930100   0.069900
#
#             PA_POS_PAYBACK  PA_POS_DEFAULT  PA_IP_PAYBACK  PA_IP_DEFAULT  \
# SK_ID_CURR
# 100002            0.913482        0.086518       0.936357       0.063643
# 100003            0.958792        0.041208       0.500000       0.500000
# 100004            0.912298        0.087702       0.500000       0.500000
# 100006            0.941321        0.058679       0.927720       0.072280
# 100007            0.926242        0.073758       0.897748       0.102252
#
#             PA_CC_PAYBACK  PA_CC_DEFAULT
# SK_ID_CURR
# 100002           0.500000       0.500000
# 100003           0.500000       0.500000
# 100004           0.500000       0.500000
# 100006           0.950272       0.049728
# 100007           0.500000       0.500000

# %%
# finales Modell

# %%
model = DecisionTreeClassifier(**TREE_PARAMS)

aucs = []

kfold = KFold(5, shuffle=True, random_state=1)
data = df

y = df["TARGET"]
x = df.drop(["TARGET"], axis=1)

for ID_TRAIN, ID_TEST in kfold.split(data):
    
    x_train = x.iloc[ID_TRAIN]
    y_train = y.iloc[ID_TRAIN]
    x_test = x.iloc[ID_TEST]
    y_test = y.iloc[ID_TEST]
    
    model.fit(x_train, y_train)
    auc = roc_auc_score(y_test, model.predict_proba(x_test)[:,1])
    aucs.append(auc)
    
    print('train: %s, test: %s, auc: %s' % (ID_TRAIN, ID_TEST, auc))

print("\n")
print("Durchschnitt: %.2f" % (np.mean(aucs)))
print("Standardabw.: %.2f" % (np.std(aucs)))
print("Varianz:      %.2f" % (np.var(aucs)))
# Out:
# train: [     0      2      3 ... 307508 307509 307510], test: [     1      4      6 ... 307493 307495 307501], auc: 0.8197617399157294
# train: [     0      1      2 ... 307508 307509 307510], test: [     3     18     22 ... 307499 307503 307504], auc: 0.8137417827031361
# train: [     0      1      2 ... 307508 307509 307510], test: [     9     10     15 ... 307489 307492 307502], auc: 0.8096337211388106
# train: [     0      1      2 ... 307506 307507 307508], test: [    12     16     23 ... 307505 307509 307510], auc: 0.8148293386745673
# train: [     1      3      4 ... 307505 307509 307510], test: [     0      2      5 ... 307506 307507 307508], auc: 0.8052350680266736
#
#
# Durchschnitt: 0.81
# Standardabw.: 0.00
# Varianz:      0.00
