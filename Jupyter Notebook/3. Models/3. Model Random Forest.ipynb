# %%
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

np.set_printoptions(suppress=True)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

# %%
path1 = Path(r"A:\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")
path2 = Path(r"C:\Users\rober\Documents\Workspace\Python\Masterarbeit\Kaggle Home Credit Datensatz")

if path1.is_dir():
    DATASET_DIR = path1
else:
    DATASET_DIR = path2

# %%
app_test = pd.read_csv(DATASET_DIR / "application_test.csv")
app_train = pd.read_csv(DATASET_DIR / "application_train.csv")

# %%
app_train["TARGET"].replace(
    {
        0: "Payback",
        1: "Default"
    }, inplace = True
)

# %%
n_heads = ['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'WEEKDAY_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21']
m_heads = ['CNT_CHILDREN','AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'CNT_FAM_MEMBERS', 'HOUR_APPR_PROCESS_START', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG', 'COMMONAREA_AVG', 'ELEVATORS_AVG', 'ENTRANCES_AVG', 'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LANDAREA_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'NONLIVINGAPARTMENTS_AVG', 'NONLIVINGAREA_AVG', 'APARTMENTS_MODE', 'BASEMENTAREA_MODE', 'YEARS_BEGINEXPLUATATION_MODE', 'YEARS_BUILD_MODE', 'COMMONAREA_MODE', 'ELEVATORS_MODE', 'ENTRANCES_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE', 'LANDAREA_MODE', 'LIVINGAPARTMENTS_MODE', 'LIVINGAREA_MODE', 'NONLIVINGAPARTMENTS_MODE', 'NONLIVINGAREA_MODE', 'APARTMENTS_MEDI', 'BASEMENTAREA_MEDI', 'YEARS_BEGINEXPLUATATION_MEDI', 'YEARS_BUILD_MEDI', 'COMMONAREA_MEDI', 'ELEVATORS_MEDI', 'ENTRANCES_MEDI', 'FLOORSMAX_MEDI', 'FLOORSMIN_MEDI', 'LANDAREA_MEDI', 'LIVINGAPARTMENTS_MEDI', 'LIVINGAREA_MEDI', 'NONLIVINGAPARTMENTS_MEDI', 'NONLIVINGAREA_MEDI', 'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR']
md_heads = ['CNT_CHILDREN', "CNT_FAM_MEMBERS","HOUR_APPR_PROCESS_START", "OBS_30_CNT_SOCIAL_CIRCLE","DEF_30_CNT_SOCIAL_CIRCLE", "OBS_60_CNT_SOCIAL_CIRCLE", "DEF_60_CNT_SOCIAL_CIRCLE","AMT_REQ_CREDIT_BUREAU_HOUR","AMT_REQ_CREDIT_BUREAU_DAY","AMT_REQ_CREDIT_BUREAU_WEEK","AMT_REQ_CREDIT_BUREAU_MON","AMT_REQ_CREDIT_BUREAU_QRT","AMT_REQ_CREDIT_BUREAU_YEAR"]
ms_heads = [head for head in m_heads if head not in md_heads]

# %%
payback = app_train[app_train["TARGET"] == "Payback"]
default = app_train[app_train["TARGET"] == "Default"]
m = app_train[m_heads]
n = app_train[n_heads]

md = m[md_heads]
mdp = md[app_train["TARGET"] == "Payback"]
mdd = md[app_train["TARGET"] == "Default"]

ms = m[ms_heads]
msp = ms[app_train["TARGET"] == "Payback"]
msd = ms[app_train["TARGET"] == "Default"]

# %%
# transformiert kategorische variablen in integer
for head in n_heads:
    app_train[head], cats = pd.factorize(app_train[head])

# %%
y = app_train["TARGET"]
x = app_train.drop(["SK_ID_CURR", "TARGET"], axis=1)

# %%
# ersätzt alle np.nan durch 0
x = x.fillna(0)

# %%
# unterteilt den trainingsdatensatz in trainings- und validierungsdatensätze
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.5, random_state=0)

# %%
model = RandomForestClassifier(max_depth=7, random_state=0)

# %%
model.fit(x,y)
# Out:
# RandomForestClassifier(max_depth=7, random_state=0)

# %%
# Prognosewerte der Testdaten
model.predict(x_test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
# Prognosewerte der Testdaten in %
x_test_prob = model.predict_proba(x_test)
x_test_prob
# Out:
# array([[0.12041091, 0.87958909],
#        [0.03853226, 0.96146774],
#        [0.06057466, 0.93942534],
#        ...,
#        [0.07556437, 0.92443563],
#        [0.07405507, 0.92594493],
#        [0.0847687 , 0.9152313 ]])

# %%
# Durchschnittliche Trefferwahrscheinlichkeit
model.score(x_test, y_test)
# Out:
# 0.919424282629621

# %%
# Erstellung der AUC & ROC-Metrik
# Wahrscheinlichkeiten für keinen Kreditausfall
prob = x_test_prob[:,1]
auc = roc_auc_score(y_test, prob)
print(auc)
# FalsePositiveRate, TruePositiveRate & Treshold
fpr, tpr, threshold = roc_curve(y_test, prob)
# Out:
# 0.7465061624680887

# %%
plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()

# %%
# Koeffizienten der einzelnen Klassen
coef_dict = {}
for coef, feat in zip(model.feature_importances_, x.columns.values):
    coef_dict[feat] = coef

# %%
# Feature Importance
d = dict(sorted(coef_dict.items(), key=lambda item: item[1], reverse=True))

for i,v in d.items():
    print('Feature: {}, Score: {}'.format(i,v))
# Out:
# Feature: EXT_SOURCE_2, Score: 0.22493750383640349
# Feature: EXT_SOURCE_3, Score: 0.20362375647895092
# Feature: EXT_SOURCE_1, Score: 0.07157034048838688
# Feature: DAYS_BIRTH, Score: 0.05510665342395673
# Feature: DAYS_EMPLOYED, Score: 0.033927147621638246
# Feature: DAYS_LAST_PHONE_CHANGE, Score: 0.02985027097465773
# Feature: AMT_GOODS_PRICE, Score: 0.0251168265165351
# Feature: NAME_INCOME_TYPE, Score: 0.02379670987698569
# Feature: NAME_EDUCATION_TYPE, Score: 0.020895357226290406
# Feature: CODE_GENDER, Score: 0.0178515315377673
# Feature: REGION_RATING_CLIENT_W_CITY, Score: 0.01733471543599935
# Feature: DAYS_ID_PUBLISH, Score: 0.017133925044443235
# Feature: AMT_CREDIT, Score: 0.01527066358895546
# Feature: AMT_ANNUITY, Score: 0.012456348573013984
# Feature: FLAG_EMP_PHONE, Score: 0.012091326543226328
# Feature: FLAG_DOCUMENT_3, Score: 0.011976692256983754
# Feature: REGION_RATING_CLIENT, Score: 0.011192389708424996
# Feature: REG_CITY_NOT_WORK_CITY, Score: 0.010431885332399153
# Feature: TOTALAREA_MODE, Score: 0.010098266736017785
# Feature: DAYS_REGISTRATION, Score: 0.009262775761049315
# Feature: FLOORSMAX_AVG, Score: 0.007888634585034845
# Feature: APARTMENTS_AVG, Score: 0.006800476065646382
# Feature: REGION_POPULATION_RELATIVE, Score: 0.006528166732193617
# Feature: OCCUPATION_TYPE, Score: 0.005937566361551643
# Feature: REG_CITY_NOT_LIVE_CITY, Score: 0.005569159583728463
# Feature: FLOORSMAX_MEDI, Score: 0.0054289084678351045
# Feature: LIVINGAREA_AVG, Score: 0.005186194788371331
# Feature: APARTMENTS_MEDI, Score: 0.004216581464551604
# Feature: ENTRANCES_AVG, Score: 0.00421248392391081
# Feature: DEF_30_CNT_SOCIAL_CIRCLE, Score: 0.0040290072048587535
# Feature: AMT_INCOME_TOTAL, Score: 0.003960938211366311
# Feature: FLOORSMAX_MODE, Score: 0.003951237701337975
# Feature: NAME_CONTRACT_TYPE, Score: 0.00393550178210415
# Feature: APARTMENTS_MODE, Score: 0.0038525716322749615
# Feature: OWN_CAR_AGE, Score: 0.0036735224687968163
# Feature: FLAG_OWN_CAR, Score: 0.003615184865471294
# Feature: LIVINGAREA_MEDI, Score: 0.0033524074298011894
# Feature: DEF_60_CNT_SOCIAL_CIRCLE, Score: 0.0031391528653861517
# Feature: HOUR_APPR_PROCESS_START, Score: 0.0030034461442935583
# Feature: ORGANIZATION_TYPE, Score: 0.0028846725023097372
# Feature: YEARS_BEGINEXPLUATATION_MEDI, Score: 0.0028419663966017983
# Feature: ELEVATORS_AVG, Score: 0.002830217881136646
# Feature: YEARS_BEGINEXPLUATATION_MODE, Score: 0.002799747467928027
# Feature: LIVINGAREA_MODE, Score: 0.002610505186317201
# Feature: EMERGENCYSTATE_MODE, Score: 0.0023300153604250327
# Feature: NAME_FAMILY_STATUS, Score: 0.002310340309527812
# Feature: WALLSMATERIAL_MODE, Score: 0.0022901587716907105
# Feature: YEARS_BEGINEXPLUATATION_AVG, Score: 0.002196261018534578
# Feature: CNT_FAM_MEMBERS, Score: 0.002096225529794725
# Feature: AMT_REQ_CREDIT_BUREAU_YEAR, Score: 0.001881064717597072
# Feature: LIVINGAPARTMENTS_AVG, Score: 0.0018526627606366543
# Feature: ENTRANCES_MEDI, Score: 0.0018007092125809448
# Feature: CNT_CHILDREN, Score: 0.0016817057683222254
# Feature: ENTRANCES_MODE, Score: 0.0016758827752044194
# Feature: ELEVATORS_MEDI, Score: 0.0016436435849514941
# Feature: LIVINGAPARTMENTS_MEDI, Score: 0.0016259465401157454
# Feature: COMMONAREA_MODE, Score: 0.001567565469586259
# Feature: OBS_60_CNT_SOCIAL_CIRCLE, Score: 0.0015031133431420319
# Feature: NONLIVINGAREA_MEDI, Score: 0.0015001770653510524
# Feature: LANDAREA_MEDI, Score: 0.0014882666099074757
# Feature: OBS_30_CNT_SOCIAL_CIRCLE, Score: 0.0014569193415447286
# Feature: LANDAREA_AVG, Score: 0.0013575202211793826
# Feature: NONLIVINGAREA_MODE, Score: 0.0013372541353916874
# Feature: NAME_HOUSING_TYPE, Score: 0.0013241236666945357
# Feature: LIVINGAPARTMENTS_MODE, Score: 0.0012757967631862235
# Feature: YEARS_BUILD_MODE, Score: 0.0012680250893997468
# Feature: LANDAREA_MODE, Score: 0.0012588316307592007
# Feature: NONLIVINGAREA_AVG, Score: 0.0012071573925782656
# Feature: COMMONAREA_AVG, Score: 0.0011801781745515894
# Feature: BASEMENTAREA_MODE, Score: 0.0011552175214972337
# Feature: BASEMENTAREA_AVG, Score: 0.0011364305698850633
# Feature: COMMONAREA_MEDI, Score: 0.001102767471310857
# Feature: NONLIVINGAPARTMENTS_MEDI, Score: 0.0010775706870054115
# Feature: YEARS_BUILD_AVG, Score: 0.0010726383985912202
# Feature: BASEMENTAREA_MEDI, Score: 0.0010363440364286266
# Feature: AMT_REQ_CREDIT_BUREAU_QRT, Score: 0.001027701926507786
# Feature: NONLIVINGAPARTMENTS_AVG, Score: 0.0009829037857903946
# Feature: FLAG_DOCUMENT_6, Score: 0.0009665397070165954
# Feature: FLOORSMIN_AVG, Score: 0.000947255623750422
# Feature: ELEVATORS_MODE, Score: 0.0008994641175200282
# Feature: NONLIVINGAPARTMENTS_MODE, Score: 0.000866659410151671
# Feature: LIVE_CITY_NOT_WORK_CITY, Score: 0.0008614762207340131
# Feature: YEARS_BUILD_MEDI, Score: 0.0008586969559861016
# Feature: AMT_REQ_CREDIT_BUREAU_MON, Score: 0.0007817774651630843
# Feature: NAME_TYPE_SUITE, Score: 0.0007752057106928658
# Feature: FLOORSMIN_MODE, Score: 0.0007388122933757046
# Feature: HOUSETYPE_MODE, Score: 0.0006517131800060461
# Feature: FLAG_WORK_PHONE, Score: 0.0006514494609076894
# Feature: WEEKDAY_APPR_PROCESS_START, Score: 0.0006324366114592977
# Feature: FLOORSMIN_MEDI, Score: 0.0006228978193385552
# Feature: AMT_REQ_CREDIT_BUREAU_WEEK, Score: 0.0006175004844453967
# Feature: AMT_REQ_CREDIT_BUREAU_DAY, Score: 0.0005269079080185149
# Feature: FLAG_DOCUMENT_8, Score: 0.0005138280802862665
# Feature: FLAG_PHONE, Score: 0.000282551119658778
# Feature: FLAG_DOCUMENT_2, Score: 0.00023523108485644495
# Feature: FLAG_OWN_REALTY, Score: 0.00018693357578982025
# Feature: FLAG_DOCUMENT_19, Score: 0.00018431787306319748
# Feature: FLAG_DOCUMENT_7, Score: 0.00016941385266843872
# Feature: REG_REGION_NOT_WORK_REGION, Score: 0.0001402439703647231
# Feature: FONDKAPREMONT_MODE, Score: 0.00013206215249443425
# Feature: FLAG_CONT_MOBILE, Score: 0.00012453175473825702
# Feature: FLAG_DOCUMENT_5, Score: 9.726738627170305e-05
# Feature: LIVE_REGION_NOT_WORK_REGION, Score: 8.614205872512316e-05
# Feature: REG_REGION_NOT_LIVE_REGION, Score: 8.426131553991367e-05
# Feature: FLAG_DOCUMENT_20, Score: 7.561826577196289e-05
# Feature: FLAG_DOCUMENT_11, Score: 7.389310831128269e-05
# Feature: AMT_REQ_CREDIT_BUREAU_HOUR, Score: 5.668583899015259e-05
# Feature: FLAG_EMAIL, Score: 5.5774205762569104e-05
# Feature: FLAG_DOCUMENT_21, Score: 5.064495641418769e-05
# Feature: FLAG_DOCUMENT_16, Score: 4.426610103083573e-05
# Feature: FLAG_DOCUMENT_15, Score: 3.949361013159755e-05
# Feature: FLAG_DOCUMENT_13, Score: 2.957077211253165e-05
# Feature: FLAG_DOCUMENT_14, Score: 2.57288199595731e-05
# Feature: FLAG_DOCUMENT_18, Score: 1.6652623371488278e-05
# Feature: FLAG_DOCUMENT_9, Score: 1.2322543126698899e-05
# Feature: FLAG_DOCUMENT_17, Score: 9.313637429785271e-06
# Feature: FLAG_MOBIL, Score: 0.0
# Feature: FLAG_DOCUMENT_4, Score: 0.0
# Feature: FLAG_DOCUMENT_10, Score: 0.0
# Feature: FLAG_DOCUMENT_12, Score: 0.0

# %%
# Feature Importance: Top10 und Bottom10 visualisiert
t = pd.DataFrame.from_dict(d,orient="index",columns=["importance"])
t = t.sort_values(by="importance")
t = np.squeeze(t)

fig, ax = plt.subplots(figsize=(12,25))
ax.barh(t.index, t.values)
ax.set_yticklabels(tuple(t.index))
plt.show()
# Out:
# <ipython-input-46-10bac31632bc>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(tuple(t.index))
